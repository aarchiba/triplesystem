# %%
import scipy.linalg

import emcee

# %%
def lnprob(x):
    return -0.5*((0.2*x[1]+x[0])**2+(x[1]-0.5*x[0])**2)

# %%
def lnprob(x):
    return -0.5*(1e-6*(0.2*x[1]+x[0])**2+(x[1]-0.5*x[0])**2)

# %%
def lnprob(x):
    return -0.5*(0.1*(x[1]+x[0]*(x[0]-1)*(x[0]+1))**2+0.1*x[1]**2)-1000

# %%
xs = emcee.utils.sample_ball(np.zeros(2),np.ones(2),size=1000)

# %%
S = emcee.EnsembleSampler(xs.shape[0], xs.shape[1], lnprob)

# %%
pos, prob, state = S.run_mcmc(xs, 1000)

# %%
offs = S.chain.transpose((1,0,2))

# %%
for i in range(xs.shape[1]):
    plt.subplot(131)
    plt.title("mean")
    plt.plot(np.mean(offs[...,i]/e,axis=1))
    plt.subplot(132)
    plt.title("std")
    plt.semilogy(np.std(offs[...,i]/e,axis=1))
eigvals = []
for j in range(offs.shape[0]):
    vals, vecs = scipy.linalg.eigh(np.corrcoef(offs[j].T))
    eigvals.append(vals)
eigvals = np.array(eigvals)
for v in eigvals.T:
    plt.subplot(133)
    plt.title("eigenvalues of corr. mtx.")
    plt.semilogy(v)
plt.gcf().set_size_inches(8,4)

# %%
burnin = 100

# %%
burntchain = offs[burnin:].reshape((-1,offs.shape[-1]))

# %%
Cv = np.cov(burntchain.T)
vals, vecs = scipy.linalg.eigh(Cv)
for l,v in zip(vals,vecs.T):
    print l, v
# Out:
# 1.2716332311 [-0.99064034  0.13649803]
# 230.437708088 [ 0.13649803  0.99064034]

# %%
Cr = np.corrcoef(burntchain.T)
vals, vecs = scipy.linalg.eigh(Cr)
for l,v in zip(vals,vecs.T):
    print l, v, v*np.std(burntchain,axis=0)
# Out:
# 0.124677997375 [-0.70710678  0.70710678]
# [ -1.66453949  10.63408906]
# 1.87532200263 [ 0.70710678  0.70710678]
# [  1.66453949  10.63408906]

# %%
xs = emcee.utils.sample_ball(np.zeros(2),np.ones(2),size=20000).reshape(40,-1,2)
print xs.shape
# Out:
# (40, 500, 2)

# %%
S = emcee.PTSampler(xs.shape[0], xs.shape[1], xs.shape[2], lnprob, lambda a: 0)

# %%
S.run_mcmc(xs, 100);

# %%
S.chain.shape
# Out:
# (40, 500, 100, 2)

# %%
for i in range(S.chain.shape[0]):
    plt.semilogy(np.std(S.chain[i,:,:,0],axis=0))

# %%
print "prob:", lnprob(S.chain[3,1,2]), S.lnprobability[3,1,2]*2**(3/2.)
full_offsets = S.chain.transpose((2,0,1,3))
full_prob = S.lnprobability.transpose((2,0,1))
print full_offsets.shape, full_prob.shape
print "prob:", lnprob(full_offsets[2,3,1]), full_prob[2,3,1]
if full_offsets.shape[1]>1:
    for i in range(0,full_offsets.shape[1],5):
        plt.figure(1)
        probs = full_prob[-1,i,:]
        print "probs:", lnprob(full_offsets[-1,i,0]), full_prob[-1,i,0]
        plt.hist(probs-np.mean(probs),histtype='step')
        plt.figure(2)
        plt.semilogy(np.std(full_offsets[:,i,:,0],axis=-1))
    #plt.title("Distribution of log probablity for various temperatures") 
    #plt.xlabel("Log(log probability)")
# Out:
# prob: -1003.97639931 -1003.97639931
# (100, 40, 500, 2) (100, 40, 500)
# prob: -1003.97639931 -354.959260052
# probs: -1000.03962695 -1000.03962695
# probs:
#  -1011.34877424 -178.782894102
# probs: -1005.49712346 -31.4217851083
# probs: -1085.22455307 -5.99507531705
# probs: -1421.04071862 -1.38773507678
# probs: -2594.54416447 -0.447905217966
# probs: -9376.83642496 -0.286158338164
# probs: -40701.6467564 -0.219577105918

# %%
vals = S.chain[0,:,50:].reshape((-1,2))
plt.hexbin(vals[:,0],vals[:,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-147-c57cccc5958b> in <module>()
#       1 vals = S.chain[0,:,100:].reshape((-1,2))
# ----> 2 plt.hexbin(vals[:,0],vals[:,1])
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in hexbin(x, y, C, gridsize, bins, xscale, yscale, extent, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, reduce_C_function, mincnt, marginals, hold, **kwargs)
#    2321         ax.hold(hold)
#    2322     try:
# -> 2323         ret = ax.hexbin(x, y, C, gridsize, bins, xscale, yscale, extent, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, reduce_C_function, mincnt, marginals, **kwargs)
#    2324         draw_if_interactive()
#    2325     finally:
#
# ...
