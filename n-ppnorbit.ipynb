# %%
# %load_ext autoreload

# %autoreload 2

# %%
from glob import glob
import os
import time

import scipy.linalg
import scipy.stats

import emcee

import kepler
import threebody

# %%
import matplotlib
matplotlib.rcParams['savefig.dpi'] = 120

# %%
F = threebody.Fitter("0337+17-scott-2013-06-06",tzrmjd_middle=True,use_delta=False)
Fppn = threebody.Fitter("0337+17-scott-2013-06-06",tzrmjd_middle='weighted',use_delta=False,ppn_mode='GR')

# %%
r = F.residuals(F.best_parameters)

# %%
rppn = Fppn.residuals(Fppn.best_parameters)

# %%
bp2 = Fppn.best_parameters.copy()
bp2['matrix_mode'] = 3
rppn2 = Fppn.residuals(bp2)

# %%
np.sqrt(np.mean((rppn-rppn2)**2))*1e6/F.best_parameters['f0']
# Out:
# 0.0028767813711508044798

# %%
plt.hexbin((F.mjds-F.best_parameters['tasc_i'])/F.best_parameters['pb_i'] % 1, F.mjds, C=rppn-rppn2, gridsize=20)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x5c8eb00>

# %%
o = threebody.compute_orbit(F.best_parameters,F.mjds-F.base_mjd)

# %%
oppn = threebody.compute_orbit(Fppn.best_parameters,Fppn.mjds-Fppn.base_mjd)

# %%
o
# Out:
# {'n_evaluations': 439704L,
#  'parameter_dict': {'acosi_i': 1.4903050674419935,
#   'acosi_o': 90.39586215763221,
#   'asini_i': 1.2175228895332197,
#   'asini_o': 74.67273987627038,
#   'delta': 0.0,
#   'delta_lan': 0.00033939808643656356,
#   'eps1_i': 0.0006868065667501865,
#   'eps1_o': 0.035186254522179924,
#   'eps2_i': -9.158947337282243e-05,
#   'eps2_o': -0.0034620186732121317,
#   'f0': 365.9533687685485,
#   'f1': -2.345382901889618e-15,
#   'j_AO1350': 5.3128230250622114e-05,
#   'j_AO1440': 4.939728546944564e-05,
#   'j_AO327': 6.692408656317315e-05,
#   'j_GBT1500': 6.267045904016819e-05,
#   'j_GBT350': 1.925487812184441e-05,
#   'j_GBT820': 7.262205924836828e-05,
#   'j_WSRT350': -3.583318833579737e-05,
#   'pb_i': 1.6293970253503247,
#   'pb_o': 327.2576559605466,
#   'ppn_mode': None,
#   'q_i': 0.13734648231334265,
#   'tasc_i': 0.40751805805513447,
#   'tasc_o': 313.93573849321007,
#   'tzrmjd': 0.0007369712245211922},
#  'states': array([[ 101.18798,  40.801962,  33.730306, ..., -5.11873,  0.40704278,
#          7.5028627e-07],
#        [ 101.18758,  40.80145,  33.729889, ..., -5.1187234,  0.40704278,
#          7.5029486e-07],
#        [ 101.18719,  40.800937,  33.729472, ..., -5.1187167,  0.40704278,
#          7.5030344e-07],
#        ...,
#        [-77.892364, -72.174083, -59.629207, ...,  3.7379231,  0.40704278,
#          3.5402896e-05],
#        [-77.769141, -72.20747, -59.656624, ...,  3.7368022,  0.40704278,
#          3.5403872e-05],
#        [-77.645352, -72.236555, -59.680526, ...,  3.7356859,  0.40704278,
#          3.5404843e-05]], dtype=float128),
#  't_bb': array([ 10.928773,  10.928902,  10.92903, ...,  516.46047,  516.47436,
#         516.48819], dtype=float128),
#  't_d': array([ 10.928383,  10.928511,  10.928639, ...,  516.46116,  516.47505,
#         516.48888], dtype=float128),
#  't_psr': array([ 10.928382,  10.92851,  10.928639, ...,  516.46113,  516.47502,
#         516.48885], dtype=float128),
#  'time': 1.9644019603729248,
#  'times': array([ 10.928773,  10.928902,  10.92903, ...,  516.46047,  516.47436,
#         516.48819], dtype=float128)}

# %%
oppn
# Out:
# {'n_evaluations': 405042L,
#  'parameter_dict': {'acosi_i': 1.4903050674419935,
#   'acosi_o': 90.39586215763221,
#   'asini_i': 1.2175228895332197,
#   'asini_o': 74.67273987627038,
#   'delta': 0.0,
#   'delta_lan': 0.00033939808643656356,
#   'eps1_i': 0.0006868065667501865,
#   'eps1_o': 0.035186254522179924,
#   'eps2_i': -9.158947337282243e-05,
#   'eps2_o': -0.0034620186732121317,
#   'f0': 365.9533687685485,
#   'f1': -2.345382901889618e-15,
#   'j_AO1350': 5.3128230250622114e-05,
#   'j_AO1440': 4.939728546944564e-05,
#   'j_AO327': 6.692408656317315e-05,
#   'j_GBT1500': 6.267045904016819e-05,
#   'j_GBT350': 1.925487812184441e-05,
#   'j_GBT820': 7.262205924836828e-05,
#   'j_WSRT350': -3.583318833579737e-05,
#   'pb_i': 1.6293970253503247,
#   'pb_o': 327.2576559605466,
#   'ppn_mode': 'GR',
#   'q_i': 0.13734648231334265,
#   'tasc_i': 0.40751805805513447,
#   'tasc_o': 313.93573849321007,
#   'tzrmjd': 0.0007369712245211922},
#  'states': array([[ 101.18804,  40.802147,  33.730457, ..., -5.11873,  0.40704278,
#          7.5028519e-07],
#        [ 101.18765,  40.801634,  33.73004, ..., -5.1187234,  0.40704278,
#          7.5029377e-07],
#        [ 101.18725,  40.801122,  33.729623, ..., -5.1187168,  0.40704278,
#          7.5030235e-07],
#        ...,
#        [-77.903506, -72.171813, -59.627351, ...,  3.7379286,  0.40704278,
#          3.540284e-05],
#        [-77.78042, -72.205659, -59.655144, ...,  3.7368077,  0.40704278,
#          3.5403817e-05],
#        [-77.656735, -72.235206, -59.679423, ...,  3.7356913,  0.40704278,
#          3.5404788e-05]], dtype=float128),
#  't_bb': array([ 10.928773,  10.928902,  10.92903, ...,  516.46047,  516.47436,
#         516.48819], dtype=float128),
#  't_d': array([ 10.928383,  10.928511,  10.928639, ...,  516.46116,  516.47505,
#         516.48888], dtype=float128),
#  't_psr': array([ 10.928382,  10.92851,  10.928639, ...,  516.46113,  516.47502,
#         516.48885], dtype=float128),
#  'time': 2.5531301498413086,
#  'times': array([ 10.928773,  10.928902,  10.92903, ...,  516.46047,  516.47436,
#         516.48819], dtype=float128)}

# %%
plt.hexbin((F.mjds-F.best_parameters['tasc_i'])/F.best_parameters['pb_i'] % 1, F.mjds, 
            C=o['states'][:,2]-oppn['states'][:,2], gridsize=20)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x3de5b00>

# %%
ix = 2
plt.plot(F.mjds,o['states'][:,ix]-oppn['states'][:,ix])

# %%
for mm, mmn in enumerate(["direct","LDLT","fullPivHouseholderQr","fullPivLu"]):
    bp2['matrix_mode'] = mm
    oppn = threebody.compute_orbit(bp2,Fppn.mjds-Fppn.base_mjd)
    print mmn, oppn['time'], "s"
# Out:
# direct 2.24281907082 s
# LDLT
#  3.29721999168 s
# fullPivHouseholderQr
#  6.69527006149 s
# fullPivLu
#  4.26188898087 s

# %%
for i in range(3):
    oppn = threebody.compute_orbit(Fppn.best_parameters,Fppn.mjds-Fppn.base_mjd)
    print oppn['time'], "s"
# Out:
# 2.25129389763 s
# 2.24680089951
#  s
# 2.25002002716
#  s
