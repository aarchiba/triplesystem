# %%
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import subprocess
import os
import cPickle as pickle

import residuals

import threebody

# %%
#vlbi_mjd = 56513
#vlbi_mjd = 56699
#vlbi_mjd = 56710
#vlbi_mjd = 56734
#vlbi_mjd = 56760
#vlbi_mjd = 56879
vlbi_mjd = 56891

# %%
subprocess.check_call(["python", "fit_segment.py", 
                       "--fixedbtx", "--length", "40", 
                       str(vlbi_mjd)])
# Out:
# 0

# %%
r = residuals.read_residuals()

# %%
plt.plot(r.bary_TOA, r.postfit_phs)
plt.axvline(vlbi_mjd)

# %%
#F = threebody.Fitter("0337+17-scott-2013-06-06",tzrmjd_middle='weighted')
#F = threebody.Fitter(files="0337+17-scott-2013-08-29",tzrmjd_middle='auto',
#                     parfile="0337_tempo2_pm.par",
#                     fit_pos=True,
#                     fit_pm=False,
#                     fit_px=True,
#                     t2_astrometry=True,
#                     ppn_mode='GR')
fp = "fake_toas_fitter.pickle"
d = pickle.load(open(fp,"rb"))
F = threebody.Fitter(**d)

# %%
p = F.compute_linear_parts() #t_psr=o_o['t_psr'])
p['f0']
# Out:
# 365.95336308213979731

# %%
F.tzrmjd_base = p['tzrmjd_base']
F.best_parameters.update(p)

# %%
resids = F.residuals(F.best_parameters)

# %%
c = (F.mjds>vlbi_mjd-21) & (F.mjds<vlbi_mjd+21)
plt.errorbar(F.mjds[c],resids[c],F.phase_uncerts[c],fmt=".")
plt.figure()
d = ((r.bary_TOA>np.amin(F.mjds[c])) 
     & (r.bary_TOA<np.amax(F.mjds[c])))
plt.plot(r.bary_TOA[d],r.postfit_phs[d])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-807b5283cc17> in <module>()
#       1 c = (F.mjds>vlbi_mjd-21) & (F.mjds<vlbi_mjd+21)
# ----> 2 plt.errorbar(F.mjds[c],resids[c],F.phase_uncerts[c],fmt=".")
#       3 plt.figure()
#       4 d = ((r.bary_TOA>np.amin(F.mjds[c]))
#       5      & (r.bary_TOA<np.amax(F.mjds[c])))
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, hold, **kwargs)
#    2249         ax.hold(hold)
#    2250     try:
# -> 2251         ret = ax.errorbar(x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, **kwargs)
#    2252         draw_if_interactive()
#    2253     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, **kwargs)
#    5372                           in cbook.safezip(y,yerr)]
#    5373
# -> 5374             barcols.append( self.vlines(x, lower, upper, **lines_kw) )
#    5375             if capsize > 0:
#    5376
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    3753         coll.update(kwargs)
#    3754
# -> 3755         minx = min( x )
#    3756         maxx = max( x )
#    3757
#
# ValueError: min() arg is an empty sequence

# %%
print (np.amax(np.abs(
             r.postfit_phs[np.abs(r.bary_TOA-vlbi_mjd)<10]))
       /F.best_parameters['f0']*1e6)
# Out:
# 4.78416082193

# %%
plt.hexbin((r.bary_TOA-F.base_mjd-F.best_parameters['tasc_i'])/F.best_parameters['pb_i'] % 1,
           r.bary_TOA,
           C=r.postfit_phs,gridsize=30)
plt.axhline(vlbi_mjd,color='k')
plt.colorbar().set_label("turns")

# %%
with open("tz.in","wt") as f:
    f.write("""0    12   60   12  1410


0337+17
""")
p = subprocess.Popen(["tempo", "-f", "rankin-c-band-56760.par", "-z"], 
                     stdin=subprocess.PIPE,
                     stdout=subprocess.PIPE,
                     stderr=subprocess.PIPE)

out, err = p.communicate(input="%d %d\n" % (vlbi_mjd-1,vlbi_mjd+1))
print out
print err
# Out:
# TZ source list for site = 0
#
#     PSR        Nspan  Ncoeffs  Maxha    Freq
# ----------------------------------------------
#  0337+17           60      12   12.00   1410.00000
#
#  Current date is 14-APR-14, or MJD 56761.358
#
#  Enter first and last MJD, or hit return to run for today:
#  12-APR-14 through 14-APR-14
#
#  *** Warning - MJD = 56758 outside UT1 table range (40224-56684)
#  *** Warning - Further UT1 messages suppressed
#    745     0.00000000  -0.254050       -694.215            1
#  PSR 0337+17      11-APR-14  UTC:   0300   rms:    0.003 us.
#  PSR 0337+17      11-APR-14  UTC:   0400   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   0500   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   0600   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   0700   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   0800   rms:    0.003 us.
#  PSR 0337+17      11-APR-14  UTC:   0900   rms:    0.003 us.
#  PSR 0337+17      11-APR-14  UTC:   1000   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   1100   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   1200   rms:    0.003 us.
#  PSR 0337+17      11-APR-14  UTC:   1300   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   1400   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   1500   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   1600   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   1700   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   1800   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   1900   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   2000   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   2100   rms:    0.002 us.
#  PSR 0337+17      11-APR-14  UTC:   2200   rms:    0.003 us.
#  PSR 0337+17      11-APR-14  UTC:   2300   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   0000   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   0100   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   0200   rms:    0.002 us.
#    745     0.00000000   0.095819        261.835            1
#  PSR 0337+17      12-APR-14  UTC:   0300   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   0400   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   0500   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   0600   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   0700   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   0800   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   0900   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   1000   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   1100   rms:    0.003 us.
#  PSR 0337+17      12-APR-14  UTC:   1200   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   1300   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   1400   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   1500   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   1600   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   1700   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   1800   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   1900   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   2000   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   2100   rms:    0.003 us.
#  PSR 0337+17      12-APR-14  UTC:   2200   rms:    0.002 us.
#  PSR 0337+17      12-APR-14  UTC:   2300   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   0000   rms:    0.003 us.
#  PSR 0337+17      13-APR-14  UTC:   0100   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   0200   rms:    0.002 us.
#    745     0.00000000  -0.166991       -456.318            1
#  PSR 0337+17      13-APR-14  UTC:   0230   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   0330   rms:    0.003 us.
#  PSR 0337+17      13-APR-14  UTC:   0430   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   0530   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   0630   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   0730   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   0830   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   0930   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   1030   rms:    0.003 us.
#  PSR 0337+17      13-APR-14  UTC:   1130   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   1230   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   1330   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   1430   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   1530   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   1630   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   1730   rms:    0.003 us.
#  PSR 0337+17      13-APR-14  UTC:   1830   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   1930   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   2030   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   2130   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   2230   rms:    0.002 us.
#  PSR 0337+17      13-APR-14  UTC:   2330   rms:    0.002 us.
#  PSR 0337+17      14-APR-14  UTC:   0030   rms:    0.002 us.
#  PSR 0337+17      14-APR-14  UTC:   0130   rms:    0.002 us.

# %%
import psrchive
import profile_manipulation

# %%
ext_prof_name = "data/gbt/GUPPI_Lband_rotated.aligned"
ext_prof = psrchive.Archive_load(ext_prof_name)
ext_prof.pscrunch()
ext_prof.fscrunch()
ext_prof.tscrunch()
ext_np = ext_prof.get_data()[0,0,0,:]
np.savetxt("vlbi-profile-5-ext.txt", ext_np)

# %%
std_prof_name = "data/wsrt/J0337+1715_1380MHz_MJD55900-56200_Jan2012-Sep2012.AR"
std_prof = psrchive.Archive_load(std_prof_name)
std_prof.pscrunch()
std_prof.fscrunch()
std_prof.tscrunch()
std_np = std_prof.get_data()[0,0,0,:]

# %%
#aligned_profile_name = "data/gbt/guppi_56515_0337+17_0002.newephem"
aligned_profile_name = "data/gbt/guppi_56702_0337+17_0008.newephem"
aligned_profile = psrchive.Archive_load(aligned_profile_name)
aligned_profile.pscrunch()
aligned_profile.fscrunch()
aligned_profile.tscrunch()
aligned_profile.bscrunch_to_nbin(len(std_np))
ap_np = aligned_profile.get_data()[0,0,0,:]

# %%
phase, a, b, c, fit_prof = profile_manipulation.approx_fit(ap_np, std_np,
    oversample=64)

# %%
plt.plot(fit_prof)
#plt.plot(std_np)
plt.plot(ap_np)

# %%
np.savetxt("vlbi-profile-3.txt", fit_prof)

# %%
aligned_archive = psrchive.Archive_load(aligned_profile_name)
aligned_archive.pscrunch()
aligned_archive.fscrunch()
aligned_archive.bscrunch_to_nbin(len(std_np))
aa_np = aligned_archive.get_data()[:,0,0,:]
print np.shape(aa_np)

# %%
phases = []
for p in aa_np:
    phase, a, b, c, fit_prof = profile_manipulation.approx_fit(p, std_np,
        oversample=64)
    phases.append(phase)

# %%
plt.plot((np.array(phases)+0.5)%1-0.5, ".", markersize=1)

# %%
subprocess.check_call(["tempo","-f","J0337+17-vlbi3.par", "0337+17-scott-2013-08-29.tim"])
r2 = residuals.read_residuals()

# %%
c = np.abs(r2.bary_TOA-56527.35)<1
plt.plot(r2.bary_TOA[c],r2.prefit_phs[c])

# %%
subprocess.check_call(["tempo","-f","J0337+17-vlbi3.par", "fake.tim"])

# %%
r3 = residuals.read_residuals()

# %%
c = np.abs(r2.bary_TOA-56527.35)<1
plt.plot(r2.bary_TOA[c],1e6*(r2.prefit_sec[c]-np.mean(r2.prefit_sec[c])))
c = np.abs(r3.bary_TOA-56527.35)<0.15
plt.plot(r3.bary_TOA[c],1e6*(r3.prefit_sec[c]-np.mean(r3.prefit_sec[c])))
plt.title("Fake TOAs vs. real TOAs")
plt.ylabel(r"$\mu$s")

# %%
c = np.abs(r2.bary_TOA-56527.35)<40
plt.plot(r2.bary_TOA[c],1e6*(r2.prefit_sec[c]-np.mean(r2.prefit_sec[c])),
    ".",markersize=1)
c = np.abs(r3.bary_TOA-56527.35)<40
plt.plot(r3.bary_TOA[c],1e6*(r3.prefit_sec[c]-np.mean(r3.prefit_sec[c])),
    ".",markersize=1)
plt.title("Fake TOAs vs. real TOAs")
plt.ylabel(r"$\mu$s")

# %%
len(F.mjds), len(r2.bary_TOA)

# %%
r2t = r2.bary_TOA.copy()
r2t.sort()
r2t = r2t[r2t>55920]
len(F.mjds), len(r2t)

# %%
f0 = 395
plt.plot(F.mjds, (r2t-threebody.tcb_to_tdb(F.mjds))*86400*f0, ".", markersize=1)

# %%
c = np.abs(r2t-56527)<1
plt.plot(F.mjds[c], (r2t[c]-threebody.tcb_to_tdb(F.mjds[c]))*86400*f0, ".", markersize=1)

# %%
F.best_parameters
