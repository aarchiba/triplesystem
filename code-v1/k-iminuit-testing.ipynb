# %%
from __future__ import division, print_function

import numpy as np

from iminuit import Minuit

# %%
def testfun(x,y,z,w):
    print(x,y,z,w)
    return (x-1)**2+(y-2)**4+(z-3)**2+(w-4)**2

# %%
M = Minuit(testfun)
# Out:
# /users/aarchiba/.virtualenvs/triplesystem/lib/python2.7/site-packages/ipykernel_launcher.py:1: InitialParamWarning: errordef is not given. Default to 1.
#   """Entry point for launching an IPython kernel.
# /users/aarchiba/.virtualenvs/triplesystem/lib/python2.7/site-packages/ipykernel_launcher.py:1: InitialParamWarning: Parameter x does not have initial value. Assume 0.
#   """Entry point for launching an IPython kernel.
# /users/aarchiba/.virtualenvs/triplesystem/lib/python2.7/site-packages/ipykernel_launcher.py:1: InitialParamWarning: Parameter x is floating but does not have initial step size. Assume 1.
#   """Entry point for launching an IPython kernel.
# /users/aarchiba/.virtualenvs/triplesystem/lib/python2.7/site-packages/ipykernel_launcher.py:1: InitialParamWarning: Parameter y does not have initial value. Assume 0.
#   """Entry point for launching an IPython kernel.
# ...

# %%
M.migrad()
# Out:
# (0.0, 0.0, 0.0, 0.0)
# (0.010000000000000002, 0.0, 0.0, 0.0)
# (-0.010000000000000002, 0.0, 0.0, 0.0)
# (0.0032018741362562666, 0.0, 0.0, 0.0)
# (-0.0032018741362562666, 0.0, 0.0, 0.0)
# (0.0, 0.010000000000000002, 0.0, 0.0)
# (0.0, -0.010000000000000002, 0.0, 0.0)
# (0.0, 0.0010000000000000002, 0.0, 0.0)
# (0.0, -0.0010000000000000002, 0.0, 0.0)
# (0.0, 0.0, 0.010000000000000002, 0.0)
# (0.0, 0.0, -0.010000000000000002, 0.0)
# (0.0, 0.0, 0.0032018741362562666, 0.0)
# (0.0, 0.0, -0.0032018741362562666, 0.0)
# (0.0, 0.0, 0.0, 0.010000000000000002)
# (0.0, 0.0, 0.0, -0.010000000000000002)
# (0.0, 0.0, 0.0, 0.0032018741362562666)
# (0.0, 0.0, 0.0, -0.0032018741362562666)
# (0.9999999999666073, 0.6666668056078654, 2.9999999998998215, 3.999999999867539)
# (1.0629920069585603, 0.7086614856894214, 3.188976020875681, 4.251968027835421)
# (1.063954293687888, 0.7086614856894214, 3.188976020875681, 4.251968027835421)
# ...
