# %%
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from glob import glob
import os
import time
import cPickle as pickle

import scipy.linalg
import scipy.stats

import emcee

import kepler
import threebody

# %%
fpickle = "fitter_params.pickle"
d = pickle.load(open(fpickle,"rb"))
F = threebody.Fitter(**d)

# %%
F.mjds = (np.linspace(1,2000,100000)).astype(np.longdouble)
F.jmatrix = np.zeros((len(F.mjds),F.jmatrix.shape[1]))

# %%
O = F.compute_orbit(F.best_parameters)

# %%
O['labels'] = [c+o for o in ["_psr","_i","_o"] for c in ["x","y","z","vx","vy","vz","m"]] + ["rel_delay"]

# %%
for i in range(3):
    plt.plot(O["times"],O["states"][:,i],label=O['labels'][i])
plt.legend(loc='best')

# %%
for j in range(3)[::-1]:
    plt.plot(O["states"][:,7*j+0],O["states"][:,7*j+1])
plt.gca().set_aspect('equal', 'datalim')

# %%
for j in range(3)[::-1]:
    plt.plot(O["states"][:,7*j+1],O["states"][:,7*j+2])
plt.gca().set_aspect('equal', 'datalim')

# %%
O['states'].shape
# Out:
# (100000, 22)

# %%
np.savez?

# %%
np.savez_compressed("orbit.npz", **O)

# %%
n = 800
for j in range(3)[::-1]:
    plt.plot(O["states"][:n,7*j+0],O["states"][:n,7*j+1])
plt.gca().set_aspect('equal', 'datalim')
