# %%
# %load_ext autoreload

# %autoreload 2

# %%
import astropy
import astropy.units as u

import threebody

# %%
F = threebody.Fitter(files="0337+17-scott-2013-08-29",tzrmjd_middle='auto',
                     parfile="0337_tempo2_nobinary.par",
                     fit_pos=True,
                     fit_pm=True,
                     fit_px=True,
                     t2_astrometry=True,
                     ppn_mode='GR')

# %%
r_best = F.residuals(F.best_parameters)

# %%
d = 700*u.parsec
v = 100*u.km/u.s
proper_motion = v/d*u.radian

# %%
proper_motion.to(u.mas/u.year)
# Out:
# <Quantity 30.1356466531 mas / yr>

# %%
proper_motion.to(u.radian/u.day)
# Out:
# <Quantity 4.00004758015e-10 rad / d>

# %%
float(((1*u.mas/u.year)/(u.radian/u.day)).decompose())
# Out:
# WARNING: Converting Quantity object in units '1' to a Python scalar [astropy.units.quantity]
# 1.3273475184381547e-11

# %%
(u.mas/u.year).to(u.radian/u.year)
# Out:
# 4.84813681109536e-09

# %%
p = F.best_parameters.copy()
p['lan']=np.pi
p['pm_x']=4e-10
p['pm_y']=0

# %%
r_p = F.residuals(p)

# %%
plt.hexbin(
        ((F.mjds-F.base_mjd-F.best_parameters['tasc_i'])/F.best_parameters['pb_i'])%1, 
        F.mjds,
        C=(r_p-r_best)/F.best_parameters['f0']*1e6, gridsize=20)
plt.colorbar().set_label(r"$\mu$s")
