# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import scipy.linalg
import matplotlib.pyplot as plt
from collections import namedtuple
from pylab import rcParams
rcParams['savefig.dpi'] = 144
import pickle
from astropy.io import fits
import os, sys, math, time
import math
from scipy.stats import norm
import matplotlib.mlab as mlab
from scipy import stats
from scipy.stats import kstest
from scipy.stats import norm
from matplotlib.font_manager import FontProperties

import read_data as rd
import arrow_plot as ap
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# #Primary:

# %%
data_primary=pickle.load(open('../../../datasets/systematics-package-primary-20171220.pickle', 'rb'))

# %%
ar_primary=ap.draw_ar_plot_from_data(data_primary, 4, scl_s='ns')
plt.title('Primary')

# %% [markdown]
# ###Arrow length investigation:

# %%
my_ul=ap.upper_limit(data_primary, my_pickle='../../../datasets/primary_1.0_10000_s.pickle', scl_s='ns')
plt.title('Primary')
# Out:
# sqrt(sum(X^2)) in ns: 19.1802152893
# signal of Delta in ns
#  33.1305494944 ; the fit value of Delta -1.08530037771e-06
# len of der array:
#  10000
# mean of resulted sigma (ns):
#  24.0836084404 ; its std: 3.17760311516
# sf(real_Delta): 0.530987854821
# 1_sigma 23.8801665453 ns
# 2_sigma 48.9681148261 ns
# 3_sigma 76.5963521108 ns
# 1-sigma upper limit on Delta: -7.8227358637e-07

# %%
d=my_data['derivatives'][np.newaxis][0]
cols= sorted(d.keys())

print np.shape(cols)
A = np.array([d[c] for c in cols]).T
print A.shape
b=new_res

r = lstsq_with_errors(A, b, new_unc)
better_phase=b-np.dot(A,r.x)
diff=new_res-better_phase

for (i,c) in enumerate(cols):
    print i, c, r.x[i], "+/-", r.uncerts[i], (r.x/r.uncerts)[i], "sigma"

# %% [markdown]
# #LowFreq:

# %%
data_lowfreq=pickle.load(open('../../../datasets/systematics-package-lowfreq-20171220.pickle', 'rb'))
#ap.der_unc(data_lowfreq)

# %%
ar_lowfreq=ap.draw_ar_plot_from_data(data_lowfreq, 4, scl_s='ns')
plt.title('lowfreq')

# %% [markdown]
# ###Arrow length investigation:

# %%
my_ul=ap.upper_limit(data_lowfreq, my_pickle='../../../datasets/lowfreq_1.0_10000_s.pickle', scl_s='ns')
plt.title('lowfreq')
# Out:
# sqrt(sum(X^2)) in ns: 53.5876085622
# signal of Delta in ns
#  64.929483207 ; the fit value of Delta -2.1149877665e-06
# len of der array:
#  10000
# mean of resulted sigma (ns):
#  66.4528821271 ; its std: 8.64522444774
# sf(real_Delta): 1.02241827467
# 1_sigma 65.9065009796 ns
# 2_sigma 135.063424038 ns
# 3_sigma 211.003652907 ns
# 1-sigma upper limit on Delta: -2.14681276394e-06

# %% [markdown]
# #Newton:

# %%
data_newton=pickle.load(open('../../../datasets/systematics-package-newton-20171220.pickle', 'rb'))
#ap.der_unc(data_lowfreq)

# %%
ar_newton=ap.draw_ar_plot_from_data(data_newton, 4, scl_s='ns')
plt.title('Newton')

# %% [markdown]
# ###Arrow length investigation:

# %%
my_ul=ap.upper_limit(data_newton, my_pickle='../../../datasets/newton_1.0_10000_s.pickle', scl_s='ns')
plt.title('newton')
# Out:
# sqrt(sum(X^2)) in ns: 125.22906197
# signal of Delta in ns
#  22.0072639646 ; the fit value of Delta 6.98711915175e-07
# len of der array:
#  10000
# mean of resulted sigma (ns):
#  154.534300672 ; its std: 19.920931894
# sf(real_Delta): 2.78892392581
# 1_sigma 153.287755648 ns
# 2_sigma 313.983563657 ns
# 3_sigma 490.21788208 ns
# 1-sigma upper limit on Delta: 4.86675588087e-06

# %% [markdown]
# #Arecibo:

# %%
data_AO=pickle.load(open('../../../datasets/systematics-package-AO-20171220.pickle', 'rb'))
#ap.der_unc(data_lowfreq)

# %%
ar_newton=ap.draw_ar_plot_from_data(data_AO, 4, scl_s='ns')
plt.title('Arecibo')

# %% [markdown]
# ###Arrow length investigation:

# %%
my_ul=ap.upper_limit(data_AO, my_pickle='../../../datasets/AO_1.00_final.pickle', scl_s='ns')
plt.title('Arecibo')
# Out:
# sqrt(sum(X^2)) in ns: 58.0836370161
# signal of Delta in ns
#  26.1762280769 ; the fit value of Delta -9.76379795539e-07
# len of der array:
#  100000
# mean of resulted sigma (ns):
#  60.1961364048 ; its std: 12.4214686528
# sf(real_Delta): 2.05324567886
# 1_sigma
#  59.0077818015 ns
# 2_sigma 125.334736715 ns
# 3_sigma 204.704449673 ns
# 1-sigma upper limit on Delta: -2.20100488739e-06

# %% [markdown]
# #Green Bank:

# %%
data_GBT=pickle.load(open('../../../datasets/systematics-package-GBT-20171220.pickle', 'rb'))
#ap.der_unc(data_lowfreq)

# %%
ar_gbt=ap.draw_ar_plot_from_data(data_GBT, 4, scl_s='ns')
plt.title('Green Bank')

# %% [markdown]
# ###Convert pickle

# %%
with open('../../../datasets/GBT_1.0_10000.pickle', 'rb') as f:
    array_pickle = pickle.load(f)

my_in=array_pickle['init_coeff']
my_der=array_pickle['der_coeff']

der_ar = {
    'init_coeff': my_in,
    'der_coeff': my_der,
    'sigma': 1.0,
}

with open('../../../datasets/GBT_1.0_10000_s.pickle', 'wb') as e:
    pickle.dump(der_ar, e, pickle.HIGHEST_PROTOCOL)
    
print len(my_in)
# Out:
# 10000

# %% [markdown]
# ###Arrow length investigation:

# %%
my_ul=ap.upper_limit(data_GBT, my_pickle='../../../datasets/GBT_1.0_10000_s.pickle', scl_s='ns')
plt.title('Green Bank')
# Out:
# sqrt(sum(X^2)) in ns: 40.8279544231
# signal of Delta in ns
#  1.11317009841 ; the fit value of Delta 3.79287836503e-08
# len of der array:
#  10000
# mean of resulted sigma (ns):
#  50.0573268469 ; its std: 6.55594738601
# sf(real_Delta): 3.09463786186
# 1_sigma 49.640755783 ns
# 2_sigma 101.761773327 ns
# 3_sigma 159.041046411 ns
# 1-sigma upper limit on Delta: 1.69139782771e-06

# %% [markdown]
# #Westerbork:

# %%
data_WSRT=pickle.load(open('../../../datasets/systematics-package-WSRT-20171220.pickle', 'rb'))
#ap.der_unc(data_lowfreq)

# %%
ar_wsrt=ap.draw_ar_plot_from_data(data_WSRT, 4, scl_s='ns')
plt.title('Westerbork')

# %% [markdown]
# ###Convert pickle

# %%
with open('../../../datasets/WSRT_1.0_10000.pickle', 'rb') as f:
    array_pickle = pickle.load(f)

my_in=array_pickle['init_coeff']
my_der=array_pickle['der_coeff']

der_ar = {
    'init_coeff': my_in,
    'der_coeff': my_der,
    'sigma': 1.0,
}

with open('../../../datasets/WSRT_1.0_10000_s.pickle', 'wb') as e:
    pickle.dump(der_ar, e, pickle.HIGHEST_PROTOCOL)
    
print len(my_in)
# Out:
# 10000

# %% [markdown]
# ###Arrow length investigation:

# %%
my_ul=ap.upper_limit(data_WSRT, my_pickle='../../../datasets/WSRT_1.0_10000_s.pickle', scl_s='ns')
plt.title('Westerbork')
# Out:
# sqrt(sum(X^2)) in ns: 59.4758942468
# signal of Delta in ns
#  41.1044870872 ; the fit value of Delta -2.13422497099e-06
# len of der array:
#  10000
# mean of resulted sigma (ns):
#  73.4513151356 ; its std: 9.60349294265
# sf(real_Delta): 1.79772230326
# 1_sigma 72.8415479851 ns
# 2_sigma 149.298278135 ns
# 3_sigma 233.4182114 ns
# 1-sigma upper limit on Delta: -3.78207494247e-06

# %% [markdown]
# #Daily DM:

# %%
data_dailyDM=pickle.load(open('../../../datasets/systematics-package-dailyDM-20171220.pickle', 'rb'))
#ap.der_unc(data_lowfreq)

# %%
ar_newton=ap.draw_ar_plot_from_data(data_dailyDM, 4, scl_s='ns')
plt.title('Daily_DM')

# %% [markdown]
# ###Arrow length investigation:

# %%
my_ul=ap.upper_limit(data_newton, my_pickle='../../../datasets/dailyDM_1.0_10000_s.pickle', scl_s='ns')
plt.title('dailyDM')
# Out:
# sqrt(sum(X^2)) in ns: 125.22906197
# signal of Delta in ns
#  22.0072639646 ; the fit value of Delta 6.98711915175e-07
# len of der array:
#  10000
# mean of resulted sigma (ns):
#  154.534300672 ; its std: 19.920931894
# sf(real_Delta): 2.78892392581
# 1_sigma 153.287755648 ns
# 2_sigma 313.983563657 ns
# 3_sigma 490.21788208 ns
# 1-sigma upper limit on Delta: 4.86675588087e-06

# %% [markdown]
# #Additional illujstrations:

# %%
my_data=data_primary

base_mjd=my_data['base_mjd']
par_dict=my_data['best_parameters']
par_dict['base_mjd']=base_mjd

p_period = my_data['f0']**(-1)
pb_i = par_dict['pb_i']
pb_o = par_dict['pb_o']
phi_i=(2.0*math.pi)/pb_i
phi_o=(2.0*math.pi)/pb_o
tasc_i = par_dict["tasc_i"]
tasc_o = par_dict["tasc_o"]

limiit=10000
c = abs(my_data['residuals']/my_data['phase_uncerts'])<limiit
new_phase = np.array(my_data['residuals'][c], dtype=np.float64)
new_times = np.array(my_data['times'][c], dtype=np.float64)+base_mjd
new_unc = np.array(my_data['phase_uncerts'][c], dtype=np.float64)



print 'base mjd:', base_mjd
print 'pulsar period:', p_period
print 'last date:', np.amax(new_times), '...its year:', rd.day_to_year(np.amax(new_times))
print 'biggest residual:', np.amax(new_phase)
# Out:
# base mjd: 55920
# pulsar period: 0.00273258859009
# last date: 57866.917495 ...its year: 2017.30998582
# biggest residual: 0.00364899262786

# %%
import read_data as rd
import arrow_plot as ap

gbt=rd.tel_transform(my_data,'GBT_1400')
ao1400=rd.tel_transform(my_data,'AO_1400')
wsrt1400=rd.tel_transform(my_data,'WSRT_1400')

name=['WSRT_1400','GBT_1400', 'AO_1400']
color=['y', 'g', 'b']

rd.plot_res(my_data, new_times, new_phase, new_unc, name, color)
plt.figtext(0.13, 0.15, '12-01-2017 data', fontsize=20, color='r')
# Out:
# (55920.0, 57930.0)
# (2011.9795067660527, 2017.4826998500996)
# /usr/lib/python2.7/dist-packages/matplotlib/lines.py:1082: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markeredgecolor != ec:
# /usr/lib/python2.7/dist-packages/matplotlib/lines.py:1106: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markerfacecolor != fc:

# %%
all_emac1=np.array(new_phase/new_unc, dtype=np.float64)
gbt_emac1=np.array(gbt.phase/gbt.unc, dtype=np.float64)
ao1400_emac1=np.array(ao1400.phase/ao1400.unc, dtype=np.float64)
wsrt1400_emac1=np.array(wsrt1400.phase/wsrt1400.unc, dtype=np.float64)

rd.fit_plot(all_emac1, 1, 'All', 'grey', 4, 6)
ao_efac1=rd.fit_plot(ao1400_emac1, 2, 'Arecibo 1400 MHz', 'dodgerblue', 4, 6)
gbt_efac1=rd.fit_plot(gbt_emac1, 3, 'GBT', 'green', 4, 6)
wsrt_efac1=rd.fit_plot(wsrt1400_emac1, 4, 'Westerbork 1400 MHz', 'orange', 4, 6)

plt.gcf().set_size_inches(15,10)
#plt.savefig('25082017_efacs.pdf')

# %% [markdown]
# ##Do additional fit (deriavtives):

# %%
better_phase=ap.der_fit(my_data,new_phase,new_unc)
diff=new_phase-better_phase

delta_only=ap.der_of_par(my_data,'delta',new_unc)

# %% [markdown]
# ##Arrow plot

# %%
scl=p_period*1e9#ns

bet_data=ap.draw_plot(par_dict, 4, new_times, better_phase*scl, new_unc*scl)
plt.title("Data 2017-12-01 better phase")

# %%
import read_data as rd

rd.plot_hex(par_dict,new_times,delta_only*scl*deltaa, 40)
plt.title(r'Signature of $\Delta$=%3.2f e-6'%(deltaa*1e6))
