# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import scipy.linalg
import matplotlib.pyplot as plt
from collections import namedtuple
from pylab import rcParams
rcParams['savefig.dpi'] = 144
import pickle
from astropy.io import fits
import os, sys, math, time
import math
from scipy.stats import norm
import matplotlib.mlab as mlab
from scipy import stats
from scipy.stats import kstest
from scipy.stats import norm
from matplotlib.font_manager import FontProperties

import read_data as rd
import arrow_plot as ap

# %% [markdown]
# #Newton:

# %%
data_newton=pickle.load(open('../../../datasets/systematics-package-newton-20171220.pickle', 'rb'))
#ap.der_unc(data_lowfreq)

# %%
data_newton['fitter_params']
# Out:
# {'efac': 1,
#  'fdn_range': (1, 5),
#  'files': 'tuned2_aligned_pulses_1400',
#  'fit_pm': True,
#  'fit_pos': True,
#  'fit_px': True,
#  'kopeikin': False,
#  'linear_dm': True,
#  'linear_jumps': True,
#  'parfile': '0337_tempo2_px_optical_dmcorr.par',
#  'ppn_mode': 'heavysimple',
#  'priors': ('dbeta', 'dgamma'),
#  't2_astrometry': True,
#  'toa_mode': 'pipeline',
#  'tzrmjd_middle': 'auto'}

# %%
ar_newton=ap.draw_ar_plot_from_data(data_newton, 4, scl_s='ns')
plt.title('Newton')

# %%
ap.der_unc(data_newton)
# Out:
# 0 DM_0001 0 0.000522052341168 +/- 0.00812851717157 -0.0642247940367 sigma
# 1 DM_0002 0 0.000202463303454 +/- 0.00970259379195 -0.0208669256691 sigma
# 2 DM_0003 0 -0.00186029449334 +/- 0.0105511088591 0.176312700228 sigma
# 3 DM_0004 0 -0.000660460061925 +/- 0.00864094710896 0.0764337581976 sigma
# 4 FD1 0 4.49045658313e-05 +/- 0.00130071499853 -0.0345229861131 sigma
# 5 FD2 0 -0.000197447125979 +/- 0.00584631145611 0.0337729399915 sigma
# 6 FD3 0 0.000384009180341 +/- 0.0110618621714 -0.0347146958072 sigma
# 7 FD4 0 -0.000270600555022 +/- 0.00750346529535 0.0360634112868 sigma
# 8 IPM_0000 0 2.67193671939 +/- 6.41683544011 -0.416394770339 sigma
# 9 IPM_0001 0 -2.26084720221 +/- 16.8209798541 0.134406391412 sigma
# 10 IPM_0002 0 -3.04631299039 +/- 24.4351948074 0.124669069119 sigma
# 11 IPM_0003 0 14.6938859405 +/- 33.3375908571 -0.440760281795 sigma
# 12 IPM_0004 0 2.74853101251 +/- 10.4038053589 -0.264185162803 sigma
# 13 acosi_i 1.49039629946 1.49027155724 +/- 0.000185589668075 0.672139908004 sigma
# 14 acosi_o 91.4930461872 91.4824603561 +/- 0.0120612777791 0.877670784472 sigma
# 15 asini_i 1.21752934642 1.21752914759 +/- 1.93320008639e-07 1.02851702313 sigma
# 16 asini_o 74.6727642903 74.6727541481 +/- 1.05747233588e-05 0.959096046515 sigma
# 17 d_DECJ 0 8.2442571464e-07 +/- 1.82887267623e-06 -0.450783548443 sigma
# 18 d_PMDEC 0 -9.31227894513e-10 +/- 1.13338793463e-09 0.821632087358 sigma
# 19 d_PMRA 0 2.01292666931e-10 +/- 3.08530685866e-10 -0.652423490279 sigma
# 20 d_PX 0 -1.56788779271 +/- 6.67584465493 0.234859837782 sigma
# 21 d_RAJ 0 -2.31191201117e-07 +/- 4.221109301e-07 0.547702474945 sigma
# 22 delta 6.98711915175e-07 5.45762592982e-07 +/- 1.58535557608e-07 0.964763517411 sigma
# 23 delta_lan 9.96790603343e-06 1.05592482977e-05 +/- 7.63518191737e-07 -0.774496627144 sigma
# 24 eps1_i 0.000684789875483 0.000684940945546 +/- 1.5782782492e-07 -0.957182695096 sigma
# 25 eps1_o 0.0351864634218 0.0351864242685 +/- 4.03454811656e-08 0.970449858172 sigma
# 26 eps2_i -9.3258406866e-05 -9.32737827528e-05 +/- 1.4832406211e-08 1.03664143089 sigma
# 27 eps2_o -0.00346143446024 -0.00346156441904 +/- 1.34289238508e-07 0.967752954315 sigma
# 28 f0 0 -2.09743420112e-09 +/- 3.66386844838e-09 0.572464385846 sigma
# 29 f1 0 3.77060684485e-22 +/- 3.27911861304e-21 -0.114988424934 sigma
# 30 j_GBT_1400 0 9.61555823439e-07 +/- 4.55973008762e-06 -0.210879987403 sigma
# 31 j_WSRT_1400 0 -1.04557707679e-07 +/- 9.93050766238e-06 0.0105289388251 sigma
# 32 pb_i 1.6294040065 1.62940350927 +/- 5.16113593806e-07 0.963417481987 sigma
# 33 pb_o 327.258006161 327.257917236 +/- 9.2121559257e-05 0.965303605892 sigma
# 34 phase 0 -2.70103492271e-05 +/- 0.00010906382783 0.247656347338 sigma
# 35 q_i 0.137733466492 0.137730537224 +/- 3.56094026537e-06 0.822610883867 sigma
# 36 tasc_i 0.40771739685 0.407717350442 +/- 4.78245152288e-08 0.970395131106 sigma
# 37 tasc_o 313.936279129 313.936190339 +/- 9.20747679659e-05 0.964330999462 sigma

# %% [markdown]
# ###Arrow length investigation:

# %%
my_ul=ap.upper_limit(data_newton, my_pickle='../../../datasets/newton_1.00_final.pickle', scl_s='ns')
plt.title('newton')
# Out:
# sqrt(sum(X^2)) in ns: 125.22906197
# signal of Delta in ns

# %% [markdown]
# #Additional illustrations:

# %%
my_data=data_newton

base_mjd=my_data['base_mjd']
par_dict=my_data['best_parameters']
par_dict['base_mjd']=base_mjd

p_period = my_data['f0']**(-1)
pb_i = par_dict['pb_i']
pb_o = par_dict['pb_o']
phi_i=(2.0*math.pi)/pb_i
phi_o=(2.0*math.pi)/pb_o
tasc_i = par_dict["tasc_i"]
tasc_o = par_dict["tasc_o"]

limiit=10000
c = abs(my_data['residuals']/my_data['phase_uncerts'])<limiit
new_phase = np.array(my_data['residuals'][c], dtype=np.float64)
new_times = np.array(my_data['times'][c], dtype=np.float64)+base_mjd
new_unc = np.array(my_data['phase_uncerts'][c], dtype=np.float64)

deltaa=my_data['best_parameters']['delta']

print 'size of residuals array:', len(new_phase)
print 'base mjd:', base_mjd
print 'pulsar period:', p_period
print 'last date:', np.amax(new_times), '...its year:', rd.day_to_year(np.amax(new_times))
print 'biggest residual:', np.amax(new_phase)
print 'delta:', deltaa
# Out:
# size of residuals array: 27110
# base mjd: 55920
# pulsar period: 0.00273258859009
# last date: 57866.917495 ...its year: 2017.30998582
# biggest residual: 0.00349469482899
# delta: 6.98711915175e-07

# %%
import read_data as rd
import arrow_plot as ap

gbt=rd.tel_transform(my_data,'GBT_1400')
ao1400=rd.tel_transform(my_data,'AO_1400')
wsrt1400=rd.tel_transform(my_data,'WSRT_1400')

name=['WSRT_1400','GBT_1400', 'AO_1400']
color=['y', 'g', 'b']

rd.plot_res(my_data, new_times, new_phase, new_unc, name, color)
plt.figtext(0.13, 0.15, '12-01-2017 data', fontsize=20, color='r')
# Out:
# (55920.0, 57930.0)
# (2011.9795067660527, 2017.4826998500996)
# /usr/lib/python2.7/dist-packages/matplotlib/lines.py:1082: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markeredgecolor != ec:
# /usr/lib/python2.7/dist-packages/matplotlib/lines.py:1106: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markerfacecolor != fc:

# %%
all_emac1=np.array(new_phase/new_unc, dtype=np.float64)
gbt_emac1=np.array(gbt.phase/gbt.unc, dtype=np.float64)
ao1400_emac1=np.array(ao1400.phase/ao1400.unc, dtype=np.float64)
wsrt1400_emac1=np.array(wsrt1400.phase/wsrt1400.unc, dtype=np.float64)

numplots=4
limm=6

rd.fit_plot(all_emac1, 1, 'All', 'grey', numplots, limm)
ao_efac1=rd.fit_plot(ao1400_emac1, 2, 'Arecibo 1400 MHz', 'dodgerblue', numplots, limm)
gbt_efac1=rd.fit_plot(gbt_emac1, 3, 'GBT', 'green', numplots, limm)
wsrt_efac1=rd.fit_plot(wsrt1400_emac1, 4, 'Westerbork 1400 MHz', 'orange', numplots, limm)

plt.gcf().set_size_inches(15,10)
#plt.savefig('25082017_efacs.pdf')

# %% [markdown]
# ##Do additional fit (deriavtives):

# %%
better_phase=ap.der_fit(my_data,new_phase,new_unc)
diff=new_phase-better_phase

delta_only=ap.der_of_par(my_data,'delta',new_unc)

# %% [markdown]
# ##Arrow plot

# %%
scl=p_period*1e9#ns

bet_data=ap.draw_plot(par_dict, 4, new_times, better_phase*scl, new_unc*scl)
plt.title("Data 2017-12-01 better phase")

# %%
import read_data as rd

rd.plot_hex(par_dict,new_times,delta_only*scl*deltaa, 40)
plt.title(r'Signature of $\Delta$=%3.2f e-6'%(deltaa*1e6))

# %%
rd.plot_res(my_data, new_times, delta_only*deltaa, new_unc*1e-15, name, color)
# Out:
# (55920.0, 57930.0)
# (2011.9795067660527, 2017.4826998500996)

# %%
res_delta=ap.draw_plot(par_dict, 4, new_times, delta_only*deltaa*scl, new_unc*scl*1e-12, color='red')
plt.title(r'Signature of New $\Delta$')

print res_delta
# Out:
# 22.0072639646
