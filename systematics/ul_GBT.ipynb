# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import scipy.linalg
import matplotlib.pyplot as plt
from collections import namedtuple
from pylab import rcParams
rcParams['savefig.dpi'] = 144
import pickle
from astropy.io import fits
import os, sys, math, time
import math
from scipy.stats import norm
import matplotlib.mlab as mlab
from scipy import stats
from scipy.stats import kstest
from scipy.stats import norm
from matplotlib.font_manager import FontProperties

import read_data as rd
import arrow_plot as ap

# %% [markdown]
# #Green Bank:

# %%
data_GBT=pickle.load(open('../../../datasets/systematics-package-GBT-20180227.pickle', 'rb'))
#ap.der_unc(data_lowfreq)

# %%
ar_gbt=ap.draw_ar_plot_from_data(data_GBT, 4, scl_s='ns')
plt.title('Green Bank')

# %%
ap.der_unc(data_GBT)
# Out:
# 0 DM_0001 0 -0.0027298854726 +/- 0.0168420643641 0.162087343546 sigma
# 1 DM_0002 0 0.000257137177194 +/- 0.019805943756 -0.0129828288094 sigma
# 2 DM_0003 0 -0.00129139814811 +/- 0.0212109994239 0.0608834181881 sigma
# 3 DM_0004 0 -0.00503708526619 +/- 0.0177545529092 0.283706680307 sigma
# 4 FD1 0 -3.31266218928e-05 +/- 0.00242386801052 0.0136668423152 sigma
# 5 FD2 0 6.96907503667e-05 +/- 0.0106690788137 -0.00653203070141 sigma
# 6 FD3 0 -6.74051114201e-05 +/- 0.0197039769 0.00342088867452 sigma
# 7 FD4 0 1.22348848145e-05 +/- 0.0130021832716 -0.00094098695265 sigma
# 8 IPM_0000 0 -2.54865015815 +/- 18.8224060553 0.135405120401 sigma
# 9 IPM_0001 0 3.49922954117 +/- 22.6790931549 -0.154293186119 sigma
# 10 IPM_0002 0 -7.31291892848 +/- 27.3413622086 0.267467248803 sigma
# 11 IPM_0003 0 -6.00663968573 +/- 45.6969924832 0.131444967367 sigma
# 12 IPM_0004 0 5.29259355073 +/- 26.9170119128 -0.196626340542 sigma
# 13 acosi_i 1.48891711068 1.48901087637 +/- 0.000376303160826 -0.249175943052 sigma
# 14 acosi_o 91.3263682192 91.3315431884 +/- 0.0228624496925 -0.226352347348 sigma
# 15 asini_i 1.21752665961 1.21752639305 +/- 4.95909563898e-07 0.537510703097 sigma
# 16 asini_o 74.6727087785 74.6727015625 +/- 2.59166989862e-05 0.278431470131 sigma
# 17 d_DECJ 0 1.79683085511e-06 +/- 3.5606038765e-06 -0.504642166733 sigma
# 18 d_PMDEC 0 2.0119904821e-10 +/- 2.86512160735e-09 -0.0702235631794 sigma
# 19 d_PMRA 0 -1.22454947872e-10 +/- 7.4429486458e-10 0.164524778686 sigma
# 20 d_PX 0 -2.53369162843 +/- 10.7281188731 0.236172963629 sigma
# 21 d_RAJ 0 -4.10043528816e-07 +/- 8.55731268413e-07 0.479173245096 sigma
# 22 dbeta 0.00107194157109 0.0725751598367 +/- 0.0945377651497 -0.756345553043 sigma
# 23 delta 3.79285055576e-08 -4.92380836996e-08 +/- 3.90547680548e-07 0.223190646364 sigma
# 24 delta_lan 8.47005839449e-07 4.84393358304e-07 +/- 2.10240286431e-06 0.172475260237 sigma
# 25 dgamma -1.24755179865e-05 0.0575237285208 +/- 0.0517111086063 -1.11264688748 sigma
# 26 eps1_i 0.000687080647688 0.000687269613682 +/- 3.89506391282e-07 -0.485142215803 sigma
# 27 eps1_o 0.0351862528267 0.0351862253808 +/- 9.89686570952e-08 0.277319241828 sigma
# 28 eps2_i -9.12873322423e-05 -9.12389183045e-05 +/- 5.28882659039e-08 -0.915400362726 sigma
# 29 eps2_o -0.00346211438537 -0.00346220382149 +/- 3.29508605795e-07 0.271422726223 sigma
# 30 f0 0 2.24342366138e-09 +/- 7.74236284073e-09 -0.289759561458 sigma
# 31 f1 0 -5.45833063428e-22 +/- 1.34147919995e-20 0.0406888950233 sigma
# 32 pb_i 1.62939707629 1.62939645854 +/- 1.29233031715e-06 0.478010313965 sigma
# 33 pb_o 327.257540096 327.257478673 +/- 0.0002260622204 0.271705633281 sigma
# 34 phase 0 -0.000267513638596 +/- 0.000339190666715 0.788682192191 sigma
# 35 q_i 0.137416444786 0.13741411892 +/- 9.04109444946e-06 0.257254899535 sigma
# 36 tasc_i 0.40771692864 0.407716868553 +/- 1.24083780155e-07 0.484243133383 sigma
# 37 tasc_o 313.93581355 313.935752125 +/- 0.000225990397004 0.271802217686 sigma

# %% [markdown]
# ###Arrow length investigation GBT:

# %%
my_ul=ap.upper_limit_delta(data_GBT, my_pickle='../../../datasets/GBT_feb_1.00_final.pickle', scl_s='ns')
# Out:
# sqrt(sum(X^2)) in ns: 40.5349438325
# signal of Delta in ns
#  1.08509303322 ; the fit value of Delta 3.79285055576e-08
# len of der array:
#  100000
# mean of resulted sigma (ns):
#  49.7194552561 ; its std: 6.5086107832
# sf(real_Delta): 3.09569784883
# 1_sigma
#  49.3058802569 ns
# 2_sigma 101.071508152 ns
# 3_sigma 157.974397208 ns
# 1-sigma of Delta: 1.72344517575e-06
# derived from delta distribution ----------------------------------------------:
# 1-sigma: 1.23720202307e-06 in ns: 35.3949958266 1-sigma ul: 1.27433793025e-06 in ns: 36.4574134876
# 2-sigma: 2.49550447144e-06 in ns: 71.3936517278 2-sigma ul: 2.51871600077e-06 in ns: 72.0577081781
# delta mu: -2.84743931743e-10 std: 1.24099380162e-06

# %% [markdown]
# #Additional illustrations:

# %%
my_data=data_GBT

base_mjd=my_data['base_mjd']
par_dict=my_data['best_parameters']
par_dict['base_mjd']=base_mjd

p_period = my_data['f0']**(-1)
pb_i = par_dict['pb_i']
pb_o = par_dict['pb_o']
phi_i=(2.0*math.pi)/pb_i
phi_o=(2.0*math.pi)/pb_o
tasc_i = par_dict["tasc_i"]
tasc_o = par_dict["tasc_o"]

limiit=10000
c = abs(my_data['residuals']/my_data['phase_uncerts'])<limiit
new_phase = np.array(my_data['residuals'][c], dtype=np.float64)
new_times = np.array(my_data['times'][c], dtype=np.float64)+base_mjd
new_unc = np.array(my_data['phase_uncerts'][c], dtype=np.float64)

deltaa=my_data['best_parameters']['delta']

print 'size of residuals array:', len(new_phase)
print 'telescopes:', my_data['telescope_list']
print 'base mjd:', base_mjd
print 'pulsar period:', p_period
print 'last date:', np.amax(new_times), '...its year:', rd.day_to_year(np.amax(new_times))
print 'biggest residual:', np.amax(new_phase)
print 'delta:', deltaa
# Out:
# size of residuals array: 18487
# telescopes: ['GBT_1400']
# base mjd: 55920
# pulsar period: 0.00273258859009
# last date: 57866.917495 ...its year: 2017.30998582
# biggest residual: 0.00363879278302
# delta: 3.79287836503e-08

# %%
import read_data as rd
import arrow_plot as ap

gbt=rd.tel_transform(my_data,'GBT_1400')
#ao1400=rd.tel_transform(my_data,'AO_1400')
#wsrt1400=rd.tel_transform(my_data,'WSRT_1400')

name=['GBT_1400']
color=['g']

rd.plot_res(my_data, new_times, new_phase, new_unc, name, color)
plt.figtext(0.13, 0.15, '12-01-2017 data', fontsize=20, color='r')
# Out:
# (55920.0, 57930.0)
# (2011.9795067660527, 2017.4826998500996)
# /usr/lib/python2.7/dist-packages/matplotlib/lines.py:1106: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markerfacecolor != fc:

# %%
#all_emac1=np.array(new_phase/new_unc, dtype=np.float64)
gbt_emac1=np.array(gbt.phase/gbt.unc, dtype=np.float64)
#ao1400_emac1=np.array(ao1400.phase/ao1400.unc, dtype=np.float64)
#wsrt1400_emac1=np.array(wsrt1400.phase/wsrt1400.unc, dtype=np.float64)


gbt_efac1=rd.fit_single_plot(gbt_emac1, 'Green Bank', 'darkgreen', 6)

plt.gcf().set_size_inches(7.5,5)
#plt.savefig('25082017_efacs.pdf')

# %% [markdown]
# ##Do additional fit (deriavtives):

# %%
better_phase=ap.der_fit(my_data,new_phase,new_unc)
diff=new_phase-better_phase

delta_only=ap.der_of_par(my_data,'delta',new_unc)

# %% [markdown]
# ##Arrow plot

# %%
scl=p_period*1e9#ns

bet_data=ap.draw_plot(par_dict, 4, new_times, better_phase*scl, new_unc*scl)
plt.title("Data 2017-12-01 better phase")

# %%
import read_data as rd

rd.plot_hex(par_dict,new_times,delta_only*scl*deltaa, 40)
plt.title(r'Signature of $\Delta$=%3.2f e-6'%(deltaa*1e6))

# %%
rd.plot_res(my_data, new_times, delta_only*deltaa, new_unc*1e-15, name, color)
# Out:
# (55920.0, 57930.0)
# (2011.9795067660527, 2017.4826998500996)

# %%
res_delta=ap.draw_plot(par_dict, 4, new_times, delta_only*deltaa*scl, new_unc*scl*1e-12, color='red')
plt.title(r'Signature of New $\Delta$')

print res_delta
# Out:
# 1.11317009841
