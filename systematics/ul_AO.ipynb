# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import scipy.linalg
import matplotlib.pyplot as plt
from collections import namedtuple
from pylab import rcParams
rcParams['savefig.dpi'] = 144
import pickle
from astropy.io import fits
import os, sys, math, time
import math
from scipy.stats import norm
import matplotlib.mlab as mlab
from scipy import stats
from scipy.stats import kstest
from scipy.stats import norm
from matplotlib.font_manager import FontProperties

import read_data as rd
import arrow_plot as ap

# %% [markdown]
# #Arecibo:

# %%
data_AO=pickle.load(open('../../../datasets/systematics-package-AO-20171220.pickle', 'rb'))
#ap.der_unc(data_lowfreq)

# %%
ar_newton=ap.draw_ar_plot_from_data(data_AO, 4, scl_s='ns')
plt.title('Arecibo')

# %%
ap.der_unc(data_AO)
# Out:
# 0 DM_0001 0.00159125246787 +/- 0.0231188307182 -0.0688292797876 sigma
# 1 DM_0002 1.02752755042 +/- 0.0257891968955 -1.06740626833 sigma
# 2 DM_0003 1.99674147179 +/- 0.0376517045262 0.0865439759308 sigma
# 3 DM_0004 3.02673326152 +/- 0.0125052045286 -2.1377708348 sigma
# 4 FD1 3.99974381981 +/- 0.00185908216731 0.137799281995 sigma
# 5 FD2 5.00106124966 +/- 0.00861347385324 -0.123208090284 sigma
# 6 FD3 5.99815193228 +/- 0.0168467782382 0.109698584023 sigma
# 7 FD4 7.00116692254 +/- 0.0118258847911 -0.0986752841481 sigma
# 8 IPM_0000 10.9949210617 +/- 7.53320317538 -0.397562762076 sigma
# 9 IPM_0001 -116.568411403 +/- 189.408868991 0.662948953087 sigma
# 10 IPM_0002 -348.779600943 +/- 186.259875028 1.92623129855 sigma
# 11 IPM_0003 -24.1202253837 +/- 403.722565844 0.086990989246 sigma
# 12 IPM_0004 -1.78407198272 +/- 13.4293907707 1.02641081923 sigma
# 13 acosi_i 1.49010003176 +/- 0.000273154099865 -1.77186574937 sigma
# 14 acosi_o 91.4032656533 +/- 0.0184703143618 -1.85030746722 sigma
# 15 asini_i 1.21752672477 +/- 3.90183295059e-07 -3.33262874998 sigma
# 16 asini_o 74.6727114074 +/- 1.8134162898e-05 -3.90838039051 sigma
# 17 d_DECJ 12.9999903202 +/- 3.66320264189e-06 2.64244871253 sigma
# 18 d_PMDEC 13.9999999943 +/- 1.7530530528e-09 3.23229044722 sigma
# 19 d_PMRA 15.0000000021 +/- 4.76942972802e-10 -4.41499715052 sigma
# 20 d_PX 9.87679766404 +/- 15.7819734462 0.387987114338 sigma
# 21 d_RAJ 17.0000019875 +/- 8.49151817654e-07 -2.34060758669 sigma
# 22 dbeta 0.00750009760793 +/- 0.0752591957827 -0.108698813123 sigma
# 23 delta 7.6303856859e-08 +/- 2.65345271458e-07 -3.96722220304 sigma
# 24 delta_lan 9.24273155976e-06 +/- 1.07714754369e-06 -3.59268239904 sigma
# 25 dgamma -0.0204998337163 +/- 0.0379834342508 0.540486642028 sigma
# 26 eps1_i 0.000687058670713 +/- 3.02052177536e-07 3.59820611835 sigma
# 27 eps1_o 0.0351862621986 +/- 6.92554820227e-08 -3.85723745611 sigma
# 28 eps2_i -9.1339052073e-05 +/- 2.29377437147e-08 -2.54854003812 sigma
# 29 eps2_o -0.00346208650062 +/- 2.30248071637e-07 -3.86391610774 sigma
# 30 f0 18.0000000091 +/- 5.28247948565e-09 -1.72087348886 sigma
# 31 f1 19.0 +/- 5.17765951434e-21 1.86157414743 sigma
# 32 pb_i 1.62939720884 +/- 9.97202407586e-07 -3.44095056191 sigma
# 33 pb_o 327.257559579 +/- 0.000157848104555 -3.86648101144 sigma
# 34 phase 20.0002565248 +/- 0.000247350236947 -1.03709120021 sigma
# 35 q_i 0.137413862862 +/- 6.23794882357e-06 -0.710054081078 sigma
# 36 tasc_i 0.407716967253 +/- 9.61689550317e-08 -3.02704421496 sigma
# 37 tasc_o 313.93583331 +/- 0.000157764334461 -3.86357465943 sigma

# %% [markdown]
# ###Arrow length investigation:

# %%
my_ul=ap.upper_limit(data_AO, my_pickle='../../../datasets/AO_1.00_final.pickle', scl_s='ns')
plt.title('Arecibo')
# Out:
# sqrt(sum(X^2)) in ns: 58.0836370161
# signal of Delta in ns
#  26.1762280769 ; the fit value of Delta -9.76379795539e-07
# len of der array:
#  100000
# mean of resulted sigma (ns):
#  60.1961364048 ; its std: 12.4214686528
# sf(real_Delta):
#  2.05324567886
# 1_sigma
#  59.0077818015 ns
# 2_sigma 125.334736715 ns
# 3_sigma 204.704449673 ns
# 1-sigma upper limit on Delta: -2.20100488739e-06

# %% [markdown]
# #Additional illustrations:

# %%
my_data=data_AO

base_mjd=my_data['base_mjd']
par_dict=my_data['best_parameters']
par_dict['base_mjd']=base_mjd

p_period = my_data['f0']**(-1)
pb_i = par_dict['pb_i']
pb_o = par_dict['pb_o']
phi_i=(2.0*math.pi)/pb_i
phi_o=(2.0*math.pi)/pb_o
tasc_i = par_dict["tasc_i"]
tasc_o = par_dict["tasc_o"]

limiit=10000
c = abs(my_data['residuals']/my_data['phase_uncerts'])<limiit
new_phase = np.array(my_data['residuals'][c], dtype=np.float64)
new_times = np.array(my_data['times'][c], dtype=np.float64)+base_mjd
new_unc = np.array(my_data['phase_uncerts'][c], dtype=np.float64)

deltaa=my_data['best_parameters']['delta']

print 'size of residuals array:', len(new_phase)
print 'telescopes:', my_data['telescope_list']
print 'base mjd:', base_mjd
print 'pulsar period:', p_period
print 'last date:', np.amax(new_times), '...its year:', rd.day_to_year(np.amax(new_times))
print 'biggest residual:', np.amax(new_phase)
print 'delta:', deltaa
# Out:
# size of residuals array: 5355
# telescopes: ['AO_1400']
# base mjd: 55920
# pulsar period: 0.00273258859009
# last date: 57832.8773217 ...its year: 2017.21678699
# biggest residual: 0.00288267154247
# delta: -9.76379795539e-07

# %%
import read_data as rd
import arrow_plot as ap

#gbt=rd.tel_transform(my_data,'GBT_1400')
ao1400=rd.tel_transform(my_data,'AO_1400')
#wsrt1400=rd.tel_transform(my_data,'WSRT_1400')

name=['AO_1400']
color=['b']

rd.plot_res(my_data, new_times, new_phase, new_unc, name, color)
plt.figtext(0.13, 0.15, '12-01-2017 data', fontsize=20, color='r')
# Out:
# (55920.0, 57930.0)
# (2011.9795067660527, 2017.4826998500996)
# /usr/lib/python2.7/dist-packages/matplotlib/lines.py:1082: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markeredgecolor != ec:
# /usr/lib/python2.7/dist-packages/matplotlib/lines.py:1106: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markerfacecolor != fc:

# %%
ao1400_emac1=np.array(ao1400.phase/ao1400.unc, dtype=np.float64)

ao_efac1=rd.fit_single_plot(ao1400_emac1, 'Arecibo 1400 MHz', 'dodgerblue', 6)

plt.gcf().set_size_inches(7.5,5)
#plt.savefig('25082017_efacs.pdf')

# %% [markdown]
# ##Do additional fit (deriavtives):

# %%
better_phase=ap.der_fit(my_data,new_phase,new_unc)
diff=new_phase-better_phase

delta_only=ap.der_of_par(my_data,'delta',new_unc)

# %% [markdown]
# ##Arrow plot

# %%
scl=p_period*1e9#ns

bet_data=ap.draw_plot(par_dict, 4, new_times, better_phase*scl, new_unc*scl)
plt.title("Data 2017-12-01 better phase")

# %%
import read_data as rd

rd.plot_hex(par_dict,new_times,delta_only*scl*deltaa, 40)
plt.title(r'Signature of $\Delta$=%3.2f e-6'%(deltaa*1e6))

# %%
rd.plot_res(my_data, new_times, delta_only*deltaa, new_unc*1e-15, name, color)
# Out:
# (55920.0, 57930.0)
# (2011.9795067660527, 2017.4826998500996)

# %%
res_delta=ap.draw_plot(par_dict, 4, new_times, delta_only*deltaa*scl, new_unc*scl*1e-12, color='red')
plt.title(r'Signature of New $\Delta$')

print res_delta
# Out:
# 26.1762280769
