# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import scipy.linalg
import matplotlib.pyplot as plt
from collections import namedtuple
from pylab import rcParams
rcParams['savefig.dpi'] = 144
import pickle
from astropy.io import fits
import os, sys, math, time
import math
from scipy.stats import norm
import matplotlib.mlab as mlab
from scipy import stats
from scipy.stats import kstest
from scipy.stats import norm
from matplotlib.font_manager import FontProperties

import read_data as rd
import arrow_plot as ap

# %% [markdown]
# #Westerbork:

# %%
data_WSRT=pickle.load(open('../../../datasets/systematics-package-WSRT-20180227.pickle', 'rb'))
#ap.der_unc(data_lowfreq)

# %%
ar_wsrt=ap.draw_ar_plot_from_data(data_WSRT, 4, scl_s='ns')
plt.title('Westerbork')

# %%
ap.der_unc(data_WSRT)
# Out:
# 0 DM_0001 0 0.00761830971734 +/- 0.184558246549 -0.0412786199468 sigma
# 1 FD1 0 -0.0312810311042 +/- 1.78060012883 0.0175676900152 sigma
# 2 FD2 0 0.145367402788 +/- 8.42287629116 -0.017258641557 sigma
# 3 FD3 0 -0.299208065831 +/- 17.6375536849 0.0169642610974 sigma
# 4 FD4 0 0.230223337957 +/- 13.7955617906 -0.0166882176639 sigma
# 5 IPM_0000 0 -11.3471776897 +/- 46.7793568557 0.242568056775 sigma
# 6 IPM_0001 0 -10.5045769846 +/- 92.0720515311 0.114090832233 sigma
# 7 acosi_i 1.49023414504 1.49012468644 +/- 0.00111107399918 0.0985160356081 sigma
# 8 acosi_o 91.425753043 91.4236970939 +/- 0.0703203958226 0.0292368829007 sigma
# 9 asini_i 1.2175239907 1.21752214097 +/- 2.98862175218e-06 0.618922903136 sigma
# 10 asini_o 74.6730792751 74.6732940422 +/- 0.0003808166486 -0.563964678793 sigma
# 11 d_DECJ 0 -0.00341940747921 +/- 0.00541336047334 0.631660776343 sigma
# 12 d_PMDEC 0 -5.32190071869e-06 +/- 8.3784430503e-06 0.635189698938 sigma
# 13 d_PMRA 0 1.46958093127e-06 +/- 2.29650102545e-06 -0.639921739631 sigma
# 14 d_PX 0 565.349857306 +/- 1868.60664355 -0.302551561216 sigma
# 15 d_RAJ 0 0.000709203592499 +/- 0.00112762825395 -0.628933861861 sigma
# 16 dbeta -0.000329087903461 0.808728067393 +/- 0.944763106455 -0.856359811014 sigma
# 17 delta -2.13422497099e-06 -2.42094294254e-06 +/- 1.34293335444e-06 0.213501266167 sigma
# 18 delta_lan 1.8038857949e-05 2.20288324735e-05 +/- 1.6767021168e-05 -0.237965616227 sigma
# 19 dgamma 1.16296548084e-05 0.373530242248 +/- 0.483897015489 -0.771896913264 sigma
# 20 eps1_i 0.000689141117221 0.000690371648555 +/- 2.12848731153e-06 -0.578124815521 sigma
# 21 eps1_o 0.0351855656748 0.0351853691773 +/- 4.31378365725e-07 0.455510906535 sigma
# 22 eps2_i -9.13850272208e-05 -9.13983585228e-05 +/- 1.49146760727e-07 0.089383784801 sigma
# 23 eps2_o -0.00346403774543 -0.00346451926303 +/- 1.3090903178e-06 0.367826113599 sigma
# 24 f0 0 2.28428014947e-08 +/- 4.08706721828e-08 -0.558904472932 sigma
# 25 f1 0 -1.68073089125e-17 +/- 4.0348533737e-17 0.416553152143 sigma
# 26 pb_i 1.62939001083 1.62938576579 +/- 7.25919272078e-06 0.584781371887 sigma
# 27 pb_o 327.256341297 327.256067571 +/- 0.000870956784866 0.314282023626 sigma
# 28 phase 0 -0.00695162172392 +/- 0.141282917144 0.0492035545729 sigma
# 29 q_i 0.137301474518 0.137139504318 +/- 0.000263644050927 0.614351809984 sigma
# 30 tasc_i 0.407716306448 0.407715870831 +/- 7.16720554142e-07 0.607791583486 sigma
# 31 tasc_o 313.934440579 313.934092612 +/- 0.000902363189298 0.385616953865 sigma

# %% [markdown]
# ###Arrow length investigation:

# %%
my_pickle='../../../datasets/WSRT_feb_1.00_final.pickle'

with open('%s'%my_pickle, 'rb') as f:
    array_pickle = pickle.load(f)

# %%
array_pickle
# Out:
# {'delta_values': array([ 0.,  0.,  0., ...,  0.,  0.,  0.]),
#  'der_coeff': array([None, None, None, ..., None, None, None], dtype=object),
#  'init_coeff': array([<Coefficients length 25>, <Coefficients length 25>,
#         <Coefficients length 25>, ..., <Coefficients length 25>,
#         <Coefficients length 25>, <Coefficients length 25>], dtype=object),
#  'sigma': 1.0}

# %%
my_ul=ap.upper_limit(data_WSRT, my_pickle='../../../datasets/WSRT_feb_1.00_final.pickle', scl_s='ns')
plt.title('Green Bank')
# Out:
# sqrt(sum(X^2)) in ns: 59.7899601314
# signal of Delta in ns
#  47.0549191196 ; the fit value of Delta -2.13422497099e-06
# len of der array:
#  100000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-272c3f2333b7> in <module>()
# ----> 1 my_ul=ap.upper_limit(data_WSRT, my_pickle='../../../datasets/WSRT_feb_1.00_final.pickle', scl_s='ns')
#       2 plt.title('Green Bank')
#
# /home/nina/scientific_study/triple_system/github_rep/triplesystem/systematics/arrow_plot.pyc in upper_limit(my_data, my_pickle, scl_s, scl)
#     712
#     713     for i in range(0,len(my_der)):
# --> 714         F=sqr_lengths(my_der[i])*scl
#     715         F_list.append(F)
#     716         sig=(my_sigma*real_F)/F
#
# /home/nina/scientific_study/triple_system/github_rep/triplesystem/systematics/arrow_plot.pyc in sqr_lengths(coeff)
#     559 #------------------------------------------
#     560 def sqr_lengths(coeff):
# --> 561     my_coeff=np.concatenate((coeff.U, coeff.V), axis=0)
#     562     res=np.sqrt(np.sum(my_coeff**2.0)/(len(my_coeff)))
#     563     return res
#
# AttributeError: 'NoneType' object has no attribute 'U'

# %% [markdown]
# #Additional illustrations:

# %%
my_data=data_WSRT

base_mjd=my_data['base_mjd']
par_dict=my_data['best_parameters']
par_dict['base_mjd']=base_mjd

p_period = my_data['f0']**(-1)
pb_i = par_dict['pb_i']
pb_o = par_dict['pb_o']
phi_i=(2.0*math.pi)/pb_i
phi_o=(2.0*math.pi)/pb_o
tasc_i = par_dict["tasc_i"]
tasc_o = par_dict["tasc_o"]

limiit=10000
c = abs(my_data['residuals']/my_data['phase_uncerts'])<limiit
new_phase = np.array(my_data['residuals'][c], dtype=np.float64)
new_times = np.array(my_data['times'][c], dtype=np.float64)+base_mjd
new_unc = np.array(my_data['phase_uncerts'][c], dtype=np.float64)

deltaa=my_data['best_parameters']['delta']

print 'size of residuals array:', len(new_phase)
print 'telescopes:', my_data['telescope_list']
print 'base mjd:', base_mjd
print 'pulsar period:', p_period
print 'last date:', np.amax(new_times), '...its year:', rd.day_to_year(np.amax(new_times))
print 'biggest residual:', np.amax(new_phase)
print 'delta:', deltaa
# Out:
# size of residuals array: 3268
# telescopes: ['WSRT_1400']
# base mjd: 55920
# pulsar period: 0.00273258859009
# last date: 56496.1859751 ...its year: 2013.55705038
# biggest residual: 0.00279305782169
# delta: -2.13422497099e-06

# %%
import read_data as rd
import arrow_plot as ap

#gbt=rd.tel_transform(my_data,'GBT_1400')
#ao1400=rd.tel_transform(my_data,'AO_1400')
wsrt1400=rd.tel_transform(my_data,'WSRT_1400')

name=['WSRT_1400']
color=['y']

rd.plot_res(my_data, new_times, new_phase, new_unc, name, color)
plt.figtext(0.13, 0.15, '12-01-2017 data', fontsize=20, color='r')
# Out:
# (55920.0, 57930.0)
# (2011.9795067660527, 2017.4826998500996)
# /usr/lib/python2.7/dist-packages/matplotlib/lines.py:1082: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markeredgecolor != ec:
# /usr/lib/python2.7/dist-packages/matplotlib/lines.py:1106: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markerfacecolor != fc:

# %%
#all_emac1=np.array(new_phase/new_unc, dtype=np.float64)
#gbt_emac1=np.array(gbt.phase/gbt.unc, dtype=np.float64)
#ao1400_emac1=np.array(ao1400.phase/ao1400.unc, dtype=np.float64)
wsrt1400_emac1=np.array(wsrt1400.phase/wsrt1400.unc, dtype=np.float64)


wsrt_efac1=rd.fit_single_plot(wsrt1400_emac1, 'Green Bank', 'orange', 6)

plt.gcf().set_size_inches(7.5,5)
#plt.savefig('25082017_efacs.pdf')

# %% [markdown]
# ##Do additional fit (deriavtives):

# %%
better_phase=ap.der_fit(my_data,new_phase,new_unc)
diff=new_phase-better_phase

delta_only=ap.der_of_par(my_data,'delta',new_unc)

# %% [markdown]
# ##Arrow plot

# %%
scl=p_period*1e9#ns

bet_data=ap.draw_plot(par_dict, 4, new_times, better_phase*scl, new_unc*scl)
plt.title("Data 2017-12-01 better phase")

# %%
import read_data as rd

rd.plot_hex(par_dict,new_times,delta_only*scl*deltaa, 40)
plt.title(r'Signature of $\Delta$=%3.2f e-6'%(deltaa*1e6))

# %%
rd.plot_res(my_data, new_times, delta_only*deltaa, new_unc*1e-15, name, color)
# Out:
# (55920.0, 57930.0)
# (2011.9795067660527, 2017.4826998500996)

# %%
res_delta=ap.draw_plot(par_dict, 4, new_times, delta_only*deltaa*scl, new_unc*scl*1e-12, color='red')
plt.title(r'Signature of New $\Delta$')

print res_delta
# Out:
# 41.1044870872
