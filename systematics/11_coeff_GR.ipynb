# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import scipy.linalg
import matplotlib.pyplot as plt
from collections import namedtuple
from pylab import rcParams
rcParams['savefig.dpi'] = 144
import pickle
from astropy.io import fits
import os, sys, math, time
import math
from scipy.stats import norm
import matplotlib.mlab as mlab
from scipy import stats
from scipy.stats import kstest
from scipy.stats import norm
from matplotlib.font_manager import FontProperties

import read_data as rd
import arrow_plot as ap

# %% [markdown]
# #Primary:

# %%
data_primary=pickle.load(open('../../../datasets/systematics-package-GR-20171220.pickle', 'rb'))

# %%
data_primary.keys()
# Out:
# ['f0',
#  'derivatives',
#  'telescope_list',
#  'base_mjd',
#  'best_parameters',
#  'linear_parameters',
#  'orbit',
#  'times',
#  'efacs',
#  'fitter_params',
#  'residuals',
#  'toa_info',
#  'telescopes',
#  'phase_uncerts']

# %%
my_data=data_primary

base_mjd=my_data['base_mjd']
par_dict=my_data['best_parameters']
par_dict['base_mjd']=base_mjd

p_period = my_data['f0']**(-1)
pb_i = par_dict['pb_i']
pb_o = par_dict['pb_o']
phi_i=(2.0*math.pi)/pb_i
phi_o=(2.0*math.pi)/pb_o
tasc_i = par_dict["tasc_i"]
tasc_o = par_dict["tasc_o"]

limiit=10000
c = abs(my_data['residuals']/my_data['phase_uncerts'])<limiit
new_phase = np.array(my_data['residuals'][c], dtype=np.float64)
new_times = np.array(my_data['times'][c], dtype=np.float64)+base_mjd
new_unc = np.array(my_data['phase_uncerts'][c], dtype=np.float64)

#deltaa=my_data['best_parameters']['delta']

print 'base mjd:', base_mjd
print 'pulsar period:', p_period
print 'last date:', np.amax(new_times), '...its year:', rd.day_to_year(np.amax(new_times))
print 'biggest residual:', np.amax(new_phase)
#print 'delta:', deltaa
# Out:
# base mjd: 55920
# pulsar period: 0.00273258859009
# last date: 57866.917495 ...its year: 2017.30998582
# biggest residual: 0.00367041677237

# %%
print my_data['f0']
# Out:
# 365.953368768

# %%
def der_fit_new(data,phase,unc, sequence, res_out=False):
    """Does additional fit of residuals (phase) for all linear parameters using 'derivatives' (responce
       of residuals to each parameter) provided by timing fit.
       Returns corrected array of residuals
data -- data package ectracted form pickle (contains phase, mjd, unc, all fit parameters and corresponing
derivatives
phase, unc -- residuals you want to refit and its uncertaities.
"""


    d=np.array(data['derivatives'])[np.newaxis][0]
    cols= sorted(sequence)
    #del cols[cols.index('delta')]
    
    A = np.array([d[c] for c in cols]).T
    b=phase
    r = ap.lstsq_with_errors(A, b, unc)
    better_phase=b-np.dot(A,r.x)
    if res_out is False:
        return better_phase
    else:
        return better_phase, A, r.x, cols

# %%
delta_phase=my_data['derivatives']['delta']*-1
ap.draw_plot(par_dict, 4, new_times, delta_phase, new_unc)
plt.title('delta')

delta_coeff=ap.ar_coeff(par_dict, 4, new_times, delta_phase, new_unc, chol=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-890f7cda60bf> in <module>()
# ----> 1 delta_phase=my_data['derivatives']['delta']*-1
#       2 ap.draw_plot(par_dict, 4, new_times, delta_phase, new_unc)
#       3 plt.title('delta')
#       4
#       5 delta_coeff=ap.ar_coeff(par_dict, 4, new_times, delta_phase, new_unc, chol=True)
#
# KeyError: 'delta'

# %%
delta_U, delta_V, delta_M=ap.arrow_extract(delta_coeff,-1,1)
print delta_U, delta_V, delta_M
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-048e029b25bb> in <module>()
# ----> 1 delta_U, delta_V, delta_M=ap.arrow_extract(delta_coeff,-1,1)
#       2 print delta_U, delta_V, delta_M
#
# NameError: name 'delta_coeff' is not defined

# %% [markdown]
# #Signature investigation

# %%
my_coeff = ap.Coefficients([-1], [1], [310000], [350000])

my_phase=ap.fake_arrow_array(my_coeff,par_dict,new_times)

ap.draw_plot(par_dict, 4, new_times, my_phase, new_unc)
# Out:
# 467546.78910243721

# %%
sequence=[ 'asini_i', 'eps2_i', 'delta_lan', 'eps2_o', 'q_i', 'asini_o',
           'acosi_i', 'acosi_o', 'eps1_i', 'tasc_o', 'tasc_i',
          'pb_o', 'pb_i', 'eps1_o']

# %%
der_my_phase, A, c, cols =der_fit_new(my_data,my_phase, new_unc, sequence=sequence, res_out=True)

par_der=np.zeros((len(c),len(A[:,1])))
its_rms=np.zeros((len(c)))

val_par=zip(cols,c)


for i in range(0,len(c)):
    par_der[i,:]=c[i]*A[:,i]
    its_rms[i]=np.std(par_der[i,:])
    
my_tuple=zip(its_rms, cols, par_der)
new_tuple=sorted(my_tuple)[::-1]

#print new_tuple


ap.draw_plot(par_dict, 4, new_times, der_my_phase, new_unc)
plt.title('residuals from the fit')

# %%
#val_par('pb_i')

# %%
for rms, name, der in new_tuple:
    plt.figure()
    ap.draw_plot(par_dict, 4, new_times, der, new_unc, lentext=True)
    plt.title(name)
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
ap.der_unc(data_primary, my_phase)
# Out:
# 0 DM_0001 0 168.526255958 +/- 0.00813297123889 -20721.3638175 sigma
# 1 DM_0002 0 -304.056914409 +/- 0.00972774226667 31256.67869 sigma
# 2 DM_0003 0 180.340502674 +/- 0.0105618836282 -17074.6534445 sigma
# 3 DM_0004 0 -84.9157209698 +/- 0.0086570336148 9808.87042239 sigma
# 4 FD1 0 2.20409183963 +/- 0.00130073471316 -1694.49759227 sigma
# 5 FD2 0 -10.4649124685 +/- 0.00584642367545 1789.96820098 sigma
# 6 FD3 0 18.6628750678 +/- 0.011062135446 -1687.09515074 sigma
# 7 FD4 0 -11.7350337654 +/- 0.00750371000026 1563.89756067 sigma
# 8 IPM_0000 0 -158225.942284 +/- 6.41618640712 24660.434134 sigma
# 9 IPM_0001 0 -133710.989727 +/- 16.9093370902 7907.52405103 sigma
# 10 IPM_0002 0 380345.502037 +/- 24.4665372219 -15545.5387326 sigma
# 11 IPM_0003 0 -513796.005392 +/- 33.6131058646 15285.5855529 sigma
# 12 IPM_0004 0 -525042.757008 +/- 10.4090475521 50440.9989849 sigma
# 13 acosi_i 1.48955415134 -21.8711750097 +/- 0.000186072202949 125546.582406 sigma
# 14 acosi_o 91.361037238 -1480.5335401 +/- 0.0121275210814 129613.840025 sigma
# 15 asini_i 1.21752527797 1.23547238431 +/- 2.73004575345e-07 -65739.2144849 sigma
# 16 asini_o 74.672633135 75.1874326608 +/- 1.31701795474e-05 -39088.2693704 sigma
# 17 d_DECJ 0 -0.0457133297487 +/- 1.85062370839e-06 24701.5800897 sigma
# 18 d_PMDEC 0 2.80866859987e-05 +/- 1.13990633252e-09 -24639.4683471 sigma
# 19 d_PMRA 0 -5.71083090881e-06 +/- 3.12183123614e-10 18293.2083025 sigma
# 20 d_PX 0 51011.698323 +/- 6.68353852956 -7632.43872949 sigma
# 21 d_RAJ 0 0.0114409909393 +/- 4.26728838684e-07 -26810.9157435 sigma
# 22 dbeta 0.00152960556651 -6074.98307538 +/- 0.0510753790333 118941.547179 sigma
# 23 delta -1.08530037771e-06 0.00606966233781 +/- 1.94498805126e-07 -31212.2618658 sigma
# 24 delta_lan 2.19913601188e-06 -0.038038458625 +/- 7.77293469747e-07 48939.8910985 sigma
# 25 dgamma -1.33795394689e-05 -2754.25901195 +/- 0.0265472850002 103749.178063 sigma
# 26 eps1_i 0.000688262063085 -0.0124739693069 +/- 2.12388175902e-07 61972.5241959 sigma
# 27 eps1_o 0.0351859658148 0.0371442807185 +/- 5.02993803597e-08 -38933.1814754 sigma
# 28 eps2_i -9.13954168319e-05 0.000433080950448 +/- 1.84126396692e-08 -28484.5832375 sigma
# 29 eps2_o -0.00346306969577 0.00301245739401 +/- 1.67308551556e-07 -38704.1010729 sigma
# 30 f0 0 -0.000440893560491 +/- 3.69382385771e-09 119359.660199 sigma
# 31 f1 0 -7.56921499797e-18 +/- 3.28736810223e-21 2302.51519227 sigma
# 32 j_GBT_1400 0 0.0854878909928 +/- 4.57145367787e-06 -18700.3734516 sigma
# 33 j_WSRT_1400 0 -0.0525412465853 +/- 9.94730493973e-06 5281.95796788 sigma
# 34 pb_i 1.62939341669 1.67411494018 +/- 7.02518188162e-07 -63658.8834828 sigma
# 35 pb_o 327.256885572 331.706765942 +/- 0.000114726110306 -38786.9889278 sigma
# 36 phase 0 9.24021936954 +/- 0.000173511227541 -53254.3023325 sigma
# 37 q_i 0.137405570412 -0.078997197329 +/- 4.29522282645e-06 50382.1981967 sigma
# 38 tasc_i 0.40771664137 0.412190134816 +/- 6.76005122847e-08 -66175.4370646 sigma
# 39 tasc_o 313.935159977 318.3909999 +/- 0.00011467846144 -38855.0724114 sigma

# %%
#for par in my_data['derivatives'].keys():
#    plt.figure()
#    der_par=ap.der_of_par(my_data, par, new_unc)
#    ap.draw_plot(par_dict, 4, new_times, der_par, new_unc)
#    plt.title(par)

# %%
par_list= my_data['derivatives'].keys()

# %%
 'phase',  'j_GBT_1400', 'j_WSRT_1400']

# %%
ap.der_unc(data_primary)
# Out:
# 0 DM_0001 0 0.000175711811736 +/- 0.00813297123889 -0.0216048731238 sigma
# 1 DM_0002 0 0.000911611018171 +/- 0.00972774226667 -0.0937124970194 sigma
# 2 DM_0003 0 -0.000708281805239 +/- 0.0105618836282 0.0670601788629 sigma
# 3 DM_0004 0 -0.00158169820183 +/- 0.0086570336148 0.182706718284 sigma
# 4 FD1 0 2.43186526016e-05 +/- 0.00130073471316 -0.0186960894912 sigma
# 5 FD2 0 -0.000103873570289 +/- 0.00584642367545 0.0177670275121 sigma
# 6 FD3 0 0.000182551130704 +/- 0.011062135446 -0.0165023409445 sigma
# 7 FD4 0 -0.000114298326488 +/- 0.00750371000026 0.0152322419822 sigma
# 8 IPM_0000 0 0.276981294438 +/- 6.41618640712 -0.043169147039 sigma
# 9 IPM_0001 0 1.23781385765 +/- 16.9093370902 -0.0732029795759 sigma
# 10 IPM_0002 0 -0.725663482258 +/- 24.4665372219 0.0296594273099 sigma
# 11 IPM_0003 0 1.67393113515 +/- 33.6131058646 -0.0497999542767 sigma
# 12 IPM_0004 0 1.92892885285 +/- 10.4090475521 -0.185312714078 sigma
# 13 acosi_i 1.48955415134 1.48960737902 +/- 0.000186072202949 -0.286059265189 sigma
# 14 acosi_o 91.361037238 91.3639566655 +/- 0.0121275210814 -0.240727469706 sigma
# 15 asini_i 1.21752527797 1.21752534287 +/- 2.73004575345e-07 -0.237730773469 sigma
# 16 asini_o 74.672633135 74.6726376037 +/- 1.31701795474e-05 -0.339308104434 sigma
# 17 d_DECJ 0 1.07663444064e-06 +/- 1.85062370839e-06 -0.581768425293 sigma
# 18 d_PMDEC 0 5.48866184648e-11 +/- 1.13990633252e-09 -0.0481501127761 sigma
# 19 d_PMRA 0 -7.17176677255e-11 +/- 3.12183123614e-10 0.229729483436 sigma
# 20 d_PX 0 -1.19266119431 +/- 6.68353852956 0.178447567712 sigma
# 21 d_RAJ 0 -2.46466087788e-07 +/- 4.26728838684e-07 0.57757073215 sigma
# 22 dbeta 0.00152960556651 0.0102723615402 +/- 0.0510753790333 -0.171173589686 sigma
# 23 delta -1.08530037771e-06 -1.01519029971e-06 +/- 1.94498805126e-07 -0.360465340395 sigma
# 24 delta_lan 2.19913601188e-06 2.20744441302e-06 +/- 7.77293469747e-07 -0.0106888858162 sigma
# 25 dgamma -1.33795394689e-05 0.00768458385654 +/- 0.0265472850002 -0.289971776623 sigma
# 26 eps1_i 0.000688262063085 0.000688205343785 +/- 2.12388175902e-07 0.267054882363 sigma
# 27 eps1_o 0.0351859658148 0.0351859829577 +/- 5.02993803597e-08 -0.34081655886 sigma
# 28 eps2_i -9.13954168319e-05 -9.13849637639e-05 +/- 1.84126396692e-08 -0.567711538863 sigma
# 29 eps2_o -0.00346306969577 -0.00346301210769 +/- 1.67308551556e-07 -0.344202881856 sigma
# 30 f0 0 1.10319896684e-09 +/- 3.69382385771e-09 -0.29866041515 sigma
# 31 f1 0 2.98629525298e-22 +/- 3.28736810223e-21 -0.0908415230701 sigma
# 32 j_GBT_1400 0 1.32651440654e-07 +/- 4.57145367787e-06 -0.0290173432787 sigma
# 33 j_WSRT_1400 0 3.30161542319e-07 +/- 9.94730493973e-06 -0.0331910546947 sigma
# 34 pb_i 1.62939341669 1.62939360285 +/- 7.02518188162e-07 -0.264984662693 sigma
# 35 pb_o 327.256885572 327.256925068 +/- 0.000114726110306 -0.344265820115 sigma
# 36 phase 0 -3.05259631743e-05 +/- 0.000173511227541 0.17593076602 sigma
# 37 q_i 0.137405570412 0.13740532952 +/- 4.29522282645e-06 0.056083749846 sigma
# 38 tasc_i 0.40771664137 0.407716658064 +/- 6.76005122847e-08 -0.246961285121 sigma
# 39 tasc_o 313.935159977 313.935199468 +/- 0.00011467846144 -0.344367883599 sigma

# %% [markdown]
# ###Arrow length investigation:

# %%
my_ul=ap.upper_limit(data_primary, my_pickle='../../../datasets/primary_1.00_final.pickle', scl_s='ns')
plt.title('Primary')
# Out:
# sqrt(sum(X^2)) in ns: 19.1802152893
# signal of Delta in ns
#  33.1305494944 ; the fit value of Delta -1.08530037771e-06
# len of der array:
#  100000
# mean of resulted sigma (ns):
#  24.0852942669 ; its std: 3.19277069748
# sf(real_Delta): 0.531092006015
# 1_sigma
#  23.879997088 ns
# 2_sigma 48.9801889959 ns
# 3_sigma 76.6373943271 ns
# 1-sigma upper limit on Delta: -7.82268035235e-07

# %% [markdown]
# #Additional illustrations:

# %%
my_data=data_primary

base_mjd=my_data['base_mjd']
par_dict=my_data['best_parameters']
par_dict['base_mjd']=base_mjd

p_period = my_data['f0']**(-1)
pb_i = par_dict['pb_i']
pb_o = par_dict['pb_o']
phi_i=(2.0*math.pi)/pb_i
phi_o=(2.0*math.pi)/pb_o
tasc_i = par_dict["tasc_i"]
tasc_o = par_dict["tasc_o"]

limiit=10000
c = abs(my_data['residuals']/my_data['phase_uncerts'])<limiit
new_phase = np.array(my_data['residuals'][c], dtype=np.float64)
new_times = np.array(my_data['times'][c], dtype=np.float64)+base_mjd
new_unc = np.array(my_data['phase_uncerts'][c], dtype=np.float64)

deltaa=my_data['best_parameters']['delta']

print 'base mjd:', base_mjd
print 'pulsar period:', p_period
print 'last date:', np.amax(new_times), '...its year:', rd.day_to_year(np.amax(new_times))
print 'biggest residual:', np.amax(new_phase)
print 'delta:', deltaa
# Out:
# base mjd: 55920
# pulsar period: 0.00273258859009
# last date: 57866.917495 ...its year: 2017.30998582
# biggest residual: 0.00364899262786
# delta: -1.08530037771e-06

# %%
import read_data as rd
import arrow_plot as ap

gbt=rd.tel_transform(my_data,'GBT_1400')
ao1400=rd.tel_transform(my_data,'AO_1400')
wsrt1400=rd.tel_transform(my_data,'WSRT_1400')

name=['WSRT_1400','GBT_1400', 'AO_1400']
color=['y', 'g', 'b']

rd.plot_res(my_data, new_times, new_phase, new_unc, name, color)
plt.figtext(0.13, 0.15, '12-01-2017 data', fontsize=20, color='r')
# Out:
# (55920.0, 57930.0)
# (2011.9795067660527, 2017.4826998500996)
# /usr/lib/python2.7/dist-packages/matplotlib/lines.py:1082: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markeredgecolor != ec:
# /usr/lib/python2.7/dist-packages/matplotlib/lines.py:1106: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markerfacecolor != fc:

# %%
all_emac1=np.array(new_phase/new_unc, dtype=np.float64)
gbt_emac1=np.array(gbt.phase/gbt.unc, dtype=np.float64)
ao1400_emac1=np.array(ao1400.phase/ao1400.unc, dtype=np.float64)
wsrt1400_emac1=np.array(wsrt1400.phase/wsrt1400.unc, dtype=np.float64)

numplots=4
limm=6

rd.fit_plot(all_emac1, 1, 'All', 'grey', numplots, limm)
ao_efac1=rd.fit_plot(ao1400_emac1, 2, 'Arecibo 1400 MHz', 'dodgerblue', numplots, limm)
gbt_efac1=rd.fit_plot(gbt_emac1, 3, 'GBT', 'green', numplots, limm)
wsrt_efac1=rd.fit_plot(wsrt1400_emac1, 4, 'Westerbork 1400 MHz', 'orange', numplots, limm)

plt.gcf().set_size_inches(15,10)
#plt.savefig('25082017_efacs.pdf')

# %% [markdown]
# ##Do additional fit (deriavtives):

# %%
better_phase=ap.der_fit(my_data,new_phase,new_unc)
diff=new_phase-better_phase

delta_only=ap.der_of_par(my_data,'delta',new_unc)

# %% [markdown]
# ##Arrow plot

# %%
scl=p_period*1e9#ns

bet_data=ap.draw_plot(par_dict, 4, new_times, better_phase*scl, new_unc*scl)
plt.title("Primary better phase")

# %%
import read_data as rd

rd.plot_hex(par_dict,new_times,delta_only*scl*deltaa, 40)
plt.title(r'Signature of $\Delta$=%3.2f e-6'%(deltaa*1e6))

# %%
rd.plot_res(my_data, new_times, delta_only*deltaa, new_unc*1e-15, name, color)
plt.ylim(-0.2,0.2)
# Out:
# (55920.0, 57930.0)
# (2011.9795067660527, 2017.4826998500996)
# (-0.2, 0.2)

# %%
res_delta=ap.draw_plot(par_dict, 4, new_times, delta_only*deltaa*scl, new_unc*scl*1e-12, color='red')
plt.title(r'Signature of $\Delta$=-1.09e-6')

print res_delta
# Out:
# 33.1305494944
