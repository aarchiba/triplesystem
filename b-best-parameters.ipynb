# %%
# %load_ext autoreload

# %autoreload 2

# %%
import cPickle as pickle
from glob import glob
import os
import random
import numpy as np

import threebody

# %%
bpd = {}

# %%
bpd = threebody.load_best_parameter_database()

# %% [markdown]
# ### Update the database based on fitter results

# %%
d = pickle.load(open("fitter_params.pickle"))
F = threebody.Fitter(**d)
p = pickle.load(open("fitter_best_values.pickle"))
newp = F.best_parameters.copy()

newp.update(p)
old = -2*F.efac**2*(F.lnprob(F.best_parameters)+F.lnprior(F.best_parameters))
new = -2*F.efac**2*(F.lnprob(newp)+F.lnprior(newp))
print "existing best parameters:", old
print "best parameters from fitter:", new
# Out:
# existing best parameters: 33794.2325396
# best parameters from fitter: 33794.2325396

# %%
if new<old:
    bpd[frozenset(F.args.iteritems())] = newp
threebody.save_best_parameter_database(bpd)

# %% [markdown]
# ### Update the database by looking at the best results from an MCMC run

# %%
jobid = "69543"
job_dir = glob(os.path.join("emcee-chains",jobid+".*"))[0]

# %%
with open(os.path.join(job_dir,"fitter_params.pickle")) as f:
    fitter_params = pickle.load(f)
F = threebody.Fitter(**fitter_params)

# %%
best_so_far = np.load(os.path.join(job_dir,"best_so_far.npy"))
newp = F.best_parameters.copy()
for i,p in enumerate(F.parameters):
    newp[p] = best_so_far[i]

# %%
old = -2*F.efac**2*(F.lnprob(F.best_parameters)+F.lnprior(F.best_parameters))
new = -2*F.efac**2*(F.lnprob(newp)+F.lnprior(newp))
print "existing best parameters:", old
print "best parameters from MCMC:", new
# Out:
# existing best parameters: 33794.2325396
# best parameters from MCMC: 33797.3887062

# %%
if new<old:
    bpd[frozenset(F.args.iteritems())] = newp
threebody.save_best_parameter_database(bpd)

# %% [markdown]
# ### Update the database for a fitter by trying values for all known configurations

# %%
#d = pickle.load(open("fitter_params.pickle"))
#d = pickle.load(open("emcee-chains/32534.nimrod/fitter_params.pickle"))
#d = pickle.load(open("fake_toas_fitter.pickle"))
d = pickle.load(open("forecaster_params.pickle"))
#d['files'] = 'fake-uniform'
#d['kopeikin'] = True
#d['fit_pm'] = True
#d['fit_px'] = True

#d = pickle.load(open("sensitivity_params.pickle"))
#d = pickle.load(open("plot_params.pickle"))
#d = pickle.load(open("scratch_params.pickle"))
print d
F = threebody.Fitter(**d)
if "j_NCY1400" not in F.best_parameters:
    F.best_parameters["j_NCY1400"] = 0.25*2.7e-3
if "delta" not in F.best_parameters:
    F.best_parameters['delta'] = 0
try:
    old = -2*F.efac**2*(F.lnprob(F.best_parameters)+F.lnprior(F.best_parameters))
except KeyError:
    print "Missing best parameter values!"
    old = np.inf
print "existing best parameters:", old
best = old
best_p = F.best_parameters.copy()
itms = bpd.items()
random.shuffle(itms)
for k, p in itms: 
    newp = F.best_parameters.copy()
    newp.update(p)
    new = -2*F.efac**2*(F.lnprob(newp)+F.lnprior(newp))
    print "best parameters from database:", new
    if new<best:
        best = new
        best_p = newp
        if True:
            bpd[frozenset(F.args.iteritems())] = best_p
            threebody.save_best_parameter_database(bpd)
# Out:
# {'ppn_mode': 'heavysimple', 'tzrmjd_middle': False, 'priors': ('dbeta', 'dgamma'), 't2_astrometry': True, 'fit_pm': False, 'files': '0337+17-anne-2014-09-22', 'kopeikin': False, 'efac': (('AO1440', 1.45), ('GBT1500', 1.11), ('WSRT1400', 1.45)), 'parfile': '0337_tempo2_px_optical.par', 'fit_pos': True, 'fit_px': False}
# No handlers could be found for logger "threebody"
# Missing best parameter values!
# existing best parameters: inf
# best parameters from database: 1355683854.61
# best parameters from database: 59101385.0785
# best parameters from database: 34392.5868496
# best parameters from database: 34392.5868496
# best parameters from database: 59063213.0186
# best parameters from database: 59262248.9467
# best parameters from database: 59262248.9467
# best parameters from database: 59026112.6342
# best parameters from database: 59101385.0785
# best parameters from database: 34392.5868496
# best parameters from database: 59063213.0186
# best parameters from database: 6974270293.04
# best parameters from database: 59026112.6342
# best parameters from database: 59262248.9467
# best parameters from database: 59026112.6342
# best parameters from database: 122134.241504
# best parameters from database: 35459.8316201
# best parameters from database: 59156893.7861
# best parameters from database: 59096633.8386
# best parameters from database: 6994553656.76
# best parameters from database: 59101385.0785
# best parameters from database: 59386140.2073

# %%
best_p
# Out:
# {'acosi_i': 1.4917920737881377967,
#  'acosi_o': 91.515517821405981132,
#  'asini_i': 1.2175268187146886046,
#  'asini_o': 74.672709901274213484,
#  'd_DECJ': 3.8297379260835209625e-07,
#  'd_RAJ': -9.1473641598984196357e-08,
#  'dbeta': 3.137215781113322372e-05,
#  'delta': -2.4326288381809617149e-10,
#  'delta_lan': -5.4096316391090949558e-05,
#  'dgamma': -2.5854449182822343408e-07,
#  'eps1_i': 0.00068724728071223587401,
#  'eps1_o': 0.035186247652040840626,
#  'eps2_i': -9.1179836780626676656e-05,
#  'eps2_o': -0.003462135260726911092,
#  'f0': 365.95336311711874974,
#  'f1': -2.3547358099625887817e-15,
#  'j_AO1350': 5.364017648361716e-05,
#  'j_AO1440': -0.00055121663140921818248,
#  'j_AO327': 6.457616019511097e-05,
#  'j_GBT1500': -0.00053763724410558742536,
#  'j_GBT350': 1.8912917353649655e-05,
#  'j_GBT820': 6.712253154451129e-05,
#  'j_NCY1400': 0.000675,
#  'j_WSRT350': -3.6063906052781444e-05,
#  'pb_i': 1.6293969394546642386,
#  'pb_o': 327.2575252205244358,
#  'ppn_mode': 'heavysimple',
#  'q_i': 0.13746673219074406775,
#  'shapiro': True,
#  'tasc_i': 0.4077170163964780749,
#  'tasc_o': 313.93579191727065536,
#  'tol': 1e-16,
#  'tzrmjd': 180.00018851636843113,
#  'tzrmjd_base': 55920,
#  'use_quad': False}

# %%
bpd[frozenset(F.args.iteritems())] = best_p
threebody.save_best_parameter_database(bpd)

# %%
bpd.items()
# Out:
# [(frozenset({('efac', 1.3),
#              ('files', '0337+17-anne-2014-09-22'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', ('GBT1500', 'WSRT1400')),
#              ('parfile', '0337_tempo2_px_optical.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4920602002505874639,
#    'acosi_o': 91.545730948517159101,
#    'asini_i': 1.2175272341154308563,
#    'asini_o': 74.672712356463980574,
#    'd_DECJ': 4.4265935417303728307e-07,
#    'd_RAJ': -1.070284187936875009e-07,
#    'dbeta': -0.0019127355350863758238,
#    'delta': -1.1740885304932356904e-10,
#    'delta_lan': -7.6260159728548056856e-05,
#    'dgamma': 1.2069184549292093443e-08,
#    'eps1_i': 0.0006872650693715394079,
#    'eps1_o': 0.035186254329626903656,
#    'eps2_i': -9.1198615744183122494e-05,
#    'eps2_o': -0.0034620856087535145001,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.364017648361716e-05,
#    'j_AO1440': -0.00055121663140921818248,
#    'j_AO327': 6.457616019511097e-05,
#    'j_GBT1500': -0.00053764273816788685786,
#    'j_GBT350': 1.8912917353649655e-05,
#    'j_GBT820': 6.712253154451129e-05,
#    'j_NCY1400': 0.000675,
#    'j_WSRT350': -3.6063906052781444e-05,
#    'pb_i': 1.6293969317025978209,
#    'pb_o': 327.25755043408027423,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.1376191350222731768,
#    'shapiro': True,
#    'tasc_i': 0.40771702892618258136,
#    'tasc_o': 313.93581604656781989,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-anne-2014-09-22'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px_optical.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4917920737881377967,
#    'acosi_o': 91.515517821405981132,
#    'asini_i': 1.2175268187146886046,
#    'asini_o': 74.672709901274213484,
#    'd_DECJ': 3.8297379260835209625e-07,
#    'd_RAJ': -9.1473641598984196357e-08,
#    'dbeta': 3.137215781113322372e-05,
#    'delta': -2.4326288381809617149e-10,
#    'delta_lan': -5.4096316391090949558e-05,
#    'dgamma': -2.5854449182822343408e-07,
#    'eps1_i': 0.00068724728071223587401,
#    'eps1_o': 0.035186247652040840626,
#    'eps2_i': -9.1179836780626676656e-05,
#    'eps2_o': -0.003462135260726911092,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.364017648361716e-05,
#    'j_AO1440': -0.00055121663140921818248,
#    'j_AO327': 6.457616019511097e-05,
#    'j_GBT1500': -0.00053763724410558742536,
#    'j_GBT350': 1.8912917353649655e-05,
#    'j_GBT820': 6.712253154451129e-05,
#    'j_WSRT350': -3.6063906052781444e-05,
#    'pb_i': 1.6293969394546642386,
#    'pb_o': 327.2575252205244358,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13746673219074406775,
#    'shapiro': True,
#    'tasc_i': 0.4077170163964780749,
#    'tasc_o': 313.93579191727065536,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-anne-2014-02-04c'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px_optical.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4923577291747272848,
#    'acosi_o': 91.568003852343165597,
#    'asini_i': 1.2175267910853809216,
#    'asini_o': 74.672706966756963683,
#    'd_DECJ': 2.5423628442321372857e-07,
#    'd_RAJ': -6.5408169166644521269e-08,
#    'delta_lan': -2.484410143055489535e-05,
#    'eps1_i': 0.00068720587536583773697,
#    'eps1_o': 0.035186249047830174902,
#    'eps2_i': -9.1216553774941896747e-05,
#    'eps2_o': -0.0034621349317285898283,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.364017648361716e-05,
#    'j_AO1440': -0.00055111083883108853691,
#    'j_AO327': 6.457616019511097e-05,
#    'j_GBT1500': -0.00053764534539384948167,
#    'j_GBT350': 1.8912917353649655e-05,
#    'j_GBT820': 6.712253154451129e-05,
#    'j_WSRT350': -3.6063906052781444e-05,
#    'pb_i': 1.6293969349933353517,
#    'pb_o': 327.25752362946413548,
#    'ppn_mode': 'GR',
#    'q_i': 0.13747890625431246096,
#    'shapiro': True,
#    'tasc_i': 0.40771697658724251884,
#    'tasc_o': 313.93579203973088682,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4917501887350015597,
#    'acosi_o': 91.537983170852789176,
#    'asini_i': 1.2175267840763296957,
#    'asini_o': 74.672701795905153006,
#    'd_DECJ': 8.8424170826024851099e-10,
#    'd_PMDEC': -1.9580532733266362e-10,
#    'd_PMRA': 9.885280864586482e-11,
#    'd_PX': -0.44641887754143123879,
#    'd_RAJ': -3.0466309448331401392e-09,
#    'delta_lan': -8.5659925312170722909e-06,
#    'eps1_i': 0.00068718344326590147168,
#    'eps1_o': 0.035186237412951548661,
#    'eps2_i': -9.115527301096248838e-05,
#    'eps2_o': -0.0034621974697836775743,
#    'f0': 365.95336311128915,
#    'j_AO1350': 5.4178078264052672269e-05,
#    'j_AO1440': 4.8927801018093807392e-05,
#    'j_AO327': 6.510258650977037e-05,
#    'j_GBT1500': 6.234446663504565226e-05,
#    'j_GBT350': 1.8519487327505129184e-05,
#    'j_GBT820': 6.7848748305041978355e-05,
#    'j_WSRT350': -3.6595112307622442627e-05,
#    'lan': -2.643658109504019207,
#    'pb_i': 1.6293969535702676601,
#    'pb_o': 327.25748589859133816,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'GR',
#    'q_i': 0.13726519094335587045,
#    'tasc_i': 0.40771702901558446841,
#    'tasc_o': 313.93575748653280483,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_pm.par'),
#              ('ppn_mode', None),
#              ('priors', ()),
#              ('shapiro', False),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4870073870355541638,
#    'acosi_o': 91.237854534157803936,
#    'asini_i': 1.2175283930291920819,
#    'asini_o': 74.672699371706741871,
#    'd_DECJ': -1.9668596769468923624e-07,
#    'd_PX': 0.82283538763088315271,
#    'd_RAJ': 3.5759512633769490936e-08,
#    'delta': 0.0,
#    'delta_lan': 3.6058449713963126572e-05,
#    'eps1_i': 0.00068568720817855979873,
#    'eps1_o': 0.035186239648851740814,
#    'eps2_i': -9.1739752941784908284e-05,
#    'eps2_o': -0.0034621973342590981416,
#    'f0': 365.95336876828094,
#    'j_AO1350': 5.434208650373407444e-05,
#    'j_AO1440': 4.894359871871847276e-05,
#    'j_AO327': 6.5677301272928149774e-05,
#    'j_GBT1500': 6.2346316822423221018e-05,
#    'j_GBT350': 1.8551757984994333581e-05,
#    'j_GBT820': 6.790490288616337796e-05,
#    'j_WSRT350': -3.6541215443850041834e-05,
#    'lan': -134.38362335792677023,
#    'pb_i': 1.6294018279029601442,
#    'pb_o': 327.25749306877732375,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': None,
#    'q_i': 0.13709385397825933884,
#    'tasc_i': 0.40771752767564116107,
#    'tasc_o': 313.93576876239566756,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2014-01-22'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px_optical.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4918437192312049521,
#    'acosi_o': 91.532778237039737909,
#    'asini_i': 1.2175267494024835254,
#    'asini_o': 74.672702265507991448,
#    'd_DECJ': 1.0262403598596522729e-07,
#    'd_RAJ': -3.3756538960864431328e-08,
#    'dbeta': 0.0,
#    'delta': 0.0,
#    'delta_lan': -1.1797194990156767344e-05,
#    'dgamma': 0.0,
#    'eps1_i': 0.00068718035161586621667,
#    'eps1_o': 0.035186247046459282362,
#    'eps2_i': -9.1189796709392292401e-05,
#    'eps2_o': -0.0034621598138703656028,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.4109955156644152237e-05,
#    'j_AO1440': 4.8913930711724925209e-05,
#    'j_AO327': 6.5123913457397526002e-05,
#    'j_GBT1500': 6.2338104349180426955e-05,
#    'j_GBT350': 1.8506406959559728913e-05,
#    'j_GBT820': 6.800341447310413326e-05,
#    'j_WSRT350': -3.6597858695465815143e-05,
#    'pb_i': 1.6293969439338296142,
#    'pb_o': 327.25750824360346886,
#    'ppn_mode': 'GR',
#    'q_i': 0.13739544781190343385,
#    'shapiro': True,
#    'tasc_i': 0.4077169805842103755,
#    'tasc_o': 313.93577942689362925,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', False),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4910576218528956638,
#    'acosi_o': 91.482292931993824565,
#    'asini_i': 1.217524275485909434,
#    'asini_o': 74.672498386687887306,
#    'd_DECJ': 1.5874545950097263076e-07,
#    'd_PX': -0.0342365032445482078,
#    'd_RAJ': -3.529865376451191052e-08,
#    'dbeta': -0.00042355065260297776296,
#    'delta': -3.1672588685309433137e-06,
#    'delta_lan': -2.4594703631176065514e-06,
#    'dgamma': 8.2962150765616317161e-06,
#    'eps1_i': 0.00069074046734913581325,
#    'eps1_o': 0.035185441371675409314,
#    'eps2_i': -9.1384457191739417255e-05,
#    'eps2_o': -0.0034648656080614749766,
#    'f0': 365.95336876828094,
#    'general': True,
#    'j_AO1350': 5.397026514259696112e-05,
#    'j_AO1440': 4.8991553548385360425e-05,
#    'j_AO327': 6.5030689101068554986e-05,
#    'j_GBT1500': 6.2351986515003780905e-05,
#    'j_GBT350': 1.8539746049516453706e-05,
#    'j_GBT820': 6.7922351602419408844e-05,
#    'j_WSRT350': -3.6604825222636967646e-05,
#    'lan': 22.663122428064735848,
#    'matrix_mode': 0,
#    'pb_i': 1.6293866452388040919,
#    'pb_o': 327.25565319235800921,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13729274824997049695,
#    'shapiro': False,
#    'special': True,
#    'tasc_i': 0.4077162786150827325,
#    'tasc_o': 313.93392418132968369,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2014-01-22'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px_optical.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4923134372041583746,
#    'acosi_o': 91.567946711008166419,
#    'asini_i': 1.2175268965964651567,
#    'asini_o': 74.672676389613664945,
#    'd_DECJ': -4.432871613703032047e-08,
#    'd_RAJ': -3.1770148728223724486e-08,
#    'delta_lan': -6.4813973954639314311e-05,
#    'eps1_i': 0.00068713963389834500529,
#    'eps1_o': 0.035186229479527398199,
#    'eps2_i': -9.1116006557494235414e-05,
#    'eps2_o': -0.0034622849148678430641,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.3875088419603969341e-05,
#    'j_AO1440': 4.8941859758778870223e-05,
#    'j_AO327': 6.4565281193511292055e-05,
#    'j_GBT1500': 6.2325232388580194337e-05,
#    'j_GBT350': 1.8635367623171773451e-05,
#    'j_GBT820': 6.7103650343912289303e-05,
#    'j_WSRT350': -3.6579510917853825211e-05,
#    'lan': 23.44542911553395316,
#    'pb_i': 1.629396974720327375,
#    'pb_o': 327.25743142095565971,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'GR',
#    'q_i': 0.13699408949250487845,
#    'shapiro': True,
#    'tasc_i': 0.40771706745216272107,
#    'tasc_o': 313.935706628862985,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({(1, 1),
#              ('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', False),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4870960373214264,
#    'acosi_o': 91.64050818300674,
#    'asini_i': 1.2175270208510585,
#    'asini_o': 74.67269127715034,
#    'd_DECJ': 6.205370804957506e-08,
#    'd_PX': 12.592392752050834,
#    'd_RAJ': -2.4140959715819855e-08,
#    'dbeta': 0.0017496703368452343,
#    'delta': -6.377575525702637e-09,
#    'delta_lan': 0.000391698094219663,
#    'dgamma': 8.684356428714682e-06,
#    'eps1_i': 0.0006875507107658865,
#    'eps1_o': 0.03518607306587351,
#    'eps2_i': -9.134923406982514e-05,
#    'eps2_o': -0.0034622589600043453,
#    'f0': 365.95336876828094,
#    'general': True,
#    'j_AO1350': 5.643819999935814e-05,
#    'j_AO1440': 4.808926216820525e-05,
#    'j_AO327': 6.747796645765516e-05,
#    'j_GBT1500': 6.163793515666107e-05,
#    'j_GBT350': 1.6935828309848197e-05,
#    'j_GBT820': 6.938573625139912e-05,
#    'j_WSRT350': -3.757528293914576e-05,
#    'lan': 26.477464503977327,
#    'matrix_mode': 0,
#    'pb_i': 1.6293969099774286,
#    'pb_o': 327.2573831851088,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13710093267043819,
#    'special': True,
#    'tasc_i': 0.4077174545865948,
#    'tasc_o': 313.93564210578614,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({(1, 1),
#              ('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_pm.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4870960373214264,
#    'acosi_o': 91.64050818300674,
#    'asini_i': 1.2175270208510585,
#    'asini_o': 74.67269127715034,
#    'd_DECJ': 6.205370804957506e-08,
#    'd_PX': 12.592392752050834,
#    'd_RAJ': -2.4140959715819855e-08,
#    'dbeta': 0.0017496703368452343,
#    'delta': -6.377575525702637e-09,
#    'delta_lan': 0.000391698094219663,
#    'dgamma': 8.684356428714682e-06,
#    'eps1_i': 0.0006875507107658865,
#    'eps1_o': 0.03518607306587351,
#    'eps2_i': -9.134923406982514e-05,
#    'eps2_o': -0.0034622589600043453,
#    'f0': 365.95336876828094,
#    'general': True,
#    'j_AO1350': 5.643819999935814e-05,
#    'j_AO1440': 4.808926216820525e-05,
#    'j_AO327': 6.747796645765516e-05,
#    'j_GBT1500': 6.163793515666107e-05,
#    'j_GBT350': 1.6935828309848197e-05,
#    'j_GBT820': 6.938573625139912e-05,
#    'j_WSRT350': -3.757528293914576e-05,
#    'lan': 26.477464503977327,
#    'matrix_mode': 0,
#    'pb_i': 1.6293969099774286,
#    'pb_o': 327.2573831851088,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13710093267043819,
#    'special': True,
#    'tasc_i': 0.4077174545865948,
#    'tasc_o': 313.93564210578614,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_pm.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4910499077251168371,
#    'acosi_o': 91.482011824902850099,
#    'asini_i': 1.2175228833065895201,
#    'asini_o': 74.672497019984797106,
#    'd_DECJ': 1.6847336940935975218e-07,
#    'd_PX': -0.92477760701603597092,
#    'd_RAJ': -3.2388334094615887816e-08,
#    'dbeta': -0.00041698493776006720714,
#    'delta': -3.1672615080429307528e-06,
#    'delta_lan': -1.112757573007618058e-05,
#    'dgamma': 1.175749501990592583e-06,
#    'eps1_i': 0.0006903474655345057885,
#    'eps1_o': 0.03518543595937889206,
#    'eps2_i': -9.1385774154890500486e-05,
#    'eps2_o': -0.0034648723233093286863,
#    'f0': 365.95336876828094,
#    'general': True,
#    'j_AO1350': 5.4169010371405938449e-05,
#    'j_AO1440': 4.8930549945746121983e-05,
#    'j_AO327': 6.5301884179095320452e-05,
#    'j_GBT1500': 6.2334158805205982467e-05,
#    'j_GBT350': 1.8510494219682503864e-05,
#    'j_GBT820': 6.7999885696179984064e-05,
#    'j_WSRT350': -3.6586764591042250491e-05,
#    'lan': 22.854202311569486596,
#    'matrix_mode': 0,
#    'pb_i': 1.6293866452666076329,
#    'pb_o': 327.25565437712082301,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13729300135991373022,
#    'special': True,
#    'tasc_i': 0.4077160812719808227,
#    'tasc_o': 313.93392396740035599,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('shapiro', False),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4917501887350015597,
#    'acosi_o': 91.537983170852789176,
#    'asini_i': 1.2175267840763296957,
#    'asini_o': 74.672701795905153006,
#    'd_DECJ': 8.8424170826024851099e-10,
#    'd_PMDEC': -1.9580532733266362e-10,
#    'd_PMRA': 9.885280864586482e-11,
#    'd_PX': -0.44641887754143123879,
#    'd_RAJ': -3.0466309448331401392e-09,
#    'delta_lan': -8.5659925312170722909e-06,
#    'eps1_i': 0.00068718344326590147168,
#    'eps1_o': 0.035186237412951548661,
#    'eps2_i': -9.115527301096248838e-05,
#    'eps2_o': -0.0034621974697836775743,
#    'f0': 365.95336311128915,
#    'j_AO1350': 5.4178078264052672269e-05,
#    'j_AO1440': 4.8927801018093807392e-05,
#    'j_AO327': 6.510258650977037e-05,
#    'j_GBT1500': 6.234446663504565226e-05,
#    'j_GBT350': 1.8519487327505129184e-05,
#    'j_GBT820': 6.7848748305041978355e-05,
#    'j_WSRT350': -3.6595112307622442627e-05,
#    'lan': -2.643658109504019207,
#    'pb_i': 1.6293969535702676601,
#    'pb_o': 327.25748589859133816,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'GR',
#    'q_i': 0.13726519094335587045,
#    'tasc_i': 0.40771702901558446841,
#    'tasc_o': 313.93575748653280483,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2014-01-22'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_pm.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4919123207492414033,
#    'acosi_o': 91.549155967301150773,
#    'asini_i': 1.2175269422995559784,
#    'asini_o': 74.672682140823357831,
#    'd_DECJ': 5.6404738219623152886e-08,
#    'd_RAJ': -4.294868149907536382e-08,
#    'delta_lan': -8.6169846887976622462e-05,
#    'eps1_i': 0.00068713953640601479366,
#    'eps1_o': 0.03518621547812238698,
#    'eps2_i': -9.1109746793790163895e-05,
#    'eps2_o': -0.0034623030702068482091,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.4601873849522655648e-05,
#    'j_AO1440': 4.8908096711626182531e-05,
#    'j_AO327': 6.5282770080013121003e-05,
#    'j_GBT1500': 6.2348944585226772196e-05,
#    'j_GBT350': 1.8618868684630695431e-05,
#    'j_GBT820': 6.7849343401690299448e-05,
#    'j_WSRT350': -3.66075544275630306e-05,
#    'lan': -5.3536486931612908922,
#    'pb_i': 1.629396981527031248,
#    'pb_o': 327.2574167735090051,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'GR',
#    'q_i': 0.1369229941434861232,
#    'shapiro': True,
#    'tasc_i': 0.40771709841264573338,
#    'tasc_o': 313.9356889734888526,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_pm.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4917501887350015597,
#    'acosi_o': 91.537983170852789176,
#    'asini_i': 1.2175267840763296957,
#    'asini_o': 74.672701795905153006,
#    'd_DECJ': 8.8424170826024851099e-10,
#    'd_PMDEC': -1.9580532733266362e-10,
#    'd_PMRA': 9.885280864586482e-11,
#    'd_PX': -0.44641887754143123879,
#    'd_RAJ': -3.0466309448331401392e-09,
#    'delta_lan': -8.5659925312170722909e-06,
#    'eps1_i': 0.00068718344326590147168,
#    'eps1_o': 0.035186237412951548661,
#    'eps2_i': -9.115527301096248838e-05,
#    'eps2_o': -0.0034621974697836775743,
#    'f0': 365.95336311128915,
#    'j_AO1350': 5.4178078264052672269e-05,
#    'j_AO1440': 4.8927801018093807392e-05,
#    'j_AO327': 6.510258650977037e-05,
#    'j_GBT1500': 6.234446663504565226e-05,
#    'j_GBT350': 1.8519487327505129184e-05,
#    'j_GBT820': 6.7848748305041978355e-05,
#    'j_WSRT350': -3.6595112307622442627e-05,
#    'lan': -2.643658109504019207,
#    'pb_i': 1.6293969535702676601,
#    'pb_o': 327.25748589859133816,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'GR',
#    'q_i': 0.13726519094335587045,
#    'tasc_i': 0.40771702901558446841,
#    'tasc_o': 313.93575748653280483,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-anne-2014-02-04b'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px_optical.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4916493021653913168,
#    'acosi_o': 91.519620761810251311,
#    'asini_i': 1.2175267653814461963,
#    'asini_o': 74.67270643847444167,
#    'd_DECJ': 2.4779681329875679358e-07,
#    'd_RAJ': -6.4499129045266957688e-08,
#    'delta_lan': -2.5631264977132676208e-05,
#    'eps1_i': 0.00068720563241181474598,
#    'eps1_o': 0.035186248275885282531,
#    'eps2_i': -9.1213668386596449718e-05,
#    'eps2_o': -0.0034621385790835670135,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.364017648361716e-05,
#    'j_AO1440': -0.00055110229623296496296,
#    'j_AO327': 6.457616019511097e-05,
#    'j_GBT1500': -0.00053762924604986671483,
#    'j_GBT350': 1.8912917353649655e-05,
#    'j_GBT820': 6.712253154451129e-05,
#    'j_WSRT350': -3.6063906052781444e-05,
#    'pb_i': 1.6293969395230589955,
#    'pb_o': 327.25752155593578771,
#    'ppn_mode': 'GR',
#    'q_i': 0.13746334425652446117,
#    'shapiro': True,
#    'tasc_i': 0.40771698415026918393,
#    'tasc_o': 313.93579039177622422,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('kopeikin', True),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('t2_astrometry', True),
#              ('tzrmjd_middle', 'auto')}),
#   {'acosi_i': 1.4870960373214264,
#    'acosi_o': 91.64050818300674,
#    'asini_i': 1.2175270208510585,
#    'asini_o': 74.67269127715034,
#    'd_DECJ': 6.205370804957506e-08,
#    'd_PX': 12.592392752050834,
#    'd_RAJ': -2.4140959715819855e-08,
#    'dbeta': 0.0017496703368452343,
#    'delta': -6.377575525702637e-09,
#    'delta_lan': 0.000391698094219663,
#    'dgamma': 8.684356428714682e-06,
#    'eps1_i': 0.0006875507107658865,
#    'eps1_o': 0.03518607306587351,
#    'eps2_i': -9.134923406982514e-05,
#    'eps2_o': -0.0034622589600043453,
#    'general': True,
#    'j_AO1350': 5.643819999935814e-05,
#    'j_AO1440': 4.808926216820525e-05,
#    'j_AO327': 6.747796645765516e-05,
#    'j_GBT1500': 6.163793515666107e-05,
#    'j_GBT350': 1.6935828309848197e-05,
#    'j_GBT820': 6.938573625139912e-05,
#    'j_WSRT350': -3.757528293914576e-05,
#    'lan': 26.477464503977327,
#    'matrix_mode': 0,
#    'pb_i': 1.6293969099774286,
#    'pb_o': 327.2573831851088,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13710093267043819,
#    'special': True,
#    'tasc_i': 0.4077174545865948,
#    'tasc_o': 313.93564210578614,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('kopeikin', True),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', True),
#              ('t2_astrometry', True),
#              ('tzrmjd_middle', 'auto')}),
#   {'acosi_i': 1.4870960373214264,
#    'acosi_o': 91.64050818300674,
#    'asini_i': 1.2175270208510585,
#    'asini_o': 74.67269127715034,
#    'd_DECJ': 6.205370804957506e-08,
#    'd_PX': 12.592392752050834,
#    'd_RAJ': -2.4140959715819855e-08,
#    'dbeta': 0.0017496703368452343,
#    'delta': -6.377575525702637e-09,
#    'delta_lan': 0.000391698094219663,
#    'dgamma': 8.684356428714682e-06,
#    'eps1_i': 0.0006875507107658865,
#    'eps1_o': 0.03518607306587351,
#    'eps2_i': -9.134923406982514e-05,
#    'eps2_o': -0.0034622589600043453,
#    'general': True,
#    'j_AO1350': 5.643819999935814e-05,
#    'j_AO1440': 4.808926216820525e-05,
#    'j_AO327': 6.747796645765516e-05,
#    'j_GBT1500': 6.163793515666107e-05,
#    'j_GBT350': 1.6935828309848197e-05,
#    'j_GBT820': 6.938573625139912e-05,
#    'j_WSRT350': -3.757528293914576e-05,
#    'lan': 26.477464503977327,
#    'matrix_mode': 0,
#    'pb_i': 1.6293969099774286,
#    'pb_o': 327.2573831851088,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13710093267043819,
#    'special': True,
#    'tasc_i': 0.4077174545865948,
#    'tasc_o': 313.93564210578614,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({(1, 1),
#              ('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_pm.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4870960373214264,
#    'acosi_o': 91.64050818300674,
#    'asini_i': 1.2175270208510585,
#    'asini_o': 74.67269127715034,
#    'd_DECJ': 6.205370804957506e-08,
#    'd_PX': 12.592392752050834,
#    'd_RAJ': -2.4140959715819855e-08,
#    'dbeta': 0.0017496703368452343,
#    'delta': -6.377575525702637e-09,
#    'delta_lan': 0.000391698094219663,
#    'dgamma': 8.684356428714682e-06,
#    'eps1_i': 0.0006875507107658865,
#    'eps1_o': 0.03518607306587351,
#    'eps2_i': -9.134923406982514e-05,
#    'eps2_o': -0.0034622589600043453,
#    'f0': 365.95336876828094,
#    'general': True,
#    'j_AO1350': 5.643819999935814e-05,
#    'j_AO1440': 4.808926216820525e-05,
#    'j_AO327': 6.747796645765516e-05,
#    'j_GBT1500': 6.163793515666107e-05,
#    'j_GBT350': 1.6935828309848197e-05,
#    'j_GBT820': 6.938573625139912e-05,
#    'j_WSRT350': -3.757528293914576e-05,
#    'lan': 26.477464503977327,
#    'matrix_mode': 0,
#    'pb_i': 1.6293969099774286,
#    'pb_o': 327.2573831851088,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13710093267043819,
#    'special': True,
#    'tasc_i': 0.4077174545865948,
#    'tasc_o': 313.93564210578614,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_pm.par'),
#              ('ppn_mode', None),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4870073870355541638,
#    'acosi_o': 91.237854534157803936,
#    'asini_i': 1.2175283930291920819,
#    'asini_o': 74.672699371706741871,
#    'd_DECJ': -1.9668596769468923624e-07,
#    'd_PX': 0.82283538763088315271,
#    'd_RAJ': 3.5759512633769490936e-08,
#    'delta': 0.0,
#    'delta_lan': 3.6058449713963126572e-05,
#    'eps1_i': 0.00068568720817855979873,
#    'eps1_o': 0.035186239648851740814,
#    'eps2_i': -9.1739752941784908284e-05,
#    'eps2_o': -0.0034621973342590981416,
#    'f0': 365.95336876828094,
#    'j_AO1350': 5.434208650373407444e-05,
#    'j_AO1440': 4.894359871871847276e-05,
#    'j_AO327': 6.5677301272928149774e-05,
#    'j_GBT1500': 6.2346316822423221018e-05,
#    'j_GBT350': 1.8551757984994333581e-05,
#    'j_GBT820': 6.790490288616337796e-05,
#    'j_WSRT350': -3.6541215443850041834e-05,
#    'lan': -134.38362335792677023,
#    'pb_i': 1.6294018279029601442,
#    'pb_o': 327.25749306877732375,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': None,
#    'q_i': 0.13709385397825933884,
#    'tasc_i': 0.40771752767564116107,
#    'tasc_o': 313.93576876239566756,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-06-06'),
#              ('fit_pm', False),
#              ('fit_pos', False),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', ('WSRT1400',)),
#              ('parfile', '0337_tempo2_nobinary.par'),
#              ('ppn_mode', None),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4897526614420296516,
#    'acosi_o': 91.406877920363995858,
#    'asini_i': 1.2175284370901029975,
#    'asini_o': 74.672709712018036338,
#    'delta': 0.0,
#    'delta_lan': 4.8220241628483202396e-05,
#    'eps1_i': 0.0006856734568106118968,
#    'eps1_o': 0.035186277265651086594,
#    'eps2_i': -9.1706450063988849455e-05,
#    'eps2_o': -0.0034621368067846675071,
#    'f0': 365.95336876828094,
#    'j_AO1350': 5.3635190284990956237e-05,
#    'j_AO1440': 4.9259452945711710099e-05,
#    'j_AO327': 6.4794561335151349273e-05,
#    'j_GBT1500': 6.2620813306723303735e-05,
#    'j_GBT350': 1.8855899287062338046e-05,
#    'j_GBT820': 6.7057259469771009361e-05,
#    'j_WSRT350': -3.6104142237134380419e-05,
#    'pb_i': 1.6294017912103802948,
#    'pb_o': 327.25753790301990501,
#    'ppn_mode': None,
#    'q_i': 0.13734741974750966142,
#    'shapiro': True,
#    'tasc_i': 0.40771744400081470636,
#    'tasc_o': 313.93581137879523948,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', None),
#              ('priors', ()),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4870073870355541638,
#    'acosi_o': 91.237854534157803936,
#    'asini_i': 1.2175283930291920819,
#    'asini_o': 74.672699371706741871,
#    'd_DECJ': -1.9668596769468923624e-07,
#    'd_PX': 0.82283538763088315271,
#    'd_RAJ': 3.5759512633769490936e-08,
#    'delta': 0.0,
#    'delta_lan': 3.6058449713963126572e-05,
#    'eps1_i': 0.00068568720817855979873,
#    'eps1_o': 0.035186239648851740814,
#    'eps2_i': -9.1739752941784908284e-05,
#    'eps2_o': -0.0034621973342590981416,
#    'f0': 365.95336876828094,
#    'j_AO1350': 5.434208650373407444e-05,
#    'j_AO1440': 4.894359871871847276e-05,
#    'j_AO327': 6.5677301272928149774e-05,
#    'j_GBT1500': 6.2346316822423221018e-05,
#    'j_GBT350': 1.8551757984994333581e-05,
#    'j_GBT820': 6.790490288616337796e-05,
#    'j_WSRT350': -3.6541215443850041834e-05,
#    'lan': -134.38362335792677023,
#    'pb_i': 1.6294018279029601442,
#    'pb_o': 327.25749306877732375,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': None,
#    'q_i': 0.13709385397825933884,
#    'tasc_i': 0.40771752767564116107,
#    'tasc_o': 313.93576876239566756,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('kopeikin', True),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', False),
#              ('t2_astrometry', True),
#              ('tzrmjd_middle', 'auto')}),
#   {'acosi_i': 1.4870960373214264,
#    'acosi_o': 91.64050818300674,
#    'asini_i': 1.2175270208510585,
#    'asini_o': 74.67269127715034,
#    'd_DECJ': 6.205370804957506e-08,
#    'd_PX': 12.592392752050834,
#    'd_RAJ': -2.4140959715819855e-08,
#    'dbeta': 0.0017496703368452343,
#    'delta': -6.377575525702637e-09,
#    'delta_lan': 0.000391698094219663,
#    'dgamma': 8.684356428714682e-06,
#    'eps1_i': 0.0006875507107658865,
#    'eps1_o': 0.03518607306587351,
#    'eps2_i': -9.134923406982514e-05,
#    'eps2_o': -0.0034622589600043453,
#    'general': True,
#    'j_AO1350': 5.643819999935814e-05,
#    'j_AO1440': 4.808926216820525e-05,
#    'j_AO327': 6.747796645765516e-05,
#    'j_GBT1500': 6.163793515666107e-05,
#    'j_GBT350': 1.6935828309848197e-05,
#    'j_GBT820': 6.938573625139912e-05,
#    'j_WSRT350': -3.757528293914576e-05,
#    'lan': 26.477464503977327,
#    'matrix_mode': 0,
#    'pb_i': 1.6293969099774286,
#    'pb_o': 327.2573831851088,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13710093267043819,
#    'special': True,
#    'tasc_i': 0.4077174545865948,
#    'tasc_o': 313.93564210578614,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_pm.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', False),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4910576218528956638,
#    'acosi_o': 91.482292931993824565,
#    'asini_i': 1.217524275485909434,
#    'asini_o': 74.672498386687887306,
#    'd_DECJ': 1.5874545950097263076e-07,
#    'd_PX': -0.0342365032445482078,
#    'd_RAJ': -3.529865376451191052e-08,
#    'dbeta': -0.00042355065260297776296,
#    'delta': -3.1672588685309433137e-06,
#    'delta_lan': -2.4594703631176065514e-06,
#    'dgamma': 8.2962150765616317161e-06,
#    'eps1_i': 0.00069074046734913581325,
#    'eps1_o': 0.035185441371675409314,
#    'eps2_i': -9.1384457191739417255e-05,
#    'eps2_o': -0.0034648656080614749766,
#    'f0': 365.95336876828094,
#    'general': True,
#    'j_AO1350': 5.397026514259696112e-05,
#    'j_AO1440': 4.8991553548385360425e-05,
#    'j_AO327': 6.5030689101068554986e-05,
#    'j_GBT1500': 6.2351986515003780905e-05,
#    'j_GBT350': 1.8539746049516453706e-05,
#    'j_GBT820': 6.7922351602419408844e-05,
#    'j_WSRT350': -3.6604825222636967646e-05,
#    'lan': 22.663122428064735848,
#    'matrix_mode': 0,
#    'pb_i': 1.6293866452388040919,
#    'pb_o': 327.25565319235800921,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13729274824997049695,
#    'shapiro': False,
#    'special': True,
#    'tasc_i': 0.4077162786150827325,
#    'tasc_o': 313.93392418132968369,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4910499077251168371,
#    'acosi_o': 91.482011824902850099,
#    'asini_i': 1.2175228833065895201,
#    'asini_o': 74.672497019984797106,
#    'd_DECJ': 1.6847336940935975218e-07,
#    'd_PX': -0.92477760701603597092,
#    'd_RAJ': -3.2388334094615887816e-08,
#    'dbeta': -0.00041698493776006720714,
#    'delta': -3.1672615080429307528e-06,
#    'delta_lan': -1.112757573007618058e-05,
#    'dgamma': 1.175749501990592583e-06,
#    'eps1_i': 0.0006903474655345057885,
#    'eps1_o': 0.03518543595937889206,
#    'eps2_i': -9.1385774154890500486e-05,
#    'eps2_o': -0.0034648723233093286863,
#    'f0': 365.95336876828094,
#    'general': True,
#    'j_AO1350': 5.4169010371405938449e-05,
#    'j_AO1440': 4.8930549945746121983e-05,
#    'j_AO327': 6.5301884179095320452e-05,
#    'j_GBT1500': 6.2334158805205982467e-05,
#    'j_GBT350': 1.8510494219682503864e-05,
#    'j_GBT820': 6.7999885696179984064e-05,
#    'j_WSRT350': -3.6586764591042250491e-05,
#    'lan': 22.854202311569486596,
#    'matrix_mode': 0,
#    'pb_i': 1.6293866452666076329,
#    'pb_o': 327.25565437712082301,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13729300135991373022,
#    'special': True,
#    'tasc_i': 0.4077160812719808227,
#    'tasc_o': 313.93392396740035599,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', None),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4870073870355541638,
#    'acosi_o': 91.237854534157803936,
#    'asini_i': 1.2175283930291920819,
#    'asini_o': 74.672699371706741871,
#    'd_DECJ': -1.9668596769468923624e-07,
#    'd_PX': 0.82283538763088315271,
#    'd_RAJ': 3.5759512633769490936e-08,
#    'delta': 0.0,
#    'delta_lan': 3.6058449713963126572e-05,
#    'eps1_i': 0.00068568720817855979873,
#    'eps1_o': 0.035186239648851740814,
#    'eps2_i': -9.1739752941784908284e-05,
#    'eps2_o': -0.0034621973342590981416,
#    'f0': 365.95336876828094,
#    'j_AO1350': 5.434208650373407444e-05,
#    'j_AO1440': 4.894359871871847276e-05,
#    'j_AO327': 6.5677301272928149774e-05,
#    'j_GBT1500': 6.2346316822423221018e-05,
#    'j_GBT350': 1.8551757984994333581e-05,
#    'j_GBT820': 6.790490288616337796e-05,
#    'j_WSRT350': -3.6541215443850041834e-05,
#    'lan': -134.38362335792677023,
#    'pb_i': 1.6294018279029601442,
#    'pb_o': 327.25749306877732375,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': None,
#    'q_i': 0.13709385397825933884,
#    'tasc_i': 0.40771752767564116107,
#    'tasc_o': 313.93576876239566756,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-06-06'),
#              ('fit_pm', False),
#              ('fit_pos', False),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', ('AO1350', 'AO1440')),
#              ('parfile', '0337_tempo2_nobinary.par'),
#              ('ppn_mode', None),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4897526614420296516,
#    'acosi_o': 91.406877920363995858,
#    'asini_i': 1.2175284370901029975,
#    'asini_o': 74.672709712018036338,
#    'delta': 0.0,
#    'delta_lan': 4.8220241628483202396e-05,
#    'eps1_i': 0.0006856734568106118968,
#    'eps1_o': 0.035186277265651086594,
#    'eps2_i': -9.1706450063988849455e-05,
#    'eps2_o': -0.0034621368067846675071,
#    'f0': 365.95336876828094,
#    'j_AO1350': 5.3635190284990956237e-05,
#    'j_AO1440': 4.9259452945711710099e-05,
#    'j_AO327': 6.4794561335151349273e-05,
#    'j_GBT1500': 6.2620813306723303735e-05,
#    'j_GBT350': 1.8855899287062338046e-05,
#    'j_GBT820': 6.7057259469771009361e-05,
#    'j_WSRT350': -3.6104142237134380419e-05,
#    'pb_i': 1.6294017912103802948,
#    'pb_o': 327.25753790301990501,
#    'ppn_mode': None,
#    'q_i': 0.13734741974750966142,
#    'shapiro': True,
#    'tasc_i': 0.40771744400081470636,
#    'tasc_o': 313.93581137879523948,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-anne-2014-09-22'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo_px_optical.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4933177393874891906,
#    'acosi_o': 91.631531640687977756,
#    'asini_i': 1.2175268957549397818,
#    'asini_o': 74.67270911129958675,
#    'd_DECJ': 3.8730561887528140474e-07,
#    'd_RAJ': -9.2888706183099058747e-08,
#    'delta_lan': -5.6886149407010859794e-05,
#    'eps1_i': 0.00068724946873887318756,
#    'eps1_o': 0.035186250832201595044,
#    'eps2_i': -9.1175639303702095519e-05,
#    'eps2_o': -0.0034621216287419294334,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.364017648361716e-05,
#    'j_AO1440': -0.00055120014696700854827,
#    'j_AO327': 6.457616019511097e-05,
#    'j_GBT1500': -0.0005376131625598995477,
#    'j_GBT350': 1.8912917353649655e-05,
#    'j_GBT820': 6.712253154451129e-05,
#    'j_WSRT350': -3.6063906052781444e-05,
#    'pb_i': 1.6293968880105445728,
#    'pb_o': 327.25752664051344981,
#    'ppn_mode': 'GR',
#    'q_i': 0.13752266545914097862,
#    'shapiro': True,
#    'tasc_i': 0.40751889681526188913,
#    'tasc_o': 313.93559483254421699,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.491751023724543408,
#    'acosi_o': 91.537950325633845601,
# ...
#    'eps1_i': 0.00068718344326590147168,
#    'eps1_o': 0.035186237412951548661,
#    'eps2_i': -9.115527301096248838e-05,
#    'eps2_o': -0.0034621974697836775743,
#    'f0': 365.95336311128915,
#    'j_AO1350': 5.4178078264052672269e-05,
#    'j_AO1440': 4.8927801018093807392e-05,
#    'j_AO327': 6.510258650977037e-05,
#    'j_GBT1500': 6.234446663504565226e-05,
#    'j_GBT350': 1.8519487327505129184e-05,
#    'j_GBT820': 6.7848748305041978355e-05,
#    'j_WSRT350': -3.6595112307622442627e-05,
#    'lan': -2.643658109504019207,
#    'pb_i': 1.6293969535702676601,
#    'pb_o': 327.25748589859133816,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'GR',
#    'q_i': 0.13726519094335587045,
#    'tasc_i': 0.40771702901558446841,
#    'tasc_o': 313.93575748653280483,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({(1, 1),
#              ('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4870960373214264,
#    'acosi_o': 91.64050818300674,
#    'asini_i': 1.2175270208510585,
#    'asini_o': 74.67269127715034,
#    'd_DECJ': 6.205370804957506e-08,
#    'd_PX': 12.592392752050834,
#    'd_RAJ': -2.4140959715819855e-08,
#    'dbeta': 0.0017496703368452343,
#    'delta': -6.377575525702637e-09,
#    'delta_lan': 0.000391698094219663,
#    'dgamma': 8.684356428714682e-06,
#    'eps1_i': 0.0006875507107658865,
#    'eps1_o': 0.03518607306587351,
#    'eps2_i': -9.134923406982514e-05,
#    'eps2_o': -0.0034622589600043453,
#    'f0': 365.95336876828094,
#    'general': True,
#    'j_AO1350': 5.643819999935814e-05,
#    'j_AO1440': 4.808926216820525e-05,
#    'j_AO327': 6.747796645765516e-05,
#    'j_GBT1500': 6.163793515666107e-05,
#    'j_GBT350': 1.6935828309848197e-05,
#    'j_GBT820': 6.938573625139912e-05,
#    'j_WSRT350': -3.757528293914576e-05,
#    'lan': 26.477464503977327,
#    'matrix_mode': 0,
#    'pb_i': 1.6293969099774286,
#    'pb_o': 327.2573831851088,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13710093267043819,
#    'special': True,
#    'tasc_i': 0.4077174545865948,
#    'tasc_o': 313.93564210578614,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_pm.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4917502711716096765,
#    'acosi_o': 91.537978361906241043,
#    'asini_i': 1.2175267841326505506,
#    'asini_o': 74.67270179576099174,
#    'd_DECJ': 8.8646943096630097989e-10,
#    'd_PMDEC': -1.9580532733266362e-10,
#    'd_PMRA': 9.885280864586482e-11,
#    'd_PX': -0.44576231637744732818,
#    'd_RAJ': -3.0457950026408630524e-09,
#    'delta_lan': -8.5542608450096089127e-06,
#    'eps1_i': 0.00068718341260624047947,
#    'eps1_o': 0.035186237417755576442,
#    'eps2_i': -9.1155391818940479249e-05,
#    'eps2_o': -0.0034621974776514838659,
#    'f0': 365.95336311128915,
#    'j_AO1350': 5.4178599925429036695e-05,
#    'j_AO1440': 4.8927806287136866099e-05,
#    'j_AO327': 6.5103043867396211205e-05,
#    'j_GBT1500': 6.2344382133130617072e-05,
#    'j_GBT350': 1.8519717889199437502e-05,
#    'j_GBT820': 6.7849258235435922024e-05,
#    'j_WSRT350': -3.6595125974280807709e-05,
#    'lan': -2.6434381081027864694,
#    'pb_i': 1.6293969535706683936,
#    'pb_o': 327.2574858984909196,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'GR',
#    'q_i': 0.13726519501137786213,
#    'shapiro': True,
#    'tasc_i': 0.4077170290398238524,
#    'tasc_o': 313.93575748591924141,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', True),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('parfile', '0337_tempo2_nobinary.par'),
#              ('ppn_mode', 'GR'),
#              ('shapiro', True),
#              ('t2_astrometry', True),
#              ('tzrmjd_middle', 'auto')}),
#   {'acosi_i': 1.4917553649083741,
#    'acosi_o': 91.53728918325116,
#    'asini_i': 1.2175267843858402,
#    'asini_o': 74.67270166579456,
#    'd_DECJ': -1.070731501745044e-09,
#    'd_PMDEC': -1.9580532733266362e-10,
#    'd_PMRA': 9.885280864586482e-11,
#    'd_PX': -0.5531255775641357,
#    'd_RAJ': -3.4254785902426147e-09,
#    'delta_lan': -1.1875825731197669e-05,
#    'eps1_i': 0.0006871812134080429,
#    'eps1_o': 0.0351862386078509,
#    'eps2_i': -9.115741533177484e-05,
#    'eps2_o': -0.003462197684711702,
#    'f0': 365.95336311128915,
#    'f1': -2.359147188177546e-15,
#    'j_AO1350': 5.416890691232084e-05,
#    'j_AO1440': 4.8927007422127645e-05,
#    'j_AO327': 6.509749509896134e-05,
#    'j_GBT1500': 6.2342354290442e-05,
#    'j_GBT350': 1.8517017863581812e-05,
#    'j_GBT820': 6.785312385988059e-05,
#    'j_WSRT350': -3.659850586544055e-05,
#    'pb_i': 1.6293969535220398,
#    'pb_o': 327.25748562198874,
#    'ppn_mode': 'GR',
#    'q_i': 0.13726698219882472,
#    'tasc_i': 0.40771702695152506,
#    'tasc_o': 313.9357571515758,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-anne-2014-02-04c'),
#              ('fit_pm', False),
#              ('fit_pos', False),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo_px_optical.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4906026211744192,
#    'acosi_o': 91.45306511868512,
#    'asini_i': 1.2175266047808866,
#    'asini_o': 74.67270046836649,
#    'delta_lan': 5.2353855210995294e-05,
#    'eps1_i': 0.0006871960477540105,
#    'eps1_o': 0.03518625484392224,
#    'eps2_i': -9.116341168613552e-05,
#    'eps2_o': -0.0034621826187927287,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.364017648361716e-05,
#    'j_AO1440': 4.928169959977888e-05,
#    'j_AO327': 6.457616019511097e-05,
#    'j_GBT1500': 6.263233068203105e-05,
#    'j_GBT350': 1.8912917353649655e-05,
#    'j_GBT820': 6.712253154451129e-05,
#    'j_WSRT350': -3.6063906052781444e-05,
#    'pb_i': 1.6293969135798416,
#    'pb_o': 327.2574914403988,
#    'ppn_mode': 'GR',
#    'q_i': 0.13733426409023541,
#    'shapiro': True,
#    'tasc_i': 0.40751890523964546,
#    'tasc_o': 313.93556809302754,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2014-01-22'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px_optical.par'),
#              ('ppn_mode', 'GR'),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4918437192312049521,
#    'acosi_o': 91.532778237039737909,
#    'asini_i': 1.2175267494024835254,
#    'asini_o': 74.672702265507991448,
#    'd_DECJ': 1.0262403598596522729e-07,
#    'd_RAJ': -3.3756538960864431328e-08,
#    'delta_lan': -1.1797194990156767344e-05,
#    'eps1_i': 0.00068718035161586621667,
#    'eps1_o': 0.035186247046459282362,
#    'eps2_i': -9.1189796709392292401e-05,
#    'eps2_o': -0.0034621598138703656028,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.4109955156644152237e-05,
#    'j_AO1440': 4.8913930711724925209e-05,
#    'j_AO327': 6.5123913457397526002e-05,
#    'j_GBT1500': 6.2338104349180426955e-05,
#    'j_GBT350': 1.8506406959559728913e-05,
#    'j_GBT820': 6.800341447310413326e-05,
#    'j_WSRT350': -3.6597858695465815143e-05,
#    'pb_i': 1.6293969439338296142,
#    'pb_o': 327.25750824360346886,
#    'ppn_mode': 'GR',
#    'q_i': 0.13739544781190343385,
#    'shapiro': True,
#    'tasc_i': 0.4077169805842103755,
#    'tasc_o': 313.93577942689362925,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('kopeikin', True),
#              ('parfile', '0337_tempo2_pm.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', True),
#              ('t2_astrometry', True),
#              ('tzrmjd_middle', 'auto')}),
#   {'acosi_i': 1.4870960373214264,
#    'acosi_o': 91.64050818300674,
#    'asini_i': 1.2175270208510585,
#    'asini_o': 74.67269127715034,
#    'd_DECJ': 6.205370804957506e-08,
#    'd_PX': 12.592392752050834,
#    'd_RAJ': -2.4140959715819855e-08,
#    'dbeta': 0.0017496703368452343,
#    'delta': -6.377575525702637e-09,
#    'delta_lan': 0.000391698094219663,
#    'dgamma': 8.684356428714682e-06,
#    'eps1_i': 0.0006875507107658865,
#    'eps1_o': 0.03518607306587351,
#    'eps2_i': -9.134923406982514e-05,
#    'eps2_o': -0.0034622589600043453,
#    'general': True,
#    'j_AO1350': 5.643819999935814e-05,
#    'j_AO1440': 4.808926216820525e-05,
#    'j_AO327': 6.747796645765516e-05,
#    'j_GBT1500': 6.163793515666107e-05,
#    'j_GBT350': 1.6935828309848197e-05,
#    'j_GBT820': 6.938573625139912e-05,
#    'j_WSRT350': -3.757528293914576e-05,
#    'lan': 26.477464503977327,
#    'matrix_mode': 0,
#    'pb_i': 1.6293969099774286,
#    'pb_o': 327.2573831851088,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13710093267043819,
#    'special': True,
#    'tasc_i': 0.4077174545865948,
#    'tasc_o': 313.93564210578614,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2013-08-29'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', True),
#              ('general', True),
#              ('kopeikin', True),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_pm.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4910499077251168371,
#    'acosi_o': 91.482011824902850099,
#    'asini_i': 1.2175228833065895201,
#    'asini_o': 74.672497019984797106,
#    'd_DECJ': 1.6847336940935975218e-07,
#    'd_PX': -0.92477760701603597092,
#    'd_RAJ': -3.2388334094615887816e-08,
#    'dbeta': -0.00041698493776006720714,
#    'delta': -3.1672615080429307528e-06,
#    'delta_lan': -1.112757573007618058e-05,
#    'dgamma': 1.175749501990592583e-06,
#    'eps1_i': 0.0006903474655345057885,
#    'eps1_o': 0.03518543595937889206,
#    'eps2_i': -9.1385774154890500486e-05,
#    'eps2_o': -0.0034648723233093286863,
#    'f0': 365.95336876828094,
#    'general': True,
#    'j_AO1350': 5.4169010371405938449e-05,
#    'j_AO1440': 4.8930549945746121983e-05,
#    'j_AO327': 6.5301884179095320452e-05,
#    'j_GBT1500': 6.2334158805205982467e-05,
#    'j_GBT350': 1.8510494219682503864e-05,
#    'j_GBT820': 6.7999885696179984064e-05,
#    'j_WSRT350': -3.6586764591042250491e-05,
#    'lan': 22.854202311569486596,
#    'matrix_mode': 0,
#    'pb_i': 1.6293866452666076329,
#    'pb_o': 327.25565437712082301,
#    'pm_x': -4.7253571656398304e-11,
#    'pm_y': 5.176655321908803e-11,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.13729300135991373022,
#    'special': True,
#    'tasc_i': 0.4077160812719808227,
#    'tasc_o': 313.93392396740035599,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-anne-2014-02-04c'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px_optical.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ('dbeta', 'dgamma')),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4916489370619297724,
#    'acosi_o': 91.519678624464995326,
#    'asini_i': 1.2175267656043140336,
#    'asini_o': 74.672706435118382629,
#    'd_DECJ': 2.4779981446904194578e-07,
#    'd_RAJ': -6.448690745948047197e-08,
#    'dbeta': 0.0,
#    'delta': 0.0,
#    'delta_lan': -2.5706953085885424337e-05,
#    'dgamma': 0.0,
#    'eps1_i': 0.00068720697559714879941,
#    'eps1_o': 0.035186248278579628566,
#    'eps2_i': -9.1219883858571423757e-05,
#    'eps2_o': -0.0034621387225861646432,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.364017648361716e-05,
#    'j_AO1440': -0.00055111145013916822883,
#    'j_AO327': 6.457616019511097e-05,
#    'j_GBT1500': -0.00053765360388875988808,
#    'j_GBT350': 1.8912917353649655e-05,
#    'j_GBT820': 6.712253154451129e-05,
#    'j_WSRT350': -3.6063906052781444e-05,
#    'pb_i': 1.6293969395322322398,
#    'pb_o': 327.25752156650259583,
#    'ppn_mode': 'GR',
#    'q_i': 0.13746334240606103578,
#    'shapiro': True,
#    'tasc_i': 0.40771698357713665275,
#    'tasc_o': 313.93579038603503967,
#    'tol': 1e-16,
#    'use_quad': False}),
#  (frozenset({('efac', 1.3),
#              ('files', '0337+17-scott-2014-01-22'),
#              ('fit_pm', False),
#              ('fit_pos', True),
#              ('fit_px', False),
#              ('general', True),
#              ('kopeikin', False),
#              ('matrix_mode', 0),
#              ('only_tels', None),
#              ('parfile', '0337_tempo2_px_optical.par'),
#              ('ppn_mode', 'heavysimple'),
#              ('priors', ()),
#              ('shapiro', True),
#              ('special', True),
#              ('t2_astrometry', True),
#              ('tol', 1e-16),
#              ('tzrmjd_middle', 'auto'),
#              ('use_quad', False)}),
#   {'acosi_i': 1.4918871881363774831,
#    'acosi_o': 91.535524948904695826,
#    'asini_i': 1.217526739549187234,
#    'asini_o': 74.672700715937872604,
#    'd_DECJ': 9.9517656035440415914e-08,
#    'd_RAJ': -3.31526215099419648e-08,
#    'dbeta': 0.00057804934025418897576,
#    'delta': -2.2163624780208710982e-08,
#    'delta_lan': -1.1330693418536946045e-05,
#    'dgamma': -0.013343732859480423443,
#    'eps1_i': 0.00068719839927835586786,
#    'eps1_o': 0.035186241505544098979,
#    'eps2_i': -9.1197025154340876167e-05,
#    'eps2_o': -0.0034621787685230236125,
#    'f0': 365.95336878765835,
#    'j_AO1350': 5.4100888676900038229e-05,
#    'j_AO1440': 4.8914391243049301435e-05,
#    'j_AO327': 6.5118223218189614499e-05,
#    'j_GBT1500': 6.2338230148823843243e-05,
#    'j_GBT350': 1.8506967353552553922e-05,
#    'j_GBT820': 6.7997950141577114623e-05,
#    'j_WSRT350': -3.6597099565111616776e-05,
#    'pb_i': 1.6293968917747183351,
#    'pb_o': 327.25749518964780857,
#    'ppn_mode': 'heavysimple',
#    'q_i': 0.1373970962887364091,
#    'shapiro': True,
#    'tasc_i': 0.40771697551031328048,
#    'tasc_o': 313.93576643712545224,
#    'tol': 1e-16,
#    'use_quad': False})]

# %%
newp
# Out:
# {'acosi_i': 1.4897526614420296516,
#  'acosi_o': 91.406877920363995858,
#  'asini_i': 1.2175284370901029975,
#  'asini_o': 74.672709712018036338,
#  'delta': 0.0,
#  'delta_lan': 4.8220241628483202396e-05,
#  'eps1_i': 0.0006856734568106118968,
#  'eps1_o': 0.035186277265651086594,
#  'eps2_i': -9.1706450063988849455e-05,
#  'eps2_o': -0.0034621368067846675071,
#  'f0': 365.95336876828094,
#  'j_AO1350': 5.3635190284990956237e-05,
#  'j_AO1440': 4.9259452945711710099e-05,
#  'j_AO327': 6.4794561335151349273e-05,
#  'j_GBT1500': 6.2620813306723303735e-05,
#  'j_GBT350': 1.8855899287062338046e-05,
#  'j_GBT820': 6.7057259469771009361e-05,
#  'j_WSRT350': -3.6104142237134380419e-05,
#  'pb_i': 1.6294017912103802948,
#  'pb_o': 327.25753790301990501,
#  'ppn_mode': None,
#  'q_i': 0.13734741974750966142,
#  'shapiro': True,
#  'tasc_i': 0.40771744400081470636,
#  'tasc_o': 313.93581137879523948,
#  'tol': 1e-16,
#  'use_quad': False}

# %%
for k in bpd.keys():
    d = dict(k)
    if False and 'shapiro' not in d:
        d['shapiro'] = True
        bpd[frozenset(d.iteritems())] = bpd[k]
        d['shapiro'] = False
        bpd[frozenset(d.iteritems())] = bpd[k]
    if d['parfile'] == '0337_tempo2_pm.par':
        d['parfile'] = '0337_tempo2_px.par'
        nk = frozenset(d.iteritems())
        if nk not in bpd:
            bpd[nk] = bpd[k]

# %%
for k in F.best_parameters:
    if k not in p:
        print "missing from p:", k, F.best_parameters[k]
    elif F.best_parameters[k]!=p[k]:
        print "different:", k, F.best_parameters[k], p[k]
# Out:
# missing from p: f0 365.953368768

# %%
for k in bpd.keys():
    if k==frozenset(d.iteritems()):
        bpd[k].pop('pm_x',None)
        bpd[k].pop('pm_y',None)
        bpd[k].pop('f1',None)

# %%
F.parameters
# Out:
# ['asini_i',
#  'pb_i',
#  'eps1_i',
#  'eps2_i',
#  'tasc_i',
#  'acosi_i',
#  'q_i',
#  'asini_o',
#  'pb_o',
#  'eps1_o',
#  'eps2_o',
#  'tasc_o',
#  'acosi_o',
#  'delta_lan',
#  'lan',
#  'delta',
#  'dgamma',
#  'dbeta',
#  'd_RAJ',
#  'd_DECJ',
#  'd_PX',
#  'j_AO1350',
#  'j_AO1440',
#  'j_AO327',
#  'j_GBT1500',
#  'j_GBT350',
#  'j_GBT820',
#  'j_WSRT350']

# %%
paper1 = dict(files="0337+17-scott-2013-06-06",
                         parfile="0337_tempo2_nobinary.par",
                         tzrmjd_middle='auto',
                         fit_pos=False,
                         fit_pm=False,
                         fit_px=False,
                         t2_astrometry=True,
                         kopeikin=False,
                         priors=(),
                         ppn_mode=None)

# %%
F = threebody.Fitter(**paper1)

# %%
bpd[frozenset(F.args.iteritems())]
# Out:
# {'acosi_i': 1.4897526614420296516,
#  'acosi_o': 91.406877920363995858,
#  'asini_i': 1.2175284370901029975,
#  'asini_o': 74.672709712018036338,
#  'delta': 0.0,
#  'delta_lan': 4.8220241628483202396e-05,
#  'eps1_i': 0.0006856734568106118968,
#  'eps1_o': 0.035186277265651086594,
#  'eps2_i': -9.1706450063988849455e-05,
#  'eps2_o': -0.0034621368067846675071,
#  'f0': 365.95336876828094,
#  'j_AO1350': 5.3635190284990956237e-05,
#  'j_AO1440': 4.9259452945711710099e-05,
#  'j_AO327': 6.4794561335151349273e-05,
#  'j_GBT1500': 6.2620813306723303735e-05,
#  'j_GBT350': 1.8855899287062338046e-05,
#  'j_GBT820': 6.7057259469771009361e-05,
#  'j_WSRT350': -3.6104142237134380419e-05,
#  'pb_i': 1.6294017912103802948,
#  'pb_o': 327.25753790301990501,
#  'ppn_mode': None,
#  'q_i': 0.13734741974750966142,
#  'shapiro': True,
#  'tasc_i': 0.40771744400081470636,
#  'tasc_o': 313.93581137879523948,
#  'tol': 1e-16,
#  'use_quad': False}

# %%
for ot in [['AO1350','AO1440'],['GBT1500'],['WSRT1400']]:
    args = F.args.copy()
    args['only_tels'] = tuple(ot)
    bpd[frozenset(args.iteritems())] = bpd[frozenset(F.args.iteritems())]

# %% [markdown]
# ## Fill in missing parameter values
