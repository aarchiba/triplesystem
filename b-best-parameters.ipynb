# %%
# %load_ext autoreload

# %autoreload 2

# %%
import cPickle as pickle
from glob import glob
import os

import threebody

# %%
bpd = {}

# %%
bpd = threebody.load_best_parameter_database()

# %% [markdown]
# ### Update the database based on fitter results

# %%
d = pickle.load(open("fitter_params.pickle"))
F = threebody.Fitter(**d)
p = pickle.load(open("fitter_best_values.pickle"))
newp = F.best_parameters.copy()

newp.update(p)
old = -2*F.efac**2*(F.lnprob(F.best_parameters)+F.lnprior(F.best_parameters))
new = -2*F.efac**2*(F.lnprob(newp)+F.lnprior(newp))
print "existing best parameters:", old
print "best parameters from fitter:", new
# Out:
# existing best parameters: 25739.8074728
# best parameters from fitter: 25343.7514034

# %%
if new<old:
    bpd[frozenset(F.args.iteritems())] = newp
threebody.save_best_parameter_database(bpd)

# %% [markdown]
# ### Update the database by looking at the best results from an MCMC run

# %%
jobid = "32534"
job_dir = glob(os.path.join("emcee-chains",jobid+".*"))[0]

# %%
with open(os.path.join(job_dir,"fitter_params.pickle")) as f:
    fitter_params = pickle.load(f)
F = threebody.Fitter(**fitter_params)

# %%
best_so_far = np.load(os.path.join(job_dir,"best_so_far.npy"))
newp = F.best_parameters.copy()
for i,p in enumerate(F.parameters):
    newp[p] = best_so_far[i]

# %%
old = -2*F.efac**2*(F.lnprob(F.best_parameters)+F.lnprior(F.best_parameters))
new = -2*F.efac**2*(F.lnprob(newp)+F.lnprior(newp))
print "existing best parameters:", old
print "best parameters from MCMC:", new
# Out:
# existing best parameters: 57475.7547414
# best parameters from MCMC: 58244.6529262

# %%
if new<old:
    bpd[frozenset(F.args.iteritems())] = newp
threebody.save_best_parameter_database(bpd)

# %% [markdown]
# ### Update the database for a fitter by trying values for all known configurations

# %%
d = pickle.load(open("fitter_params.pickle"))
F = threebody.Fitter(**d)
if "j_NCY1400" not in F.best_parameters:
    F.best_parameters["j_NCY1400"] = 0.25*2.7e-3
old = -2*F.efac**2*(F.lnprob(F.best_parameters)+F.lnprior(F.best_parameters))
print "existing best parameters:", old
best = old
best_p = F.best_parameters.copy()
for k, p in bpd.items(): 
    newp = F.best_parameters.copy()
    newp.update(p)
    new = -2*F.efac**2*(F.lnprob(newp)+F.lnprior(newp))
    print "best parameters from database:", new
    if new<best:
        best = new
        best_p = newp
# Out:
# existing best parameters: 2504746925.04
# best parameters from database:
#  27883.7587278
# best parameters from database:
#  113428246.742
# best parameters from database: 113428246.742
# best parameters from database:
#  114180736.003
# best parameters from database: 114180736.003
# best parameters from database:
#  113428246.742
# best parameters from database:
#  114002643.434
# best parameters from database:
#  114045145.387
# best parameters from database:
#  113906277.137
# best parameters from database:
#  27731.0704868
# best parameters from database:
#  114002643.434
# best parameters from database:
#  893077370.77
# best parameters from database:
#  113858033.214
# best parameters from database:
#  114078548.181
# best parameters from database:
#  113858033.214
# best parameters from database:
#  113428246.742
# best parameters from database:
#  113858033.214
# best parameters from database:
#  113428246.742
# best parameters from database: 113428246.742
# best parameters from database:
#  114038412.23
# best parameters from database:
#  114002635.942
# best parameters from database:
#  114587558.601
# best parameters from database:
#  113428246.742
# best parameters from database: 113428246.742
# best parameters from database:
#  114078548.181
# best parameters from database:
#  114019723.081
# best parameters from database:
#  114002643.434
# best parameters from database:
#  2504746925.04
# best parameters from database:
#  114045145.387
# best parameters from database:
#  113858033.214
# best parameters from database:
#  114019723.081
# best parameters from database:
#  113428246.742
# best parameters from database:
#  33104.2283945
# best parameters from database:
#  114078548.181
# best parameters from database:
#  113428246.742
# best parameters from database:
#  113861456.69
# best parameters from database:
#  113428246.742
# best parameters from database:
#  2386683498.47
# best parameters from database:
#  27801.2650148
# best parameters from database:
#  114045145.387
# best parameters from database:
#  114002643.434
# best parameters from database:
#  113428246.742
# best parameters from database:
#  893077370.77
# best parameters from database:
#  113858033.214
# best parameters from database:
#  114078548.181
# best parameters from database:
#  113858033.214
# best parameters from database:
#  114019723.081
# best parameters from database:
#  90650.2123186
# best parameters from database:
#  114180736.003
# best parameters from database:
#  25739.8074728
# best parameters from database:
#  114038412.23
# best parameters from database:
#  114002433.79
# best parameters from database:
#  114180736.003
# No handlers could be found for logger "threebody"

# %%
bpd[frozenset(F.args.iteritems())] = best_p
threebody.save_best_parameter_database(bpd)

# %%
bpd
# Out:
# {frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-06-06'),
#             ('fit_pm', False),
#             ('fit_pos', False),
#             ('fit_px', False),
#             ('general', True),
#             ('kopeikin', False),
#             ('matrix_mode', 0),
#             ('only_tels', ('AO1350', 'AO1440')),
#             ('parfile', '0337_tempo2_nobinary.par'),
#             ('ppn_mode', None),
#             ('priors', ()),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4897526614420296516,
#   'acosi_o': 91.406877920363995858,
#   'asini_i': 1.2175284370901029975,
#   'asini_o': 74.672709712018036338,
#   'delta': 0.0,
#   'delta_lan': 4.8220241628483202396e-05,
#   'eps1_i': 0.0006856734568106118968,
#   'eps1_o': 0.035186277265651086594,
#   'eps2_i': -9.1706450063988849455e-05,
#   'eps2_o': -0.0034621368067846675071,
#   'f0': 365.95336876828094,
#   'j_AO1350': 5.3635190284990956237e-05,
#   'j_AO1440': 4.9259452945711710099e-05,
#   'j_AO327': 6.4794561335151349273e-05,
#   'j_GBT1500': 6.2620813306723303735e-05,
#   'j_GBT350': 1.8855899287062338046e-05,
#   'j_GBT820': 6.7057259469771009361e-05,
#   'j_WSRT350': -3.6104142237134380419e-05,
#   'pb_i': 1.6294017912103802948,
#   'pb_o': 327.25753790301990501,
#   'ppn_mode': None,
#   'q_i': 0.13734741974750966142,
#   'shapiro': True,
#   'tasc_i': 0.40771744400081470636,
#   'tasc_o': 313.93581137879523948,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', 'GR'),
#             ('priors', ()),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4917502711716096765,
#   'acosi_o': 91.537978361906241043,
#   'asini_i': 1.2175267841326505506,
#   'asini_o': 74.67270179576099174,
#   'd_DECJ': 8.8646943096630097989e-10,
#   'd_PMDEC': -1.9580532733266362e-10,
#   'd_PMRA': 9.885280864586482e-11,
#   'd_PX': -0.44576231637744732818,
#   'd_RAJ': -3.0457950026408630524e-09,
#   'delta_lan': -8.5542608450096089127e-06,
#   'eps1_i': 0.00068718341260624047947,
#   'eps1_o': 0.035186237417755576442,
#   'eps2_i': -9.1155391818940479249e-05,
#   'eps2_o': -0.0034621974776514838659,
#   'f0': 365.95336311128915,
#   'j_AO1350': 5.4178599925429036695e-05,
#   'j_AO1440': 4.8927806287136866099e-05,
#   'j_AO327': 6.5103043867396211205e-05,
#   'j_GBT1500': 6.2344382133130617072e-05,
#   'j_GBT350': 1.8519717889199437502e-05,
#   'j_GBT820': 6.7849258235435922024e-05,
#   'j_WSRT350': -3.6595125974280807709e-05,
#   'lan': -2.6434381081027864694,
#   'pb_i': 1.6293969535706683936,
#   'pb_o': 327.2574858984909196,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': 'GR',
#   'q_i': 0.13

#   'f0': 365.95336876828094,
#   'general': True,
#   'j_AO1350': 5.397026514259696112e-05,
#   'j_AO1440': 4.8991553548385360425e-05,
#   'j_AO327': 6.5030689101068554986e-05,
#   'j_GBT1500': 6.2351986515003780905e-05,
#   'j_GBT350': 1.8539746049516453706e-05,
#   'j_GBT820': 6.7922351602419408844e-05,
#   'j_WSRT350': -3.6604825222636967646e-05,
#   'lan': 22.663122428064735848,
#   'matrix_mode': 0,
#   'pb_i': 1.6293866452388040919,
#   'pb_o': 327.25565319235800921,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13729274824997049695,
#   'shapiro': False,
#   'special': True,
#   'tasc_i': 0.4077162786150827325,
#   'tasc_o': 313.93392418132968369,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', 'GR'),
#             ('priors', ()),
#             ('shapiro', False),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4917501887350015597,
#   'acosi_o': 91.537983170852789176,
#   'asini_i': 1.2175267840763296957,
#   'asini_o': 74.672701795905153006,
#   'd_DECJ': 8.8424170826024851099e-10,
#   'd_PMDEC': -1.9580532733266362e-10,
#   'd_PMRA': 9.885280864586482e-11,
#   'd_PX': -0.44641887754143123879,
#   'd_RAJ': -3.0466309448331401392e-09,
#   'delta_lan': -8.5659925312170722909e-06,
#   'eps1_i': 0.00068718344326590147168,
#   'eps1_o': 0.035186237412951548661,
#   'eps2_i': -9.115527301096248838e-05,
#   'eps2_o': -0.0034621974697836775743,
#   'f0': 365.95336311128915,
#   'j_AO1350': 5.4178078264052672269e-05,
#   'j_AO1440': 4.8927801018093807392e-05,
#   'j_AO327': 6.510258650977037e-05,
#   'j_GBT1500': 6.234446663504565226e-05,
#   'j_GBT350': 1.8519487327505129184e-05,
#   'j_GBT820': 6.7848748305041978355e-05,
#   'j_WSRT350': -3.6595112307622442627e-05,
#   'lan': -2.643658109504019207,
#   'pb_i': 1.6293969535702676601,
#   'pb_o': 327.25748589859133816,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': 'GR',
#   'q_i': 0.13726519094335587045,
#   'tasc_i': 0.40771702901558446841,
#   'tasc_o': 313.93575748653280483,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_px.par'),
#             ('ppn_mode', None),
#             ('priors', ()),
#             ('shapiro', False),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4870073870355541638,
#   'acosi_o': 91.237854534157803936,
#   'asini_i': 1.2175283930291920819,
#   'asini_o': 74.672699371706741871,
#   'd_DECJ': -1.9668596769468923624e-07,
#   'd_PX': 0.82283538763088315271,
#   'd_RAJ': 3.5759512633769490936e-08,
#   'delta': 0.0,
#   'delta_lan': 3.6058449713963126572e-05,
#   'eps1_i': 0.00068568720817855979873,
#   'eps1_o': 0.035186239648851740814,
#   'eps2_i': -9.1739752941784908284e-05,
#   'eps2_o': -0.0034621973342590981416,
#   'f0': 365.95336876828094,
#   'j_AO1350': 5.434208650373407444e-05,
#   'j_AO1440': 4.894359871871847276e-05,
#   'j_AO327': 6.5677301272928149774e-05,
#   'j_GBT1500': 6.2346316822423221018e-05,
#   'j_GBT350': 1.8551757984994333581e-05,
#   'j_GBT820': 6.790490288616337796e-05,
#   'j_WSRT350': -3.6541215443850041834e-05,
#   'lan': -134.38362335792677023,
#   'pb_i': 1.6294018279029601442,
#   'pb_o': 327.25749306877732375,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': None,
#   'q_i': 0.13709385397825933884,
#   'tasc_i': 0.40771752767564116107,
#   'tasc_o': 313.93576876239566756,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({(1, 1),
#             ('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', 'heavysimple'),
#             ('priors', ('dbeta', 'dgamma')),
#             ('shapiro', False),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4870960373214264,
#   'acosi_o': 91.64050818300674,
#   'asini_i': 1.2175270208510585,
#   'asini_o': 74.67269127715034,
#   'd_DECJ': 6.205370804957506e-08,
#   'd_PX': 12.592392752050834,
#   'd_RAJ': -2.4140959715819855e-08,
#   'dbeta': 0.0017496703368452343,
#   'delta': -6.377575525702637e-09,
#   'delta_lan': 0.000391698094219663,
#   'dgamma': 8.684356428714682e-06,
#   'eps1_i': 0.0006875507107658865,
#   'eps1_o': 0.03518607306587351,
#   'eps2_i': -9.134923406982514e-05,
#   'eps2_o': -0.0034622589600043453,
#   'f0': 365.95336876828094,
#   'general': True,
#   'j_AO1350': 5.643819999935814e-05,
#   'j_AO1440': 4.808926216820525e-05,
#   'j_AO327': 6.747796645765516e-05,
#   'j_GBT1500': 6.163793515666107e-05,
#   'j_GBT350': 1.6935828309848197e-05,
#   'j_GBT820': 6.938573625139912e-05,
#   'j_WSRT350': -3.757528293914576e-05,
#   'lan': 26.477464503977327,
#   'matrix_mode': 0,
#   'pb_i': 1.6293969099774286,
#   'pb_o': 327.2573831851088,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13710093267043819,
#   'special': True,
#   'tasc_i': 0.4077174545865948,
#   'tasc_o': 313.93564210578614,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', True),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('parfile', '0337_tempo2_nobinary.par'),
#             ('ppn_mode', 'GR'),
#             ('shapiro', True),
#             ('t2_astrometry', True),
#             ('tzrmjd_middle', 'auto')}): {'acosi_i': 1.4917553649083741,
#   'acosi_o': 91.53728918325116,
#   'asini_i': 1.2175267843858402,
#   'asini_o': 74.67270166579456,
#   'd_DECJ': -1.070731501745044e-09,
#   'd_PMDEC': -1.9580532733266362e-10,
#   'd_PMRA': 9.885280864586482e-11,
#   'd_PX': -0.5531255775641357,
#   'd_RAJ': -3.4254785902426147e-09,
#   'delta_lan': -1.1875825731197669e-05,
#   'eps1_i': 0.0006871812134080429,
#   'eps1_o': 0.0351862386078509,
#   'eps2_i': -9.115741533177484e-05,
#   'eps2_o': -0.003462197684711702,
#   'f0': 365.95336311128915,
#   'f1': -2.359147188177546e-15,
#   'j_AO1350': 5.416890691232084e-05,
#   'j_AO1440': 4.8927007422127645e-05,
#   'j_AO327': 6.509749509896134e-05,
#   'j_GBT1500': 6.2342354290442e-05,
#   'j_GBT350': 1.8517017863581812e-05,
#   'j_GBT820': 6.785312385988059e-05,
#   'j_WSRT350': -3.659850586544055e-05,
#   'pb_i': 1.6293969535220398,
#   'pb_o': 327.25748562198874,
#   'ppn_mode': 'GR',
#   'q_i': 0.13726698219882472,
#   'tasc_i': 0.40771702695152506,
#   'tasc_o': 313.9357571515758,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', False),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', 'heavysimple'),
#             ('priors', ('dbeta', 'dgamma')),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4906736558306250252,
#   'acosi_o': 91.51784576942648524,
#   'asini_i': 1.2175270646365951845,
#   'asini_o': 74.672630241657446365,
#   'd_DECJ': 1.6118867220248788268e-07,
#   'd_PX': 1.599439333678191133,
#   'd_RAJ': -6.030997761511506587e-08,
#   'dbeta': -0.0044409738602370583034,
#   'delta': -4.7570976758711830287e-08,
#   'delta_lan': -9.2446698208036799916e-05,
#   'dgamma': 7.2198144083240881749e-09,
#   'eps1_i': 0.00068717667851777506016,
#   'eps1_o': 0.035186213587602510246,
#   'eps2_i': -9.108891309901145672e-05,
#   'eps2_o': -0.0034620562612311675369,
#   'f0': 365.95336878765835,
#   'j_AO1350': 5.4899053733528369843e-05,
#   'j_AO1440': 4.8920171627234973538e-05,
#   'j_AO327': 6.548242502928580811e-05,
#   'j_GBT1500': 6.2428174269600328113e-05,
#   'j_GBT350': 1.8526335664259844802e-05,
#   'j_GBT820': 6.8366885786854832855e-05,
#   'j_WSRT350': -3.6577961107093393488e-05,
#   'lan': -3.210271366215223488,
#   'pb_i': 1.6293968345416796055,
#   'pb_o': 327.25740295615782147,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13701275616744529459,
#   'shapiro': True,
#   'tasc_i': 0.40771724741295354254,
#   'tasc_o': 313.9360538707316409,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-06-06'),
#             ('fit_pm', False),
#             ('fit_pos', False),
#             ('fit_px', False),
#             ('general', True),
#             ('kopeikin', False),
#             ('matrix_mode', 0),
#             ('only_tels', ('GBT1500',)),
#             ('parfile', '0337_tempo2_nobinary.par'),
#             ('ppn_mode', None),
#             ('priors', ()),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4897526614420296516,
#   'acosi_o': 91.406877920363995858,
#   'asini_i': 1.2175284370901029975,
#   'asini_o': 74.672709712018036338,
#   'delta': 0.0,
#   'delta_lan': 4.8220241628483202396e-05,
#   'eps1_i': 0.0006856734568106118968,
#   'eps1_o': 0.035186277265651086594,
#   'eps2_i': -9.1706450063988849455e-05,
#   'eps2_o': -0.0034621368067846675071,
#   'f0': 365.95336876828094,
#   'j_AO1350': 5.3635190284990956237e-05,
#   'j_AO1440': 4.9259452945711710099e-05,
#   'j_AO327': 6.4794561335151349273e-05,
#   'j_GBT1500': 6.2620813306723303735e-05,
#   'j_GBT350': 1.8855899287062338046e-05,
#   'j_GBT820': 6.7057259469771009361e-05,
#   'j_WSRT350': -3.6104142237134380419e-05,
#   'pb_i': 1.6294017912103802948,
#   'pb_o': 327.25753790301990501,
#   'ppn_mode': None,
#   'q_i': 0.13734741974750966142,
#   'shapiro': True,
#   'tasc_i': 0.40771744400081470636,
#   'tasc_o': 313.93581137879523948,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2014-01-22'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', False),
#             ('general', True),
#             ('kopeikin', False),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_px_optical.par'),
#             ('ppn_mode', 'GR'),
#             ('priors', ()),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4918437192312049521,
#   'acosi_o': 91.532778237039737909,
#   'asini_i': 1.2175267494024835254,
#   'asini_o': 74.672702265507991448,
#   'd_DECJ': 1.0262403598596522729e-07,
#   'd_RAJ': -3.3756538960864431328e-08,
#   'delta_lan': -1.1797194990156767344e-05,
#   'eps1_i': 0.00068718035161586621667,
#   'eps1_o': 0.035186247046459282362,
#   'eps2_i': -9.1189796709392292401e-05,
#   'eps2_o': -0.0034621598138703656028,
#   'f0': 365.95336878765835,
#   'j_AO1350': 5.4109955156644152237e-05,
#   'j_AO1440': 4.8913930711724925209e-05,
#   'j_AO327': 6.5123913457397526002e-05,
#   'j_GBT1500': 6.2338104349180426955e-05,
#   'j_GBT350': 1.8506406959559728913e-05,
#   'j_GBT820': 6.800341447310413326e-05,
#   'j_WSRT350': -3.6597858695465815143e-05,
#   'pb_i': 1.6293969439338296142,
#   'pb_o': 327.25750824360346886,
#   'ppn_mode': 'GR',
#   'q_i': 0.13739544781190343385,
#   'shapiro': True,
#   'tasc_i': 0.4077169805842103755,
#   'tasc_o': 313.93577942689362925,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({(1, 1),
#             ('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', 'heavysimple'),
#             ('priors', ('dbeta', 'dgamma')),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4870960373214264,
#   'acosi_o': 91.64050818300674,
#   'asini_i': 1.2175270208510585,
#   'asini_o': 74.67269127715034,
#   'd_DECJ': 6.205370804957506e-08,
#   'd_PX': 12.592392752050834,
#   'd_RAJ': -2.4140959715819855e-08,
#   'dbeta': 0.0017496703368452343,
#   'delta': -6.377575525702637e-09,
#   'delta_lan': 0.000391698094219663,
#   'dgamma': 8.684356428714682e-06,
#   'eps1_i': 0.0006875507107658865,
#   'eps1_o': 0.03518607306587351,
#   'eps2_i': -9.134923406982514e-05,
#   'eps2_o': -0.0034622589600043453,
#   'f0': 365.95336876828094,
#   'general': True,
#   'j_AO1350': 5.643819999935814e-05,
#   'j_AO1440': 4.808926216820525e-05,
#   'j_AO327': 6.747796645765516e-05,
#   'j_GBT1500': 6.163793515666107e-05,
#   'j_GBT350': 1.6935828309848197e-05,
#   'j_GBT820': 6.938573625139912e-05,
#   'j_WSRT350': -3.757528293914576e-05,
#   'lan': 26.477464503977327,
#   'matrix_mode': 0,
#   'pb_i': 1.6293969099774286,
#   'pb_o': 327.2573831851088,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13710093267043819,
#   'special': True,
#   'tasc_i': 0.4077174545865948,
#   'tasc_o': 313.93564210578614,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2014-01-22'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', False),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', 'GR'),
#             ('priors', ()),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4919123207492414033,
#   'acosi_o': 91.549155967301150773,
#   'asini_i': 1.2175269422995559784,
#   'asini_o': 74.672682140823357831,
#   'd_DECJ': 5.6404738219623152886e-08,
#   'd_RAJ': -4.294868149907536382e-08,
#   'delta_lan': -8.6169846887976622462e-05,
#   'eps1_i': 0.00068713953640601479366,
#   'eps1_o': 0.03518621547812238698,
#   'eps2_i': -9.1109746793790163895e-05,
#   'eps2_o': -0.0034623030702068482091,
#   'f0': 365.95336878765835,
#   'j_AO1350': 5.4601873849522655648e-05,
#   'j_AO1440': 4.8908096711626182531e-05,
#   'j_AO327': 6.5282770080013121003e-05,
#   'j_GBT1500': 6.2348944585226772196e-05,
#   'j_GBT350': 1.8618868684630695431e-05,
#   'j_GBT820': 6.7849343401690299448e-05,
#   'j_WSRT350': -3.66075544275630306e-05,
#   'lan': -5.3536486931612908922,
#   'pb_i': 1.629396981527031248,
#   'pb_o': 327.2574167735090051,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': 'GR',
#   'q_i': 0.1369229941434861232,
#   'shapiro': True,
#   'tasc_i': 0.40771709841264573338,
#   'tasc_o': 313.9356889734888526,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', None),
#             ('priors', ()),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4870073870355541638,
#   'acosi_o': 91.237854534157803936,
#   'asini_i': 1.2175283930291920819,
#   'asini_o': 74.672699371706741871,
#   'd_DECJ': -1.9668596769468923624e-07,
#   'd_PX': 0.82283538763088315271,
#   'd_RAJ': 3.5759512633769490936e-08,
#   'delta': 0.0,
#   'delta_lan': 3.6058449713963126572e-05,
#   'eps1_i': 0.00068568720817855979873,
#   'eps1_o': 0.035186239648851740814,
#   'eps2_i': -9.1739752941784908284e-05,
#   'eps2_o': -0.0034621973342590981416,
#   'f0': 365.95336876828094,
#   'j_AO1350': 5

#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': 'GR',
#   'q_i': 0.13726519094335587045,
#   'tasc_i': 0.40771702901558446841,
#   'tasc_o': 313.93575748653280483,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', None),
#             ('priors', ()),
#             ('shapiro', False),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4870073870355541638,
#   'acosi_o': 91.237854534157803936,
#   'asini_i': 1.2175283930291920819,
#   'asini_o': 74.672699371706741871,
#   'd_DECJ': -1.9668596769468923624e-07,
#   'd_PX': 0.82283538763088315271,
#   'd_RAJ': 3.5759512633769490936e-08,
#   'delta': 0.0,
#   'delta_lan': 3.6058449713963126572e-05,
#   'eps1_i': 0.00068568720817855979873,
#   'eps1_o': 0.035186239648851740814,
#   'eps2_i': -9.1739752941784908284e-05,
#   'eps2_o': -0.0034621973342590981416,
#   'f0': 365.95336876828094,
#   'j_AO1350': 5.434208650373407444e-05,
#   'j_AO1440': 4.894359871871847276e-05,
#   'j_AO327': 6.5677301272928149774e-05,
#   'j_GBT1500': 6.2346316822423221018e-05,
#   'j_GBT350': 1.8551757984994333581e-05,
#   'j_GBT820': 6.790490288616337796e-05,
#   'j_WSRT350': -3.6541215443850041834e-05,
#   'lan': -134.38362335792677023,
#   'pb_i': 1.6294018279029601442,
#   'pb_o': 327.25749306877732375,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': None,
#   'q_i': 0.13709385397825933884,
#   'tasc_i': 0.40771752767564116107,
#   'tasc_o': 313.93576876239566756,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-06-06'),
#             ('fit_pm', False),
#             ('fit_pos', False),
#             ('fit_px', False),
#             ('general', True),
#             ('kopeikin', False),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_nobinary.par'),
#             ('ppn_mode', None),
#             ('priors', ()),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4897526614420296516,
#   'acosi_o': 91.406877920363995858,
#   'asini_i': 1.2175284370901029975,
#   'asini_o': 74.672709712018036338,
#   'delta': 0.0,
#   'delta_lan': 4.8220241628483202396e-05,
#   'eps1_i': 0.0006856734568106118968,
#   'eps1_o': 0.035186277265651086594,
#   'eps2_i': -9.1706450063988849455e-05,
#   'eps2_o': -0.0034621368067846675071,
#   'f0': 365.95336876828094,
#   'j_AO1350': 5.3635190284990956237e-05,
#   'j_AO1440': 4.9259452945711710099e-05,
#   'j_AO327': 6.4794561335151349273e-05,
#   'j_GBT1500': 6.2620813306723303735e-05,
#   'j_GBT350': 1.8855899287062338046e-05,
#   'j_GBT820': 6.7057259469771009361e-05,
#   'j_WSRT350': -3.6104142237134380419e-05,
#   'pb_i': 1.6294017912103802948,
#   'pb_o': 327.25753790301990501,
#   'ppn_mode': None,
#   'q_i': 0.13734741974750966142,
#   'shapiro': True,
#   'tasc_i': 0.40771744400081470636,
#   'tasc_o': 313.93581137879523948,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2014-01-22'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', False),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_px_optical.par'),
#             ('ppn_mode', 'GR'),
#             ('priors', ()),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4923134372041583746,
#   'acosi_o': 91.567946711008166419,
#   'asini_i': 1.2175268965964651567,
#   'asini_o': 74.672676389613664945,
#   'd_DECJ': -4.432871613703032047e-08,
#   'd_RAJ': -3.1770148728223724486e-08,
#   'delta_lan': -6.4813973954639314311e-05,
#   'eps1_i': 0.00068713963389834500529,
#   'eps1_o': 0.035186229479527398199,
#   'eps2_i': -9.1116006557494235414e-05,
#   'eps2_o': -0.0034622849148678430641,
#   'f0': 365.95336878765835,
#   'j_AO1350': 5.3875088419603969341e-05,
#   'j_AO1440': 4.8941859758778870223e-05,
#   'j_AO327': 6.4565281193511292055e-05,
#   'j_GBT1500': 6.2325232388580194337e-05,
#   'j_GBT350': 1.8635367623171773451e-05,
#   'j_GBT820': 6.7103650343912289303e-05,
#   'j_WSRT350': -3.6579510917853825211e-05,
#   'lan': 23.44542911553395316,
#   'pb_i': 1.629396974720327375,
#   'pb_o': 327.25743142095565971,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': 'GR',
#   'q_i': 0.13699408949250487845,
#   'shapiro': True,
#   'tasc_i': 0.40771706745216272107,
#   'tasc_o': 313.935706628862985,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({(1, 1),
#             ('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_px.par'),
#             ('ppn_mode', 'heavysimple'),
#             ('priors', ('dbeta', 'dgamma')),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4870960373214264,
#   'acosi_o': 91.64050818300674,
#   'asini_i': 1.2175270208510585,
#   'asini_o': 74.67269127715034,
#   'd_DECJ': 6.205370804957506e-08,
#   'd_PX': 12.592392752050834,
#   'd_RAJ': -2.4140959715819855e-08,
#   'dbeta': 0.0017496703368452343,
#   'delta': -6.377575525702637e-09,
#   'delta_lan': 0.000391698094219663,
#   'dgamma': 8.684356428714682e-06,
#   'eps1_i': 0.0006875507107658865,
#   'eps1_o': 0.03518607306587351,
#   'eps2_i': -9.134923406982514e-05,
#   'eps2_o': -0.0034622589600043453,
#   'f0': 365.95336876828094,
#   'general': True,
#   'j_AO1350': 5.643819999935814e-05,
#   'j_AO1440': 4.808926216820525e-05,
#   'j_AO327': 6.747796645765516e-05,
#   'j_GBT1500': 6.163793515666107e-05,
#   'j_GBT350': 1.6935828309848197e-05,
#   'j_GBT820': 6.938573625139912e-05,
#   'j_WSRT350': -3.757528293914576e-05,
#   'lan': 26.477464503977327,
#   'matrix_mode': 0,
#   'pb_i': 1.6293969099774286,
#   'pb_o': 327.2573831851088,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13710093267043819,
#   'special': True,
#   'tasc_i': 0.4077174545865948,
#   'tasc_o': 313.93564210578614,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', True),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('parfile', '0337_tempo2_nobinary.par'),
#             ('ppn_mode', 'GR'),
#             ('t2_astrometry', True),
#             ('tzrmjd_middle', 'auto')}): {'acosi_i': 1.4917553649083741,
#   'acosi_o': 91.53728918325116,
#   'asini_i': 1.2175267843858402,
#   'asini_o': 74.67270166579456,
#   'd_DECJ': -1.070731501745044e-09,
#   'd_PMDEC': -1.9580532733266362e-10,
#   'd_PMRA': 9.885280864586482e-11,
#   'd_PX': -0.5531255775641357,
#   'd_RAJ': -3.4254785902426147e-09,
#   'delta_lan': -1.1875825731197669e-05,
#   'eps1_i': 0.0006871812134080429,
#   'eps1_o': 0.0351862386078509,
#   'eps2_i': -9.115741533177484e-05,
#   'eps2_o': -0.003462197684711702,
#   'f0': 365.95336311128915,
#   'f1': -2.359147188177546e-15,
#   'j_AO1350': 5.416890691232084e-05,
#   'j_AO1440': 4.8927007422127645e-05,
#   'j_AO327': 6.509749509896134e-05,
#   'j_GBT1500': 6.2342354290442e-05,
#   'j_GBT350': 1.8517017863581812e-05,
#   'j_GBT820': 6.785312385988059e-05,
#   'j_WSRT350': -3.659850586544055e-05,
#   'pb_i': 1.6293969535220398,
#   'pb_o': 327.25748562198874,
#   'ppn_mode': 'GR',
#   'q_i': 0.13726698219882472,
#   'tasc_i': 0.40771702695152506,
#   'tasc_o': 313.9357571515758,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', True),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('parfile', '0337_tempo2_nobinary.par'),
#             ('ppn_mode', 'GR'),
#             ('shapiro', False),
#             ('t2_astrometry', True),
#             ('tzrmjd_middle', 'auto')}): {'acosi_i': 1.4917553649083741,
#   'acosi_o': 91.53728918325116,
#   'asini_i': 1.2175267843858402,
#   'asini_o': 74.67270166579456,
#   'd_DECJ': -1.070731501745044e-09,
#   'd_PMDEC': -1.9580532733266362e-10,
#   'd_PMRA': 9.885280864586482e-11,
#   'd_PX': -0.5531255775641357,
#   'd_RAJ': -3.4254785902426147e-09,
#   'delta_lan': -1.1875825731197669e-05,
#   'eps1_i': 0.0006871812134080429,
#   'eps1_o': 0.0351862386078509,
#   'eps2_i': -9.115741533177484e-05,
#   'eps2_o': -0.003462197684711702,
#   'f0': 365.95336311128915,
#   'f1': -2.359147188177546e-15,
#   'j_AO1350': 5.416890691232084e-05,
#   'j_AO1440': 4.8927007422127645e-05,
#   'j_AO327': 6.509749509896134e-05,
#   'j_GBT1500': 6.2342354290442e-05,
#   'j_GBT350': 1.8517017863581812e-05,
# ...
#   'j_GBT350': 1.8551757984994333581e-05,
#   'j_GBT820': 6.790490288616337796e-05,
#   'j_WSRT350': -3.6541215443850041834e-05,
#   'lan': -134.38362335792677023,
#   'pb_i': 1.6294018279029601442,
#   'pb_o': 327.25749306877732375,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': None,
#   'q_i': 0.13709385397825933884,
#   'tasc_i': 0.40771752767564116107,
#   'tasc_o': 313.93576876239566756,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', 'GR'),
#             ('priors', ()),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4917501887350015597,
#   'acosi_o': 91.537983170852789176,
#   'asini_i': 1.2175267840763296957,
#   'asini_o': 74.672701795905153006,
#   'd_DECJ': 8.8424170826024851099e-10,
#   'd_PMDEC': -1.9580532733266362e-10,
#   'd_PMRA': 9.885280864586482e-11,
#   'd_PX': -0.44641887754143123879,
#   'd_RAJ': -3.0466309448331401392e-09,
#   'delta_lan': -8.5659925312170722909e-06,
#   'eps1_i': 0.00068718344326590147168,
#   'eps1_o': 0.035186237412951548661,
#   'eps2_i': -9.115527301096248838e-05,
#   'eps2_o': -0.0034621974697836775743,
#   'f0': 365.95336311128915,
#   'j_AO1350': 5.4178078264052672269e-05,
#   'j_AO1440': 4.8927801018093807392e-05,
#   'j_AO327': 6.510258650977037e-05,
#   'j_GBT1500': 6.234446663504565226e-05,
#   'j_GBT350': 1.8519487327505129184e-05,
#   'j_GBT820': 6.7848748305041978355e-05,
#   'j_WSRT350': -3.6595112307622442627e-05,
#   'lan': -2.643658109504019207,
#   'pb_i': 1.6293969535702676601,
#   'pb_o': 327.25748589859133816,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': 'GR',
#   'q_i': 0.13726519094335587045,
#   'tasc_i': 0.40771702901558446841,
#   'tasc_o': 313.93575748653280483,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', False),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_px.par'),
#             ('ppn_mode', 'heavysimple'),
#             ('priors', ('dbeta', 'dgamma')),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4906736558306250252,
#   'acosi_o': 91.51784576942648524,
#   'asini_i': 1.2175270646365951845,
#   'asini_o': 74.672630241657446365,
#   'd_DECJ': 1.6118867220248788268e-07,
#   'd_PX': 1.599439333678191133,
#   'd_RAJ': -6.030997761511506587e-08,
#   'dbeta': -0.0044409738602370583034,
#   'delta': -4.7570976758711830287e-08,
#   'delta_lan': -9.2446698208036799916e-05,
#   'dgamma': 7.2198144083240881749e-09,
#   'eps1_i': 0.00068717667851777506016,
#   'eps1_o': 0.035186213587602510246,
#   'eps2_i': -9.108891309901145672e-05,
#   'eps2_o': -0.0034620562612311675369,
#   'f0': 365.95336878765835,
#   'j_AO1350': 5.4899053733528369843e-05,
#   'j_AO1440': 4.8920171627234973538e-05,
#   'j_AO327': 6.548242502928580811e-05,
#   'j_GBT1500': 6.2428174269600328113e-05,
#   'j_GBT350': 1.8526335664259844802e-05,
#   'j_GBT820': 6.8366885786854832855e-05,
#   'j_WSRT350': -3.6577961107093393488e-05,
#   'lan': -3.210271366215223488,
#   'pb_i': 1.6293968345416796055,
#   'pb_o': 327.25740295615782147,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13701275616744529459,
#   'shapiro': True,
#   'tasc_i': 0.40771724741295354254,
#   'tasc_o': 313.9360538707316409,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_px.par'),
#             ('ppn_mode', 'heavysimple'),
#             ('priors', ('dbeta', 'dgamma')),
#             ('shapiro', False),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4910576218528956638,
#   'acosi_o': 91.482292931993824565,
#   'asini_i': 1.217524275485909434,
#   'asini_o': 74.672498386687887306,
#   'd_DECJ': 1.5874545950097263076e-07,
#   'd_PX': -0.0342365032445482078,
#   'd_RAJ': -3.529865376451191052e-08,
#   'dbeta': -0.00042355065260297776296,
#   'delta': -3.1672588685309433137e-06,
#   'delta_lan': -2.4594703631176065514e-06,
#   'dgamma': 8.2962150765616317161e-06,
#   'eps1_i': 0.00069074046734913581325,
#   'eps1_o': 0.035185441371675409314,
#   'eps2_i': -9.1384457191739417255e-05,
#   'eps2_o': -0.0034648656080614749766,
#   'f0': 365.95336876828094,
#   'general': True,
#   'j_AO1350': 5.397026514259696112e-05,
#   'j_AO1440': 4.8991553548385360425e-05,
#   'j_AO327': 6.5030689101068554986e-05,
#   'j_GBT1500': 6.2351986515003780905e-05,
#   'j_GBT350': 1.8539746049516453706e-05,
#   'j_GBT820': 6.7922351602419408844e-05,
#   'j_WSRT350': -3.6604825222636967646e-05,
#   'lan': 22.663122428064735848,
#   'matrix_mode': 0,
#   'pb_i': 1.6293866452388040919,
#   'pb_o': 327.25565319235800921,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13729274824997049695,
#   'shapiro': False,
#   'special': True,
#   'tasc_i': 0.4077162786150827325,
#   'tasc_o': 313.93392418132968369,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({(1, 1),
#             ('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_px.par'),
#             ('ppn_mode', 'heavysimple'),
#             ('priors', ('dbeta', 'dgamma')),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4870960373214264,
#   'acosi_o': 91.64050818300674,
#   'asini_i': 1.2175270208510585,
#   'asini_o': 74.67269127715034,
#   'd_DECJ': 6.205370804957506e-08,
#   'd_PX': 12.592392752050834,
#   'd_RAJ': -2.4140959715819855e-08,
#   'dbeta': 0.0017496703368452343,
#   'delta': -6.377575525702637e-09,
#   'delta_lan': 0.000391698094219663,
#   'dgamma': 8.684356428714682e-06,
#   'eps1_i': 0.0006875507107658865,
#   'eps1_o': 0.03518607306587351,
#   'eps2_i': -9.134923406982514e-05,
#   'eps2_o': -0.0034622589600043453,
#   'f0': 365.95336876828094,
#   'general': True,
#   'j_AO1350': 5.643819999935814e-05,
#   'j_AO1440': 4.808926216820525e-05,
#   'j_AO327': 6.747796645765516e-05,
#   'j_GBT1500': 6.163793515666107e-05,
#   'j_GBT350': 1.6935828309848197e-05,
#   'j_GBT820': 6.938573625139912e-05,
#   'j_WSRT350': -3.757528293914576e-05,
#   'lan': 26.477464503977327,
#   'matrix_mode': 0,
#   'pb_i': 1.6293969099774286,
#   'pb_o': 327.2573831851088,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13710093267043819,
#   'special': True,
#   'tasc_i': 0.4077174545865948,
#   'tasc_o': 313.93564210578614,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('kopeikin', True),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', 'heavysimple'),
#             ('priors', ('dbeta', 'dgamma')),
#             ('shapiro', False),
#             ('t2_astrometry', True),
#             ('tzrmjd_middle', 'auto')}): {'acosi_i': 1.4870960373214264,
#   'acosi_o': 91.64050818300674,
#   'asini_i': 1.2175270208510585,
#   'asini_o': 74.67269127715034,
#   'd_DECJ': 6.205370804957506e-08,
#   'd_PX': 12.592392752050834,
#   'd_RAJ': -2.4140959715819855e-08,
#   'dbeta': 0.0017496703368452343,
#   'delta': -6.377575525702637e-09,
#   'delta_lan': 0.000391698094219663,
#   'dgamma': 8.684356428714682e-06,
#   'eps1_i': 0.0006875507107658865,
#   'eps1_o': 0.03518607306587351,
#   'eps2_i': -9.134923406982514e-05,
#   'eps2_o': -0.0034622589600043453,
#   'general': True,
#   'j_AO1350': 5.643819999935814e-05,
#   'j_AO1440': 4.808926216820525e-05,
#   'j_AO327': 6.747796645765516e-05,
#   'j_GBT1500': 6.163793515666107e-05,
#   'j_GBT350': 1.6935828309848197e-05,
#   'j_GBT820': 6.938573625139912e-05,
#   'j_WSRT350': -3.757528293914576e-05,
#   'lan': 26.477464503977327,
#   'matrix_mode': 0,
#   'pb_i': 1.6293969099774286,
#   'pb_o': 327.2573831851088,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13710093267043819,
#   'special': True,
#   'tasc_i': 0.4077174545865948,
#   'tasc_o': 313.93564210578614,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({(1, 1),
#             ('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_px.par'),
#             ('ppn_mode', 'heavysimple'),
#             ('priors', ('dbeta', 'dgamma')),
#             ('shapiro', False),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4870960373214264,
#   'acosi_o': 91.64050818300674,
#   'asini_i': 1.2175270208510585,
#   'asini_o': 74.67269127715034,
#   'd_DECJ': 6.205370804957506e-08,
#   'd_PX': 12.592392752050834,
#   'd_RAJ': -2.4140959715819855e-08,
#   'dbeta': 0.0017496703368452343,
#   'delta': -6.377575525702637e-09,
#   'delta_lan': 0.000391698094219663,
#   'dgamma': 8.684356428714682e-06,
#   'eps1_i': 0.0006875507107658865,
#   'eps1_o': 0.03518607306587351,
#   'eps2_i': -9.134923406982514e-05,
#   'eps2_o': -0.0034622589600043453,
#   'f0': 365.95336876828094,
#   'general': True,
#   'j_AO1350': 5.643819999935814e-05,
#   'j_AO1440': 4.808926216820525e-05,
#   'j_AO327': 6.747796645765516e-05,
#   'j_GBT1500': 6.163793515666107e-05,
#   'j_GBT350': 1.6935828309848197e-05,
#   'j_GBT820': 6.938573625139912e-05,
#   'j_WSRT350': -3.757528293914576e-05,
#   'lan': 26.477464503977327,
#   'matrix_mode': 0,
#   'pb_i': 1.6293969099774286,
#   'pb_o': 327.2573831851088,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13710093267043819,
#   'special': True,
#   'tasc_i': 0.4077174545865948,
#   'tasc_o': 313.93564210578614,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-06-06'),
#             ('fit_pm', False),
#             ('fit_pos', False),
#             ('fit_px', False),
#             ('general', True),
#             ('kopeikin', False),
#             ('matrix_mode', 0),
#             ('only_tels', ('WSRT1400',)),
#             ('parfile', '0337_tempo2_nobinary.par'),
#             ('ppn_mode', None),
#             ('priors', ()),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4897526614420296516,
#   'acosi_o': 91.406877920363995858,
#   'asini_i': 1.2175284370901029975,
#   'asini_o': 74.672709712018036338,
#   'delta': 0.0,
#   'delta_lan': 4.8220241628483202396e-05,
#   'eps1_i': 0.0006856734568106118968,
#   'eps1_o': 0.035186277265651086594,
#   'eps2_i': -9.1706450063988849455e-05,
#   'eps2_o': -0.0034621368067846675071,
#   'f0': 365.95336876828094,
#   'j_AO1350': 5.3635190284990956237e-05,
#   'j_AO1440': 4.9259452945711710099e-05,
#   'j_AO327': 6.4794561335151349273e-05,
#   'j_GBT1500': 6.2620813306723303735e-05,
#   'j_GBT350': 1.8855899287062338046e-05,
#   'j_GBT820': 6.7057259469771009361e-05,
#   'j_WSRT350': -3.6104142237134380419e-05,
#   'pb_i': 1.6294017912103802948,
#   'pb_o': 327.25753790301990501,
#   'ppn_mode': None,
#   'q_i': 0.13734741974750966142,
#   'shapiro': True,
#   'tasc_i': 0.40771744400081470636,
#   'tasc_o': 313.93581137879523948,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('kopeikin', True),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', 'heavysimple'),
#             ('priors', ('dbeta', 'dgamma')),
#             ('shapiro', True),
#             ('t2_astrometry', True),
#             ('tzrmjd_middle', 'auto')}): {'acosi_i': 1.4870960373214264,
#   'acosi_o': 91.64050818300674,
#   'asini_i': 1.2175270208510585,
#   'asini_o': 74.67269127715034,
#   'd_DECJ': 6.205370804957506e-08,
#   'd_PX': 12.592392752050834,
#   'd_RAJ': -2.4140959715819855e-08,
#   'dbeta': 0.0017496703368452343,
#   'delta': -6.377575525702637e-09,
#   'delta_lan': 0.000391698094219663,
#   'dgamma': 8.684356428714682e-06,
#   'eps1_i': 0.0006875507107658865,
#   'eps1_o': 0.03518607306587351,
#   'eps2_i': -9.134923406982514e-05,
#   'eps2_o': -0.0034622589600043453,
#   'general': True,
#   'j_AO1350': 5.643819999935814e-05,
#   'j_AO1440': 4.808926216820525e-05,
#   'j_AO327': 6.747796645765516e-05,
#   'j_GBT1500': 6.163793515666107e-05,
#   'j_GBT350': 1.6935828309848197e-05,
#   'j_GBT820': 6.938573625139912e-05,
#   'j_WSRT350': -3.757528293914576e-05,
#   'lan': 26.477464503977327,
#   'matrix_mode': 0,
#   'pb_i': 1.6293969099774286,
#   'pb_o': 327.2573831851088,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13710093267043819,
#   'special': True,
#   'tasc_i': 0.4077174545865948,
#   'tasc_o': 313.93564210578614,
#   'tol': 1e-16,
#   'use_quad': False},
#  frozenset({('efac', 1.3),
#             ('files', '0337+17-scott-2013-08-29'),
#             ('fit_pm', False),
#             ('fit_pos', True),
#             ('fit_px', True),
#             ('general', True),
#             ('kopeikin', True),
#             ('matrix_mode', 0),
#             ('only_tels', None),
#             ('parfile', '0337_tempo2_pm.par'),
#             ('ppn_mode', 'heavysimple'),
#             ('priors', ('dbeta', 'dgamma')),
#             ('shapiro', True),
#             ('special', True),
#             ('t2_astrometry', True),
#             ('tol', 1e-16),
#             ('tzrmjd_middle', 'auto'),
#             ('use_quad', False)}): {'acosi_i': 1.4910499077251168371,
#   'acosi_o': 91.482011824902850099,
#   'asini_i': 1.2175228833065895201,
#   'asini_o': 74.672497019984797106,
#   'd_DECJ': 1.6847336940935975218e-07,
#   'd_PX': -0.92477760701603597092,
#   'd_RAJ': -3.2388334094615887816e-08,
#   'dbeta': -0.00041698493776006720714,
#   'delta': -3.1672615080429307528e-06,
#   'delta_lan': -1.112757573007618058e-05,
#   'dgamma': 1.175749501990592583e-06,
#   'eps1_i': 0.0006903474655345057885,
#   'eps1_o': 0.03518543595937889206,
#   'eps2_i': -9.1385774154890500486e-05,
#   'eps2_o': -0.0034648723233093286863,
#   'f0': 365.95336876828094,
#   'general': True,
#   'j_AO1350': 5.4169010371405938449e-05,
#   'j_AO1440': 4.8930549945746121983e-05,
#   'j_AO327': 6.5301884179095320452e-05,
#   'j_GBT1500': 6.2334158805205982467e-05,
#   'j_GBT350': 1.8510494219682503864e-05,
#   'j_GBT820': 6.7999885696179984064e-05,
#   'j_WSRT350': -3.6586764591042250491e-05,
#   'lan': 22.854202311569486596,
#   'matrix_mode': 0,
#   'pb_i': 1.6293866452666076329,
#   'pb_o': 327.25565437712082301,
#   'pm_x': -4.7253571656398304e-11,
#   'pm_y': 5.176655321908803e-11,
#   'ppn_mode': 'heavysimple',
#   'q_i': 0.13729300135991373022,
#   'special': True,
#   'tasc_i': 0.4077160812719808227,
#   'tasc_o': 313.93392396740035599,
#   'tol': 1e-16,
#   'use_quad': False}}

# %%
newp
# Out:
# {'acosi_i': 1.4897526614420296516,
#  'acosi_o': 91.406877920363995858,
#  'asini_i': 1.2175284370901029975,
#  'asini_o': 74.672709712018036338,
#  'delta': 0.0,
#  'delta_lan': 4.8220241628483202396e-05,
#  'eps1_i': 0.0006856734568106118968,
#  'eps1_o': 0.035186277265651086594,
#  'eps2_i': -9.1706450063988849455e-05,
#  'eps2_o': -0.0034621368067846675071,
#  'f0': 365.95336876828094,
#  'j_AO1350': 5.3635190284990956237e-05,
#  'j_AO1440': 4.9259452945711710099e-05,
#  'j_AO327': 6.4794561335151349273e-05,
#  'j_GBT1500': 6.2620813306723303735e-05,
#  'j_GBT350': 1.8855899287062338046e-05,
#  'j_GBT820': 6.7057259469771009361e-05,
#  'j_WSRT350': -3.6104142237134380419e-05,
#  'pb_i': 1.6294017912103802948,
#  'pb_o': 327.25753790301990501,
#  'ppn_mode': None,
#  'q_i': 0.13734741974750966142,
#  'shapiro': True,
#  'tasc_i': 0.40771744400081470636,
#  'tasc_o': 313.93581137879523948,
#  'tol': 1e-16,
#  'use_quad': False}

# %%
for k in bpd.keys():
    d = dict(k)
    if False and 'shapiro' not in d:
        d['shapiro'] = True
        bpd[frozenset(d.iteritems())] = bpd[k]
        d['shapiro'] = False
        bpd[frozenset(d.iteritems())] = bpd[k]
    if d['parfile'] == '0337_tempo2_pm.par':
        d['parfile'] = '0337_tempo2_px.par'
        nk = frozenset(d.iteritems())
        if nk not in bpd:
            bpd[nk] = bpd[k]

# %%
for k in F.best_parameters:
    if k not in p:
        print "missing from p:", k, F.best_parameters[k]
    elif F.best_parameters[k]!=p[k]:
        print "different:", k, F.best_parameters[k], p[k]
# Out:
# missing from p: f0 365.953368768

# %%
for k in bpd.keys():
    if k==frozenset(d.iteritems()):
        bpd[k].pop('pm_x',None)
        bpd[k].pop('pm_y',None)
        bpd[k].pop('f1',None)

# %%
F.parameters
# Out:
# ['asini_i',
#  'pb_i',
#  'eps1_i',
#  'eps2_i',
#  'tasc_i',
#  'acosi_i',
#  'q_i',
#  'asini_o',
#  'pb_o',
#  'eps1_o',
#  'eps2_o',
#  'tasc_o',
#  'acosi_o',
#  'delta_lan',
#  'lan',
#  'delta',
#  'dgamma',
#  'dbeta',
#  'd_RAJ',
#  'd_DECJ',
#  'd_PX',
#  'j_AO1350',
#  'j_AO1440',
#  'j_AO327',
#  'j_GBT1500',
#  'j_GBT350',
#  'j_GBT820',
#  'j_WSRT350']

# %%
paper1 = dict(files="0337+17-scott-2013-06-06",
                         parfile="0337_tempo2_nobinary.par",
                         tzrmjd_middle='auto',
                         fit_pos=False,
                         fit_pm=False,
                         fit_px=False,
                         t2_astrometry=True,
                         kopeikin=False,
                         priors=(),
                         ppn_mode=None)

# %%
F = threebody.Fitter(**paper1)

# %%
bpd[frozenset(F.args.iteritems())]
# Out:
# {'acosi_i': 1.4897526614420296516,
#  'acosi_o': 91.406877920363995858,
#  'asini_i': 1.2175284370901029975,
#  'asini_o': 74.672709712018036338,
#  'delta': 0.0,
#  'delta_lan': 4.8220241628483202396e-05,
#  'eps1_i': 0.0006856734568106118968,
#  'eps1_o': 0.035186277265651086594,
#  'eps2_i': -9.1706450063988849455e-05,
#  'eps2_o': -0.0034621368067846675071,
#  'f0': 365.95336876828094,
#  'j_AO1350': 5.3635190284990956237e-05,
#  'j_AO1440': 4.9259452945711710099e-05,
#  'j_AO327': 6.4794561335151349273e-05,
#  'j_GBT1500': 6.2620813306723303735e-05,
#  'j_GBT350': 1.8855899287062338046e-05,
#  'j_GBT820': 6.7057259469771009361e-05,
#  'j_WSRT350': -3.6104142237134380419e-05,
#  'pb_i': 1.6294017912103802948,
#  'pb_o': 327.25753790301990501,
#  'ppn_mode': None,
#  'q_i': 0.13734741974750966142,
#  'shapiro': True,
#  'tasc_i': 0.40771744400081470636,
#  'tasc_o': 313.93581137879523948,
#  'tol': 1e-16,
#  'use_quad': False}

# %%
for ot in [['AO1350','AO1440'],['GBT1500'],['WSRT1400']]:
    args = F.args.copy()
    args['only_tels'] = tuple(ot)
    bpd[frozenset(args.iteritems())] = bpd[frozenset(F.args.iteritems())]
